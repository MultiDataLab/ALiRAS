# %% [markdown]
# # XLSR - ITW

# %%
import pandas as pd

# %%
import tensorflow as tf

# %%
#import torch

# %%
pd
# Out:
# <module 'pandas' from '/umbc/rs/iharp/users/zkhanja1/tensorflow_env/lib/python3.13/site-packages/pandas/__init__.py'>

# %%
pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install -U scikit-learn scipy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 2.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.7/37.7 MB 58.2 MB/s eta 0:00:00:00:0100:01
# ...
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.15.2
#     Uninstalling scipy-1.15.2:
#       Successfully uninstalled scipy-1.15.2
#   WARNING: Failed to remove contents in a temporary directory '/umbc/rs/iharp/users/zkhanja1/.local/lib/python3.11/site-packages/~cipy.libs'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory '/umbc/rs/iharp/users/zkhanja1/.local/lib/python3.11/site-packages/~cipy'.
#   You can safely remove it manually.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ...

# %%
pip install librosa
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install resampy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install tf_slim
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from tensorflow.keras.models import Model
from tensorflow.keras import Input
from tensorflow.keras.layers import concatenate, Permute, Reshape
import os

# %%
import math
import glob
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential

# %%
#from tensorflow.keras.optimizers import Adam
from tensorflow.keras.optimizers.legacy import Adam
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.layers import LSTM,TimeDistributed
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.layers import BatchNormalization
from keras.layers import MaxPooling2D
from keras.layers import BatchNormalization
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.model_selection import StratifiedKFold
import numpy as np
import sklearn.metrics as metrics

# %%
import pandas as pd
import math
import numpy as np
#from numpy.lib.function_base import average
import os
import librosa
import librosa.display
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import normalize
import warnings
warnings.filterwarnings('ignore')
from sklearn.model_selection import train_test_split
import tensorflow
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras import models, layers
import tensorflow as tf
from matplotlib.pyplot import specgram
import glob

# %%
y_test_new
# Out:
#      audio_filenames     Label
# 0       E_0000000024     spoof
# 1       E_0000000034     spoof
# 2       E_0000000076     spoof
# 3       E_0000000111     spoof
# 4       E_0000000146     spoof
# ...              ...       ...
# 6995    E_0000106133     spoof
# 6996    E_0000106138  bonafide
# 6997    E_0000106142  bonafide
# 6998    E_0000106158     spoof
# 6999    E_0000106161     spoof
#
# [7000 rows x 2 columns]

# %%
from sklearn.metrics import confusion_matrix
import IPython.display as ipd  # To play sound in the notebook
from sklearn.model_selection import train_test_split
import tensorflow.keras as keras
import sys
import warnings
# ignore warnings
if not sys.warnoptions:
    warnings.simplefilter("ignore")
warnings.filterwarnings("ignore", category=DeprecationWarning)
import json

from sklearn.preprocessing import normalize
import warnings
warnings.filterwarnings('ignore')

import pickle
import joblib
from tensorflow.keras import models, layers
import tensorflow as tf

# %%
import tensorflow as tf

# Simple operation
with tf.device('/GPU:0'):
    a = tf.constant([[1.0, 2.0], [3.0, 4.0]])
    b = tf.constant([[1.0, 1.0], [0.0, 1.0]])
    c = tf.matmul(a, b)

print(c)

# Check where the tensor was placed
print("Operation executed on:", c.device)
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1767888310.865805 2015047 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 22804 MB memory:  -> device: 0, name: Quadro RTX 6000, pci bus id: 0000:1b:00.0, compute capability: 7.5
# tf.Tensor(
# [[1. 3.]
#  [3. 7.]], shape=(2, 2), dtype=float32)
# Operation executed on: /job:localhost/replica:0/task:0/device:GPU:0

# %%
print("Num GPUs Available:", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available: 1

# %%
import tensorflow as tf
import librosa
import os

# %%
pip install ffmpeg
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for ffmpeg: filename=ffmpeg-1.4-py3-none-any.whl size=6082 sha256=9a34e0c2d141d532efe8a2a5039eaa8d21fb51146cc3f7feca77e7875c09df23
#   Stored in directory: /umbc/rs/iharp/users/zkhanja1/.cache/pip/wheels/56/30/c5/576bdd729f3bc062d62a551be7fefd6ed2f761901568171e4e
# Successfully built ffmpeg
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# !module load FFmpeg/7.0.2-GCCcore-13.3.0

# %%
import ffmpeg
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 import ffmpeg
#
# ModuleNotFoundError: No module named 'ffmpeg'

# %%
# !ffmpeg -version

# %%
import os
import subprocess
#flac_folder = '/umbc/rs/vjaneja/users/zkhanja1/first_7000_subset_pa_train'
#wav_folder = '/umbc/rs/vjaneja/users/zkhanja1/first_7000_subset_pa_train_converted_wav'

# %%
# !pip install ffmpeg-python

# %% [markdown]
# import ffmpeg
# import os
#
# #flac_folder = '/umbc/rs/vjaneja/users/zkhanja1/first_7000_subset_pa_train'
# #wav_folder = '/umbc/rs/vjaneja/users/zkhanja1/first_7000_subset_pa_train_converted_wav'
#
# os.makedirs(wav_folder, exist_ok=True)
#
# for file in os.listdir(flac_folder):
#     if file.endswith(".flac"):
#         flac_path = os.path.join(flac_folder, file)
#         wav_path = os.path.join(wav_folder, file.replace(".flac", ".wav"))
#
#         # Convert .flac to .wav using ffmpeg-python
#         ffmpeg.input(flac_path).output(wav_path).run()

# %%
import numpy as np
from sklearn.metrics import roc_curve

def compute_eer(y_true, y_probs):
    """
    Computes the Equal Error Rate (EER) as the average of FPR and FNR.
    
    Parameters:
        y_true (array-like): True binary labels (0 or 1).
        y_probs (array-like): Predicted probabilities for the positive class.

    Returns:
        eer (float): Equal Error Rate (average of FPR and FNR).
        eer_threshold (float): Threshold where FPR and FNR are closest.
    """
    # Compute ROC curve
    fpr, tpr, thresholds = roc_curve(y_true, y_probs)

    # Compute False Negative Rate (FNR)
    fnr = 1 - tpr  # FNR = 1 - TPR

    # Find the threshold where FPR and FNR are closest
    eer_index = np.nanargmin(np.abs(fpr - fnr))  # Get index of min difference
    eer_threshold = thresholds[eer_index]

    # Compute EER as the average of FPR and FNR at that threshold
    eer = (fpr[eer_index] + fnr[eer_index]) / 2

    return eer, eer_threshold

# %%
eer, eer_threshold = compute_eer(y_train, probs_train)
print(f"EER (Average of FPR & FNR): {eer:.4f}, Threshold: {eer_threshold:.4f}")
# Out:
# EER (Average of FPR & FNR): 0.1252, Threshold: 0.6353

# %%
from sklearn.metrics import confusion_matrix
import numpy as np

def compute_eer_fixed_threshold(y_true, y_scores, threshold):
    """
    Compute the Equal Error Rate (EER) at a fixed threshold.
    
    Parameters:
    - y_true: array-like of shape (n_samples,) -> True binary labels (0 or 1)
    - y_scores: array-like of shape (n_samples,) -> Predicted scores/probabilities
    - threshold: float, the fixed threshold at which to compute EER
    
    Returns:
    - eer: float, the average of FPR and FNR at the fixed threshold
    """
    # Convert scores to binary predictions using the fixed threshold
    y_pred = (y_scores >= threshold).astype(int)
    
    # Compute confusion matrix
    tn, fp, fn, tp = confusion_matrix(y_true, y_pred).ravel()
    
    # Compute False Positive Rate (FPR) and False Negative Rate (FNR)
    fpr = fp / (fp + tn) if (fp + tn) > 0 else 0.0
    fnr = fn / (fn + tp) if (fn + tp) > 0 else 0.0
    
    # Compute EER as the average of FPR and FNR
    eer = (fpr + fnr) / 2
    
    return eer

# %%
eer_test = compute_eer_fixed_threshold(y_test, probs_test, 0.6353)

# %%
eer_test
# Out:
# np.float64(0.5055904504635829)

# %%
/umbc/rs/iharp/users/zkhanja1/converted_wavs_df_7000

# %%
pwd
# Out:
# '/umbc/rs/iharp/users/zkhanja1/asvspoof5_codes'

# %% [markdown]
# Fake vs real Detection using HuBERT:

# %%
y_test1 = pd.read_excel('/umbc/rs/iharp/users/zkhanja1/in_the_wild_more_files/audio_filenames_for_xlsr_ITW_0to5000.xlsx')

# %%
y_test2 = pd.read_excel('/umbc/rs/iharp/users/zkhanja1/in_the_wild_more_files/audio_filenames_for_xlsr_ITW_5000to10000.xlsx')

# %%
y_test3= pd.read_excel('/umbc/rs/iharp/users/zkhanja1/in_the_wild_more_files/audio_filenames_for_xlsr_ITW_10000to15000.xlsx')

# %%
y_test4= pd.read_excel('/umbc/rs/iharp/users/zkhanja1/in_the_wild_more_files/audio_filenames_for_xlsr_ITW_15000to20000.xlsx')

# %%
y_test5= pd.read_excel('/umbc/rs/iharp/users/zkhanja1/in_the_wild_more_files/audio_filenames_for_xlsr_ITW_20000to25000.xlsx')

# %%
y_test6= pd.read_excel('/umbc/rs/iharp/users/zkhanja1/in_the_wild_more_files/audio_filenames_for_xlsr_ITW_25000to31777.xlsx')

# %%
 y_train1 = pd.read_excel('/umbc/rs/iharp/users/zkhanja1/asvspoof5/audio_filenames_for_xlsr_df_flac_T_aa_asvspoof5_0to7000.xlsx')

# %%
#y_train2= pd.read_excel('/umbc/rs/iharp/users/zkhanja1/asvspoof5/audio_filenames_for_xlsr_df_T_3001to7000.xlsx')

# %%
y_test = pd.concat([y_test1, y_test2, y_test3, y_test4, y_test5, y_test6], ignore_index=True)

# %%
y_train = y_train1

# %%
y_test
# Out:
#       audio_filenames
# 0               0.wav
# 1               1.wav
# 2              10.wav
# 3             100.wav
# 4            1000.wav
# ...               ...
# 31772        9993.wav
# 31773        9994.wav
# 31774        9995.wav
# 31775        9996.wav
# 31776        9997.wav
#
# [31777 rows x 1 columns]

# %%
y_train
# Out:
#         audio_filenames
# 0     T_0000000000.flac
# 1     T_0000000001.flac
# 2     T_0000000002.flac
# 3     T_0000000003.flac
# 4     T_0000000004.flac
# ...                 ...
# 6995  T_0000006995.flac
# 6996  T_0000006996.flac
# 6997  T_0000006997.flac
# 6998  T_0000006998.flac
# 6999  T_0000006999.flac
#
# [7000 rows x 1 columns]

# %%
 #Df_train_with_labels.csv

# %%
 #Df_eval_all_parts_with_labels.csv

# %%
pwd
# Out:
# '/umbc/rs/iharp/users/zkhanja1/asvspoof5_codes'

# %%
Df_train_with_labels = pd.read_csv('/umbc/rs/iharp/users/zkhanja1/asvspoof5/protocols/ASVspoof5.train.tsv', sep=' ', header=None)

# %%
Df_train_with_labels
# Out:
#                         0  1  2  3  4    5         6         7  8
# 0       T_0000000000.flac  F  -  -  -  AC3       A05     spoof  -
# 1       T_0000000001.flac  M  -  -  -  AC3       A07     spoof  -
# 2       T_0000000002.flac  M  -  -  -  AC2       A04     spoof  -
# 3       T_0000000003.flac  M  -  -  -  AC2       A08     spoof  -
# 4       T_0000000004.flac  M  -  -  -  AC2       A05     spoof  -
# ...                   ... .. .. .. ..  ...       ...       ... ..
# 182352  T_0000182352.flac  F  -  -  -  AC2       A03     spoof  -
# 182353  T_0000182353.flac  M  -  -  -  AC2       A05     spoof  -
# 182354  T_0000182354.flac  M  -  -  -  AC3       A02     spoof  -
# 182355  T_0000182355.flac  M  -  -  -    -  bonafide  bonafide  -
# 182356  T_0000182356.flac  M  -  -  -  AC2       A06     spoof  -
#
# [182357 rows x 9 columns]

# %%
Df_train_with_labels.columns
# Out:
# Index([0, 1, 2, 3, 4, 5, 6, 7, 8], dtype='int64')

# %%
pwd
# Out:
# '/umbc/rs/iharp/users/zkhanja1/asvspoof5_codes_and_ITW'

# %%
 Df_eval_all_parts_with_labels = pd.read_csv('/umbc/rs/iharp/users/zkhanja1/in_the_wild_more_files/meta.csv')

# %%
Df_eval_all_parts_with_labels
# Out:
#             file                speaker      label
# 0          0.wav          Alec Guinness      spoof
# 1          1.wav          Alec Guinness      spoof
# 2          2.wav           Barack Obama      spoof
# 3          3.wav          Alec Guinness      spoof
# 4          4.wav   Christopher Hitchens  bona-fide
# ...          ...                    ...        ...
# 31774  31774.wav          Boris Johnson  bona-fide
# 31775  31775.wav           Donald Trump  bona-fide
# 31776  31776.wav           Donald Trump  bona-fide
# 31777  31777.wav             Alan Watts  bona-fide
# 31778  31778.wav  Arnold Schwarzenegger      spoof
#
# [31779 rows x 3 columns]

# %%
Df_eval_all_parts_with_labels = Df_eval_all_parts_with_labels.rename(columns={'file': 'audio_filenames'})

# %%
Df_eval_all_parts_with_labels
# Out:
#       audio_filenames                speaker      label
# 0               0.wav          Alec Guinness      spoof
# 1               1.wav          Alec Guinness      spoof
# 2               2.wav           Barack Obama      spoof
# 3               3.wav          Alec Guinness      spoof
# 4               4.wav   Christopher Hitchens  bona-fide
# ...               ...                    ...        ...
# 31774       31774.wav          Boris Johnson  bona-fide
# 31775       31775.wav           Donald Trump  bona-fide
# 31776       31776.wav           Donald Trump  bona-fide
# 31777       31777.wav             Alan Watts  bona-fide
# 31778       31778.wav  Arnold Schwarzenegger      spoof
#
# [31779 rows x 3 columns]

# %%
y_train
# Out:
#         audio_filenames
# 0     T_0000000000.flac
# 1     T_0000000001.flac
# 2     T_0000000002.flac
# 3     T_0000000003.flac
# 4     T_0000000004.flac
# ...                 ...
# 6996  T_0000006996.flac
# 6997  T_0000006997.flac
# 6998  T_0000006998.flac
# 6999  T_0000006999.flac
# 7000  T_0000007000.flac
#
# [7001 rows x 1 columns]

# %%
#y_train['audio_filenames'] = y_train['audio_filenames'].str.replace('.flac', '', regex=False)

# 2. Rename 'FileName' column to 'audio_filenames' in Df_train_with_labels
#Df_train_with_labels = Df_train_with_labels.rename(columns={0: 'audio_filenames'})
#Df_train_with_labels = Df_train_with_labels.rename(columns={7: 'Label'})

# %%
Df_train_with_labels = Df_train_with_labels.rename(columns={0: 'audio_filenames'})

# %%
Df_train_with_labels
# Out:
#           audio_filenames  1  2  3  4    5         6         7  8
# 0       T_0000000000.flac  F  -  -  -  AC3       A05     spoof  -
# 1       T_0000000001.flac  M  -  -  -  AC3       A07     spoof  -
# 2       T_0000000002.flac  M  -  -  -  AC2       A04     spoof  -
# 3       T_0000000003.flac  M  -  -  -  AC2       A08     spoof  -
# 4       T_0000000004.flac  M  -  -  -  AC2       A05     spoof  -
# ...                   ... .. .. .. ..  ...       ...       ... ..
# 182352  T_0000182352.flac  F  -  -  -  AC2       A03     spoof  -
# 182353  T_0000182353.flac  M  -  -  -  AC2       A05     spoof  -
# 182354  T_0000182354.flac  M  -  -  -  AC3       A02     spoof  -
# 182355  T_0000182355.flac  M  -  -  -    -  bonafide  bonafide  -
# 182356  T_0000182356.flac  M  -  -  -  AC2       A06     spoof  -
#
# [182357 rows x 9 columns]

# %%
Df_train_with_labels['audio_filenames'] = Df_train_with_labels['audio_filenames'].str.replace('.flac', '', regex=False)

# %%
Df_train_with_labels
# Out:
#        audio_filenames  1  2  3  4    5         6         7  8
# 0         T_0000000000  F  -  -  -  AC3       A05     spoof  -
# 1         T_0000000001  M  -  -  -  AC3       A07     spoof  -
# 2         T_0000000002  M  -  -  -  AC2       A04     spoof  -
# 3         T_0000000003  M  -  -  -  AC2       A08     spoof  -
# 4         T_0000000004  M  -  -  -  AC2       A05     spoof  -
# ...                ... .. .. .. ..  ...       ...       ... ..
# 182352    T_0000182352  F  -  -  -  AC2       A03     spoof  -
# 182353    T_0000182353  M  -  -  -  AC2       A05     spoof  -
# 182354    T_0000182354  M  -  -  -  AC3       A02     spoof  -
# 182355    T_0000182355  M  -  -  -    -  bonafide  bonafide  -
# 182356    T_0000182356  M  -  -  -  AC2       A06     spoof  -
#
# [182357 rows x 9 columns]

# %%
Df_train_with_labels = Df_train_with_labels.rename(columns={7: 'Label'})

# %%
Df_eval_all_parts_with_labels['audio_filenames'] = Df_eval_all_parts_with_labels['audio_filenames'].str.replace('.wav', '', regex=False)

# %%
y_train['audio_filenames'] = y_train['audio_filenames'].str.replace('.flac', '', regex=False)

# %%
Df_train_with_labels
# Out:
#        audio_filenames  1  2  3  4    5         6     Label  8
# 0         T_0000000000  F  -  -  -  AC3       A05     spoof  -
# 1         T_0000000001  M  -  -  -  AC3       A07     spoof  -
# 2         T_0000000002  M  -  -  -  AC2       A04     spoof  -
# 3         T_0000000003  M  -  -  -  AC2       A08     spoof  -
# 4         T_0000000004  M  -  -  -  AC2       A05     spoof  -
# ...                ... .. .. .. ..  ...       ...       ... ..
# 182352    T_0000182352  F  -  -  -  AC2       A03     spoof  -
# 182353    T_0000182353  M  -  -  -  AC2       A05     spoof  -
# 182354    T_0000182354  M  -  -  -  AC3       A02     spoof  -
# 182355    T_0000182355  M  -  -  -    -  bonafide  bonafide  -
# 182356    T_0000182356  M  -  -  -  AC2       A06     spoof  -
#
# [182357 rows x 9 columns]

# %%
# 3. Merge the two dataframes based on 'audio_filenames', keeping y_train's order
y_train_new = y_train.merge(Df_train_with_labels[['audio_filenames', 'Label']], 
                            on='audio_filenames', 
                            how='left')

# %%
y_train_new
# Out:
#      audio_filenames     Label
# 0       T_0000000000     spoof
# 1       T_0000000001     spoof
# 2       T_0000000002     spoof
# 3       T_0000000003     spoof
# 4       T_0000000004     spoof
# ...              ...       ...
# 6996    T_0000006996     spoof
# 6997    T_0000006997     spoof
# 6998    T_0000006998  bonafide
# 6999    T_0000006999     spoof
# 7000    T_0000007000     spoof
#
# [7001 rows x 2 columns]

# %%
null_count = y_train_new['Label'].isnull().sum()

print(f"Number of missing 'Label' values in y_train_new: {null_count}")
# Out:
# Number of missing 'Label' values in y_train_new: 0

# %%
y_test
# Out:
#       audio_filenames
# 0               0.wav
# 1               1.wav
# 2              10.wav
# 3             100.wav
# 4            1000.wav
# ...               ...
# 31772        9993.wav
# 31773        9994.wav
# 31774        9995.wav
# 31775        9996.wav
# 31776        9997.wav
#
# [31777 rows x 1 columns]

# %%
Df_eval_all_parts_with_labels
# Out:
#       audio_filenames                speaker      label
# 0                   0          Alec Guinness      spoof
# 1                   1          Alec Guinness      spoof
# 2                   2           Barack Obama      spoof
# 3                   3          Alec Guinness      spoof
# 4                   4   Christopher Hitchens  bona-fide
# ...               ...                    ...        ...
# 31774           31774          Boris Johnson  bona-fide
# 31775           31775           Donald Trump  bona-fide
# 31776           31776           Donald Trump  bona-fide
# 31777           31777             Alan Watts  bona-fide
# 31778           31778  Arnold Schwarzenegger      spoof
#
# [31779 rows x 3 columns]

# %%
y_test['audio_filenames'] = y_test['audio_filenames'].str.replace('.wav', '', regex=False)

# %%
# 2. Rename 'FileName' column to 'audio_filenames' in Df_train_with_labels
#Df_eval_all_parts_with_labels = Df_eval_all_parts_with_labels.rename(columns={1: 'audio_filenames'})
#Df_eval_all_parts_with_labels = Df_eval_all_parts_with_labels.rename(columns={8: 'Label'})

# %%
Df_eval_all_parts_with_labels
# Out:
#       audio_filenames                speaker      label
# 0                   0          Alec Guinness      spoof
# 1                   1          Alec Guinness      spoof
# 2                   2           Barack Obama      spoof
# 3                   3          Alec Guinness      spoof
# 4                   4   Christopher Hitchens  bona-fide
# ...               ...                    ...        ...
# 31774           31774          Boris Johnson  bona-fide
# 31775           31775           Donald Trump  bona-fide
# 31776           31776           Donald Trump  bona-fide
# 31777           31777             Alan Watts  bona-fide
# 31778           31778  Arnold Schwarzenegger      spoof
#
# [31779 rows x 3 columns]

# %%
y_test
# Out:
#       audio_filenames
# 0                   0
# 1                   1
# 2                  10
# 3                 100
# 4                1000
# ...               ...
# 31772            9993
# 31773            9994
# 31774            9995
# 31775            9996
# 31776            9997
#
# [31777 rows x 1 columns]

# %%
# 3. Merge the two dataframes based on 'audio_filenames', keeping y_train's order
y_test_new = y_test.merge(Df_eval_all_parts_with_labels[['audio_filenames', 'label']], 
                            on='audio_filenames', 
                            how='left')

# %%
y_test_new
# Out:
#       audio_filenames      label
# 0                   0      spoof
# 1                   1      spoof
# 2                  10      spoof
# 3                 100  bona-fide
# 4                1000  bona-fide
# ...               ...        ...
# 31772            9993      spoof
# 31773            9994  bona-fide
# 31774            9995      spoof
# 31775            9996  bona-fide
# 31776            9997      spoof
#
# [31777 rows x 2 columns]

# %%
# Check for null values in the 'Label' column
null_count = y_test_new['label'].isnull().sum()

print(f"Number of missing 'Label' values in y_test_new: {null_count}")
# Out:
# Number of missing 'Label' values in y_test_new: 0

# %%
y_train_new.to_csv('asvspoof5_DF_labels_corresponding_to_xlsr_7000_train_for_ITW.csv')

# %%
y_test_new.to_csv('ITW_labels_corresponding_to_xlsr.csv')

# %%
y_train = pd.read_csv('asvspoof5_DF_labels_corresponding_to_xlsr_7000_train_for_ITW.csv')

# %%
y_test = pd.read_csv('ITW_labels_corresponding_to_xlsr.csv')

# %%
len(y_test)
# Out:
# 31777

# %%
pwd
# Out:
# '/umbc/rs/iharp/users/zkhanja1/asvspoof5_codes_and_ITW'

# %%
X_test1 = np.load('/umbc/rs/iharp/users/zkhanja1/in_the_wild_more_files/xlsr_hidden_states_ITW_0to5000.npy')
X_test2=np.load('/umbc/rs/iharp/users/zkhanja1/in_the_wild_more_files/xlsr_hidden_states_ITW_5000to10000.npy')
X_test3 = np.load('/umbc/rs/iharp/users/zkhanja1/in_the_wild_more_files/xlsr_hidden_states_ITW_10000to15000.npy')
X_test4= np.load('/umbc/rs/iharp/users/zkhanja1/in_the_wild_more_files/xlsr_hidden_states_ITW_15000to20000.npy')
X_test5=np.load('/umbc/rs/iharp/users/zkhanja1/in_the_wild_more_files/xlsr_hidden_states_ITW_20000to25000.npy')
X_test6=np.load('/umbc/rs/iharp/users/zkhanja1/in_the_wild_more_files/xlsr_hidden_states_ITW_25000to31777.npy')
#X_test3 = np.load('/umbc/rs/iharp/users/zkhanja1/npy_files/HuBERT_hidden_states_df_eval_7000_4000to7000.npy')

# Concatenate them in order
X_test = np.concatenate((X_test1, X_test2, X_test3, X_test4, X_test5, X_test6), axis=0)

# Save X_test to a new .npy file if needed
# np.save('X_test.npy', X_test)

# %%
print(f"Shape of X_test: {X_test.shape}")
# Out:
# Shape of X_test: (31777, 549, 1024)

# %%
pd
# Out:
# <module 'pandas' from '/umbc/rs/iharp/users/zkhanja1/tensorflow_env/lib/python3.13/site-packages/pandas/__init__.py'>

# %%
#X_test2 = X_test[:7000]

# %%
#X_test2.shape

# %%
import numpy as np

# Load the .npy files for X_train
X_train1 = np.load('/umbc/rs/iharp/users/zkhanja1/asvspoof5/xlsr_hidden_states_df_flac_T_aa_asvspoof5_0to7000.npy')
#X_train2 = np.load('/umbc/rs/iharp/users/zkhanja1/asvspoof5/HuBERT_hidden_states_df_T_3001to7000.npy')
#X_train3 = np.load('/umbc/rs/iharp/users/zkhanja1/npy_files/HuBERT_hidden_states_df_train_7000_4000to7000.npy')

# Concatenate them in order


# Print the shape of X_train
#print(f"Shape of X_train: {X_train.shape}")

# %%
X_train = X_train1

# %%
print(f"Shape of X_train: {X_train.shape}")
# Out:
# Shape of X_train: (7001, 549, 1024)

# %%
y_train
# Out:
#      audio_filenames
# 0       T_0000000000
# 1       T_0000000001
# 2       T_0000000002
# 3       T_0000000003
# 4       T_0000000004
# ...              ...
# 6996    T_0000006996
# 6997    T_0000006997
# 6998    T_0000006998
# 6999    T_0000006999
# 7000    T_0000007000
#
# [7001 rows x 1 columns]

# %%
y_train_new = y_train
y_test_new = y_test

# %%
y_test
# Out:
#        Unnamed: 0  audio_filenames      label
# 0               0                0      spoof
# 1               1                1      spoof
# 2               2               10      spoof
# 3               3              100  bona-fide
# 4               4             1000  bona-fide
# ...           ...              ...        ...
# 31772       31772             9993      spoof
# 31773       31773             9994  bona-fide
# 31774       31774             9995      spoof
# 31775       31775             9996  bona-fide
# 31776       31776             9997      spoof
#
# [31777 rows x 3 columns]

# %%
# For y_train_new
y_train = y_train_new['Label'].map({'spoof': 1, 'bonafide': 0})
print(f"First few y_train values:\n{y_train.head()}")
# Out:
# First few y_train values:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: Label, dtype: int64

# %%
#y_test_new = Df_eval_all_parts_with_labels

# %%
# For y_test_new
y_test = y_test_new['label'].map({'spoof': 1, 'bona-fide': 0})
print(f"First few y_test values:\n{y_test.head()}")
# Out:
# First few y_test values:
# 0    1
# 1    1
# 2    1
# 3    0
# 4    0
# Name: label, dtype: int64

# %%
# Calculate the percentage of 1s in y_train
percentage_1_train = (y_train == 1).mean() * 100
print(f"Percentage of '1' (spoof) in y_train: {percentage_1_train:.2f}%")

# Calculate the percentage of 1s in y_test
percentage_1_test = (y_test == 1).mean() * 100
print(f"Percentage of '1' (spoof) in y_test: {percentage_1_test:.2f}%")
# Out:
# Percentage of '1' (spoof) in y_train: 89.36%
# Percentage of '1' (spoof) in y_test: 37.18%

# %%
# !pip install --upgrade scikit-learn
# !pip install --upgrade imbalanced-learn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 238.4/238.4 kB 5.4 MB/s eta 0:00:00:00:01
# ...

# %%
from imblearn.over_sampling import SMOTE

# First, ensure y_train is a numpy array if it's not already
y_train_np = y_train.values if hasattr(y_train, 'values') else y_train

# Apply SMOTE
smote = SMOTE(random_state=42)
X_train_resampled, y_train_resampled = smote.fit_resample(X_train.reshape(X_train.shape[0], -1), y_train_np)

# If needed, reshape X_train_resampled back to original dimensions
X_train_resampled = X_train_resampled.reshape(-1, X_train.shape[1], X_train.shape[2])

# Print new class distribution
print(f"Resampled class distribution:\n{pd.Series(y_train_resampled).value_counts()}")
# Out:
# Resampled class distribution:
# 1    6256
# 0    6256
# Name: count, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# Use 10% of the original X_train and y_train as validation
#X_train_sub, X_val, y_train_sub, y_val = train_test_split(
#    X_train, y_train, test_size=0.1, random_state=42, stratify=y_train
#)

# %%
from tensorflow.keras.metrics import AUC

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Flatten
from tensorflow.keras.optimizers import Adam

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Flatten
from tensorflow.keras.optimizers import Adam

# Flatten input shape for MLP
input_dim = X_train_resampled.shape[1] * X_train_resampled.shape[2]

model = Sequential([
    Flatten(input_shape=(X_train_resampled.shape[1], X_train_resampled.shape[2])),
    Dense(128, activation='relu'),
   # Dropout(0.5),
    Dense(64, activation='relu'),
    Dropout(0.6),
    Dense(1, activation='sigmoid')
])



model.compile(
    optimizer=Adam(learning_rate=0.001), 
    loss='binary_crossentropy', 
    metrics=[AUC(name='roc_auc')]
)

# %%
 X_train.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 X_train.shape
#
# NameError: name 'X_train' is not defined

# %%
X_train_resampled = np.squeeze(X_train_resampled, axis=1)
X_train = np.squeeze(X_train, axis=1)
X_test= np.squeeze(X_test, axis=1)

# %%
history = model.fit(
    X_train_resampled, y_train_resampled,
    validation_split=0.15,
    epochs=50,
    batch_size=32,
    callbacks=[early_stop]
)

# %%
# Get probabilities for original X_train and X_test
probs_train = model.predict(X_train)
probs_test = model.predict(X_test)

print(f"First 5 probabilities on X_train:\n{probs_train[:5].flatten()}")
print(f"First 5 probabilities on X_test:\n{probs_test[:5].flatten()}")
# Out:
# 215/219 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 2025-11-08 11:24:21.530211: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-11-08 11:24:21.530431: W external/local_xla/xla/service/gpu/autotuning/gemm_fusion_autotuner.cc:1008] Compiling 41 configs for 2 fusions on a single thread.
# 2025-11-08 11:24:23.116090: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_17', 292 bytes spill stores, 292 bytes spill loads
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 7s 30ms/step
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step
# First 5 probabilities on X_train:
# [1.         1.         0.99999475 0.99999905 0.9999999 ]
# First 5 probabilities on X_test:
# ...

# %%
len(X_test)
# Out:
# 6998

# %%
y_test
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 6994    1
# 6995    1
# 6996    1
# 6997    1
# 6998    1
# Name: Label, Length: 6999, dtype: int64

# %%
from sklearn.metrics import roc_auc_score

# Calculate ROC AUC for train
roc_auc_train = roc_auc_score(y_train, probs_train)
print(f"ROC AUC on training data: {roc_auc_train:.4f}")

# Calculate ROC AUC for test
roc_auc_test = roc_auc_score(y_test, probs_test)
print(f"ROC AUC on test data: {roc_auc_test:.4f}")
# Out:
# ROC AUC on training data: 0.9999
# ROC AUC on test data: 0.5221

# %%
probs_test
# Out:
# array([[1.],
#        [1.],
#        [1.],
#        ...,
#        [1.],
#        [1.],
#        [1.]], dtype=float32)

# %%
unique_values = np.unique(probs_test)
print(unique_values)
# Out:
# [1.11031072e-17 2.00934760e-17 2.14623806e-17 4.43134749e-17
#  5.05572129e-17 7.02908769e-17 1.31468513e-16 1.35873270e-16
#  1.71125524e-16 1.82784456e-16 2.15523934e-16 4.30567388e-16
#  7.05856801e-16 7.79204931e-16 8.32292933e-16 1.89700059e-15
#  2.68126839e-15 3.72783054e-15 5.09819856e-15 6.11127156e-15
#  6.21281684e-15 6.74631588e-15 9.07552943e-15 9.85488953e-15
#  1.01850689e-14 1.16200952e-14 1.28276042e-14 1.72563939e-14
#  2.13784170e-14 2.39920592e-14 2.64851092e-14 3.22754281e-14
#  3.86888634e-14 3.93316463e-14 4.71472328e-14 5.20464680e-14
#  6.03662086e-14 9.11360966e-14 1.12905690e-13 1.22601243e-13
#  1.94472436e-13 2.04327305e-13 2.14681585e-13 4.89311282e-13
#  7.03095243e-13 7.50997842e-13 1.02706808e-12 1.15262921e-12
#  1.17177915e-12 1.25160873e-12 1.31503142e-12 1.71170901e-12
#  1.76905181e-12 1.85869484e-12 1.88958267e-12 2.41936809e-12
#  2.67077332e-12 3.30874542e-12 3.36371079e-12 4.30682486e-12
# ...

# %%
count_under_ = np.sum(probs_test < 0.5)
print(count_under_)
# Out:
# 307

# %%
# Assuming X_train shape is (samples, time_steps, features)
X_train_resampled = np.expand_dims(X_train_resampled, axis=1)  # (samples, 1, time_steps, features)
#X_val = np.expand_dims(X_val, axis=1)
X_train = np.expand_dims(X_train, axis=1)
X_test = np.expand_dims(X_test, axis=1)

# %%
import tensorflow as tf
from tensorflow.keras import layers, models, regularizers

def build_resnet18(input_shape):
    inputs = layers.Input(shape=input_shape)
    x = layers.Conv2D(64, 7, strides=2, padding='same', use_bias=False)(inputs)
    x = layers.BatchNormalization()(x)
    x = layers.ReLU()(x)
    x = layers.MaxPooling2D(3, strides=2, padding='same')(x)

    def residual_block(x, filters, downsample=False):
        shortcut = x
        strides = 2 if downsample else 1
        x = layers.Conv2D(filters, 3, strides=strides, padding='same', use_bias=False,
                          kernel_regularizer=regularizers.l2(1e-4))(x)
        x = layers.BatchNormalization()(x)
        x = layers.ReLU()(x)
        x = layers.Conv2D(filters, 3, strides=1, padding='same', use_bias=False,
                          kernel_regularizer=regularizers.l2(1e-4))(x)
        x = layers.BatchNormalization()(x)

        if downsample or shortcut.shape[-1] != filters:
            shortcut = layers.Conv2D(filters, 1, strides=strides, padding='same', use_bias=False,
                                     kernel_regularizer=regularizers.l2(1e-4))(shortcut)
            shortcut = layers.BatchNormalization()(shortcut)

        x = layers.add([x, shortcut])
        x = layers.ReLU()(x)
        return x

    x = residual_block(x, 64)
    x = residual_block(x, 64)
    x = residual_block(x, 128, downsample=True)
    x = residual_block(x, 128)
    x = residual_block(x, 256, downsample=True)
    x = residual_block(x, 256)
    x = residual_block(x, 512, downsample=True)
    x = residual_block(x, 512)

    x = layers.GlobalAveragePooling2D()(x)
    outputs = layers.Dense(1, activation='sigmoid')(x)

    model = models.Model(inputs, outputs)
    return model

input_shape = X_train_resampled.shape[1:]  # (time_steps, features, 1)
resnet18_model = build_resnet18(input_shape)
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1768253488.617843  245765 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 43489 MB memory:  -> device: 0, name: NVIDIA L40S, pci bus id: 0000:4a:00.0, compute capability: 8.9

# %%
from tensorflow.keras.optimizers import Adam

resnet18_model.compile(
    optimizer=Adam(learning_rate=1e-4),
    loss='binary_crossentropy',
    metrics=[tf.keras.metrics.AUC(name='roc_auc')]
)

# %%
from tensorflow.keras.callbacks import EarlyStopping

# Define early stopping
early_stop = EarlyStopping(
    monitor='val_roc_auc',   # monitor validation AUC
    patience=5,              # stop if no improvement after 5 epochs
    mode='max',              # maximize AUC
    restore_best_weights=True  # restore the best model weights
)

# %%
history = resnet18_model.fit(
    X_train_resampled, y_train_resampled,
    validation_split=0.15,
    epochs=50,
    batch_size=32,
    callbacks=[early_stop]
)
# Out:
# Epoch 1/50
# 2026-01-12 16:32:10.530955: I external/local_xla/xla/service/service.cc:163] XLA service 0x152f040217c0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2026-01-12 16:32:10.530973: I external/local_xla/xla/service/service.cc:171]   StreamExecutor device (0): NVIDIA L40S, Compute Capability 8.9
# 2026-01-12 16:32:10.759268: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2026-01-12 16:32:12.214970: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:473] Loaded cuDNN version 91301
#   7/333 ━━━━━━━━━━━━━━━━━━━━ 7s 24ms/step - loss: 1.0271 - roc_auc: 0.8013
# I0000 00:00:1768253543.387334  337136 device_compiler.h:196] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# ...

# %%
# Save full model (recommended)
resnet18_model.save("resnet18_model_xlsr_trained_on_asvspoof5_7000samples.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
import tensorflow as tf
from tensorflow.keras.models import load_model

# %%
resnet18_model = load_model("resnet18_model_xlsr_trained_on_asvspoof5_7000samples.h5")
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1767974749.453494 2219546 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 47184 MB memory:  -> device: 0, name: Quadro RTX 8000, pci bus id: 0000:1c:00.0, compute capability: 7.5
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
X_train = np.squeeze(X_train, axis=1)
X_test = np.squeeze(X_test, axis=1)

# %%
probs_train = resnet18_model.predict(X_train)
# Out:
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step

# %%
print(type(X_test))
print(X_test.dtype)
print(X_test.nbytes / 1024**3, "GB")

# %%
import numpy as np

batch_size = 8
probs_list = []

for i in range(0, len(X_test), batch_size):
    batch = X_test[i:i+batch_size]
    probs = resnet18_model.predict(batch, verbose=0)
    probs_list.append(probs)

probs_test = np.concatenate(probs_list, axis=0)

# %%
probs_test.shape
# Out:
# (31777, 1)

# %%
probs_train.shape
# Out:
# (7000, 1)

# %%
y_test.shape
# Out:
# (7000,)

# %%
probs_train
# Out:
# array([[1.0000000e+00],
#        [1.0000000e+00],
#        [1.0000000e+00],
#        ...,
#        [1.0000000e+00],
#        [1.0591374e-06],
#        [1.0000000e+00]], shape=(7000, 1), dtype=float32)

# %%
#y_test = y_test[:7000]

# %%
from sklearn.metrics import roc_auc_score

# Calculate ROC AUC for train
roc_auc_train = roc_auc_score(y_train, probs_train)
print(f"ROC AUC on training data: {roc_auc_train:.4f}")
# Out:
# ROC AUC on training data: 0.9491

# %%
#probs_test = resnet18_model.predict(X_test).flatten()

# %%
len(probs_test)

# %%
# Calculate ROC AUC for test
roc_auc_test = roc_auc_score(y_test, probs_test)
print(f"ROC AUC on test data: {roc_auc_test:.4f}")
# Out:
# ROC AUC on test data: 0.4701

# %%
df_train_preds = pd.DataFrame({
    'audio_filenames': y_train_new['audio_filenames'],  # or appropriate filenames list
    'prob_spoof': probs_train.flatten()
})

# %%
df_train_preds
# Out:
#      audio_filenames  prob_spoof
# 0       T_0000000000    0.692673
# 1       T_0000000001    0.757853
# 2       T_0000000002    0.689329
# 3       T_0000000003    0.723493
# 4       T_0000000004    0.676550
# ...              ...         ...
# 6996    T_0000006996    0.722816
# 6997    T_0000006997    0.529187
# 6998    T_0000006998    0.586431
# 6999    T_0000006999    0.839899
# 7000    T_0000007000    0.609588
#
# [7001 rows x 2 columns]

# %%
# Save train predictions
df_train_preds.to_csv('ITW_train_predictions_xlsr_resnet18_asvspoof5_as_train.csv', index=False)

# %%
count_under_ = np.sum(probs_test < 0.5)
print(count_under_)
# Out:
# 122

# %%
# Create DataFrame for test predictions
df_test_preds = pd.DataFrame({
    'audio_filenames': y_test_new['audio_filenames'],  # or appropriate filenames list
    'prob_spoof': probs_test.flatten()
})

# %%
df_test_preds
# Out:
#        audio_filenames  prob_spoof
# 0                    0    0.786643
# 1                    1    0.737604
# 2                   10    0.726019
# 3                  100    0.779081
# 4                 1000    0.829804
# ...                ...         ...
# 31772             9993    0.794828
# 31773             9994    0.771972
# 31774             9995    0.801221
# 31775             9996    0.798714
# 31776             9997    0.715364
#
# [31777 rows x 2 columns]

# %%
# Save test predictions
df_test_preds.to_csv('ITW_test_predictions_xlsr_resnet18.csv', index=False)
