# %%
import pandas as pd

# %%
pd
# Out:
# <module 'pandas' from '/umbc/rs/iharp/users/zkhanja1/tensorflow_env/lib/python3.13/site-packages/pandas/__init__.py'>

# %%
import tensorflow as tf
# Out:
# 2026-01-26 14:25:01.961406: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-01-26 14:25:07.632779: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 AVX512_FP16 AVX_VNNI AMX_TILE AMX_INT8 AMX_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-01-26 14:26:43.940730: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.

# %%
tf.__version__
# Out:
# '2.20.0'

# %%
import importlib.metadata
importlib.metadata.version("tensorflow")
# Out:
# '2.20.0'

# %%
import pkg_resources
[(p.project_name, p.version) for p in pkg_resources.working_set]
# Out:
# /tmp/ipykernel_1417070/2474053727.py:1: DeprecationWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html
#   import pkg_resources
# [('absl-py', '2.3.1'),
#  ('asttokens', '3.0.0'),
#  ('astunparse', '1.6.3'),
#  ('audioop-lts', '0.2.2'),
#  ('audioread', '3.0.1'),
#  ('certifi', '2025.10.5'),
#  ('cffi', '2.0.0'),
#  ('charset-normalizer', '3.4.3'),
#  ('comm', '0.2.1'),
#  ('contourpy', '1.3.3'),
#  ('cycler', '0.12.1'),
#  ('debugpy', '1.8.16'),
#  ('decorator', '5.2.1'),
#  ('et-xmlfile', '2.0.0'),
#  ('executing', '2.2.1'),
#  ('flatbuffers', '25.9.23'),
#  ('fonttools', '4.60.1'),
#  ('gast', '0.6.0'),
#  ('google-pasta', '0.2.0'),
#  ('grpcio', '1.75.1'),
#  ('h5py', '3.14.0'),
#  ('idna', '3.10'),
#  ('imbalanced-learn', '0.14.0'),
#  ('imblearn', '0.0'),
#  ('ipykernel', '6.30.1'),
#  ('ipython', '9.5.0'),
#  ('ipython-pygments-lexers', '1.1.1'),
#  ('jedi', '0.19.2'),
#  ('joblib', '1.5.2'),
#  ('jupyter-client', '8.6.3'),
#  ('jupyter-core', '5.8.1'),
#  ('keras', '3.11.3'),
#  ('kiwisolver', '1.4.9'),
#  ('lazy-loader', '0.4'),
#  ('libclang', '18.1.1'),
#  ('librosa', '0.11.0'),
#  ('llvmlite', '0.45.1'),
#  ('markdown', '3.9'),
#  ('markdown-it-py', '4.0.0'),
#  ('markupsafe', '3.0.3'),
#  ('matplotlib', '3.10.6'),
#  ('matplotlib-inline', '0.1.7'),
#  ('mdurl', '0.1.2'),
#  ('ml-dtypes', '0.5.3'),
#  ('msgpack', '1.1.1'),
#  ('namex', '0.1.0'),
#  ('nest-asyncio', '1.6.0'),
#  ('numba', '0.62.1'),
#  ('numpy', '2.3.3'),
#  ('nvidia-cublas-cu12', '12.9.1.4'),
#  ('nvidia-cuda-cupti-cu12', '12.9.79'),
#  ('nvidia-cuda-nvcc-cu12', '12.9.86'),
#  ('nvidia-cuda-nvrtc-cu12', '12.9.86'),
#  ('nvidia-cuda-runtime-cu12', '12.9.79'),
#  ('nvidia-cudnn-cu12', '9.13.1.26'),
#  ('nvidia-cufft-cu12', '11.4.1.4'),
#  ('nvidia-curand-cu12', '10.3.10.19'),
#  ('nvidia-cusolver-cu12', '11.7.5.82'),
#  ('nvidia-cusparse-cu12', '12.5.10.65'),
#  ('nvidia-nccl-cu12', '2.28.3'),
#  ('nvidia-nvjitlink-cu12', '12.9.86'),
#  ('openpyxl', '3.1.5'),
#  ('opt-einsum', '3.4.0'),
#  ('optree', '0.17.0'),
#  ('packaging', '25.0'),
#  ('pandas', '2.3.3'),
#  ('parso', '0.8.4'),
#  ('pexpect', '4.9.0'),
#  ('pillow', '11.3.0'),
#  ('pip', '25.2'),
#  ('platformdirs', '4.3.7'),
#  ('pooch', '1.8.2'),
#  ('prompt-toolkit', '3.0.43'),
#  ('protobuf', '6.32.1'),
#  ('psutil', '7.0.0'),
#  ('ptyprocess', '0.7.0'),
#  ('pure-eval', '0.2.3'),
#  ('pycparser', '2.23'),
#  ('pygments', '2.19.1'),
#  ('pyparsing', '3.2.5'),
#  ('python-dateutil', '2.9.0.post0'),
#  ('pytz', '2025.2'),
#  ('pyzmq', '27.1.0'),
#  ('requests', '2.32.5'),
#  ('resampy', '0.4.3'),
#  ('rich', '14.1.0'),
#  ('scikit-learn', '1.7.2'),
#  ('scipy', '1.16.2'),
#  ('setuptools', '78.1.1'),
#  ('six', '1.17.0'),
#  ('soundfile', '0.13.1'),
#  ('soxr', '1.0.0'),
#  ('stack-data', '0.6.3'),
#  ('standard-aifc', '3.13.0'),
#  ('standard-chunk', '3.13.0'),
#  ('standard-sunau', '3.13.0'),
#  ('tensorboard', '2.20.0'),
#  ('tensorboard-data-server', '0.7.2'),
#  ('tensorflow', '2.20.0'),
#  ('termcolor', '3.1.0'),
#  ('tf-slim', '1.1.0'),
#  ('threadpoolctl', '3.6.0'),
#  ('tornado', '6.5.1'),
#  ('traitlets', '5.14.3'),
#  ('typing-extensions', '4.15.0'),
#  ('tzdata', '2025.2'),
#  ('urllib3', '2.5.0'),
#  ('wcwidth', '0.2.13'),
#  ('werkzeug', '3.1.3'),
#  ('wheel', '0.45.1'),
#  ('wrapt', '1.17.3'),
#  ('autocommand', '2.2.2'),
#  ('backports.tarfile', '1.2.0'),
#  ('importlib-metadata', '8.0.0'),
#  ('inflect', '7.3.1'),
#  ('jaraco.collections', '5.1.0'),
#  ('jaraco.context', '5.3.0'),
#  ('jaraco.functools', '4.0.1'),
#  ('jaraco.text', '3.12.1'),
#  ('more-itertools', '10.3.0'),
#  ('tomli', '2.0.1'),
#  ('typeguard', '4.3.0'),
#  ('zipp', '3.19.2')]

# %%
for p in sorted(pkg_resources.working_set, key=lambda x: x.project_name.lower()):
    print(f"{p.project_name}=={p.version}")
# Out:
# absl-py==2.3.1
# asttokens==3.0.0
# astunparse==1.6.3
# audioop-lts==0.2.2
# audioread==3.0.1
# autocommand==2.2.2
# backports.tarfile==1.2.0
# certifi==2025.10.5
# cffi==2.0.0
# charset-normalizer==3.4.3
# comm==0.2.1
# contourpy==1.3.3
# cycler==0.12.1
# debugpy==1.8.16
# decorator==5.2.1
# et-xmlfile==2.0.0
# executing==2.2.1
# flatbuffers==25.9.23
# fonttools==4.60.1
# gast==0.6.0
# google-pasta==0.2.0
# grpcio==1.75.1
# h5py==3.14.0
# idna==3.10
# imbalanced-learn==0.14.0
# imblearn==0.0
# importlib-metadata==8.0.0
# inflect==7.3.1
# ipykernel==6.30.1
# ipython==9.5.0
# ipython-pygments-lexers==1.1.1
# jaraco.collections==5.1.0
# jaraco.context==5.3.0
# jaraco.functools==4.0.1
# jaraco.text==3.12.1
# jedi==0.19.2
# joblib==1.5.2
# jupyter-client==8.6.3
# jupyter-core==5.8.1
# keras==3.11.3
# kiwisolver==1.4.9
# lazy-loader==0.4
# libclang==18.1.1
# librosa==0.11.0
# llvmlite==0.45.1
# markdown==3.9
# markdown-it-py==4.0.0
# markupsafe==3.0.3
# matplotlib==3.10.6
# matplotlib-inline==0.1.7
# mdurl==0.1.2
# ml-dtypes==0.5.3
# more-itertools==10.3.0
# msgpack==1.1.1
# namex==0.1.0
# nest-asyncio==1.6.0
# numba==0.62.1
# numpy==2.3.3
# nvidia-cublas-cu12==12.9.1.4
# nvidia-cuda-cupti-cu12==12.9.79
# nvidia-cuda-nvcc-cu12==12.9.86
# nvidia-cuda-nvrtc-cu12==12.9.86
# nvidia-cuda-runtime-cu12==12.9.79
# nvidia-cudnn-cu12==9.13.1.26
# nvidia-cufft-cu12==11.4.1.4
# nvidia-curand-cu12==10.3.10.19
# nvidia-cusolver-cu12==11.7.5.82
# nvidia-cusparse-cu12==12.5.10.65
# nvidia-nccl-cu12==2.28.3
# nvidia-nvjitlink-cu12==12.9.86
# openpyxl==3.1.5
# opt-einsum==3.4.0
# optree==0.17.0
# packaging==25.0
# pandas==2.3.3
# parso==0.8.4
# pexpect==4.9.0
# pillow==11.3.0
# pip==25.2
# platformdirs==4.3.7
# pooch==1.8.2
# prompt-toolkit==3.0.43
# protobuf==6.32.1
# psutil==7.0.0
# ptyprocess==0.7.0
# pure-eval==0.2.3
# pycparser==2.23
# pygments==2.19.1
# pyparsing==3.2.5
# python-dateutil==2.9.0.post0
# pytz==2025.2
# pyzmq==27.1.0
# requests==2.32.5
# resampy==0.4.3
# rich==14.1.0
# scikit-learn==1.7.2
# scipy==1.16.2
# setuptools==78.1.1
# six==1.17.0
# soundfile==0.13.1
# soxr==1.0.0
# stack-data==0.6.3
# standard-aifc==3.13.0
# standard-chunk==3.13.0
# standard-sunau==3.13.0
# tensorboard==2.20.0
# tensorboard-data-server==0.7.2
# tensorflow==2.20.0
# termcolor==3.1.0
# tf-slim==1.1.0
# threadpoolctl==3.6.0
# tomli==2.0.1
# tornado==6.5.1
# traitlets==5.14.3
# typeguard==4.3.0
# typing-extensions==4.15.0
# tzdata==2025.2
# urllib3==2.5.0
# wcwidth==0.2.13
# werkzeug==3.1.3
# wheel==0.45.1
# wrapt==1.17.3
# zipp==3.19.2

# %%
pip install matplotlib
# Out:
# Collecting matplotlib
#   Downloading matplotlib-3.10.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.3.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.4 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.56.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (101 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.4.8-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (6.2 kB)
# Requirement already satisfied: numpy>=1.23 in /nfs/ada/vjaneja/users/zkhanja1/.conda/envs/myenv/lib/python3.10/site-packages (from matplotlib) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /nfs/ada/vjaneja/users/zkhanja1/.conda/envs/myenv/lib/python3.10/site-packages (from matplotlib) (24.1)
# Collecting pillow>=8 (from matplotlib)
#   Downloading pillow-11.1.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.1 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib)
#   Downloading pyparsing-3.2.1-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: python-dateutil>=2.7 in /nfs/ada/vjaneja/users/zkhanja1/.conda/envs/myenv/lib/python3.10/site-packages (from matplotlib) (2.9.0)
# Requirement already satisfied: six>=1.5 in /nfs/ada/vjaneja/users/zkhanja1/.conda/envs/myenv/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Downloading matplotlib-3.10.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 27.3 MB/s eta 0:00:00a 0:00:01
# Downloading contourpy-1.3.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (324 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.56.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 35.9 MB/s eta 0:00:00
# Downloading kiwisolver-1.4.8-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 34.2 MB/s eta 0:00:00
# Downloading pillow-11.1.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 37.2 MB/s eta 0:00:00
# Downloading pyparsing-3.2.1-py3-none-any.whl (107 kB)
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.3.1 cycler-0.12.1 fonttools-4.56.0 kiwisolver-1.4.8 matplotlib-3.10.1 pillow-11.1.0 pyparsing-3.2.1
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install -U scikit-learn scipy
# Out:
# Collecting scikit-learn
#   Downloading scikit_learn-1.6.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (18 kB)
# Collecting scipy
#   Downloading scipy-1.15.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# Requirement already satisfied: numpy>=1.19.5 in /nfs/ada/vjaneja/users/zkhanja1/.conda/envs/myenv/lib/python3.10/site-packages (from scikit-learn) (2.0.2)
# Collecting joblib>=1.2.0 (from scikit-learn)
#   Using cached joblib-1.4.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn)
#   Using cached threadpoolctl-3.5.0-py3-none-any.whl.metadata (13 kB)
# Downloading scikit_learn-1.6.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.5/13.5 MB 56.0 MB/s eta 0:00:00a 0:00:01
# Downloading scipy-1.15.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (37.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.6/37.6 MB 92.4 MB/s eta 0:00:00:00:0100:01
# Using cached joblib-1.4.2-py3-none-any.whl (301 kB)
# Using cached threadpoolctl-3.5.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, scipy, joblib, scikit-learn
# Successfully installed joblib-1.4.2 scikit-learn-1.6.1 scipy-1.15.2 threadpoolctl-3.5.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install librosa
# Out:
# Collecting librosa
#   Using cached librosa-0.10.2.post1-py3-none-any.whl.metadata (8.6 kB)
# Collecting audioread>=2.1.9 (from librosa)
#   Using cached audioread-3.0.1-py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: numpy!=1.22.0,!=1.22.1,!=1.22.2,>=1.20.3 in /nfs/ada/vjaneja/users/zkhanja1/.conda/envs/myenv/lib/python3.10/site-packages (from librosa) (2.0.2)
# Requirement already satisfied: scipy>=1.2.0 in /nfs/ada/vjaneja/users/zkhanja1/.conda/envs/myenv/lib/python3.10/site-packages (from librosa) (1.15.2)
# Requirement already satisfied: scikit-learn>=0.20.0 in /nfs/ada/vjaneja/users/zkhanja1/.conda/envs/myenv/lib/python3.10/site-packages (from librosa) (1.6.1)
# Requirement already satisfied: joblib>=0.14 in /nfs/ada/vjaneja/users/zkhanja1/.conda/envs/myenv/lib/python3.10/site-packages (from librosa) (1.4.2)
# Requirement already satisfied: decorator>=4.3.0 in /nfs/ada/vjaneja/users/zkhanja1/.conda/envs/myenv/lib/python3.10/site-packages (from librosa) (5.1.1)
# Collecting numba>=0.51.0 (from librosa)
#   Downloading numba-0.61.0-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.8 kB)
# Collecting soundfile>=0.12.1 (from librosa)
#   Using cached soundfile-0.13.1-py2.py3-none-any.whl.metadata (16 kB)
# Collecting pooch>=1.1 (from librosa)
#   Using cached pooch-1.8.2-py3-none-any.whl.metadata (10 kB)
# Collecting soxr>=0.3.2 (from librosa)
#   Downloading soxr-0.5.0.post1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.6 kB)
# Requirement already satisfied: typing-extensions>=4.1.1 in /nfs/ada/vjaneja/users/zkhanja1/.conda/envs/myenv/lib/python3.10/site-packages (from librosa) (4.12.2)
# Collecting lazy-loader>=0.1 (from librosa)
#   Using cached lazy_loader-0.4-py3-none-any.whl.metadata (7.6 kB)
# Collecting msgpack>=1.0 (from librosa)
#   Downloading msgpack-1.1.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (8.4 kB)
# Requirement already satisfied: packaging in /nfs/ada/vjaneja/users/zkhanja1/.conda/envs/myenv/lib/python3.10/site-packages (from lazy-loader>=0.1->librosa) (24.1)
# Collecting llvmlite<0.45,>=0.44.0dev0 (from numba>=0.51.0->librosa)
#   Downloading llvmlite-0.44.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.8 kB)
# Requirement already satisfied: platformdirs>=2.5.0 in /nfs/ada/vjaneja/users/zkhanja1/.conda/envs/myenv/lib/python3.10/site-packages (from pooch>=1.1->librosa) (4.3.6)
# Requirement already satisfied: requests>=2.19.0 in /nfs/ada/vjaneja/users/zkhanja1/.conda/envs/myenv/lib/python3.10/site-packages (from pooch>=1.1->librosa) (2.32.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /nfs/ada/vjaneja/users/zkhanja1/.conda/envs/myenv/lib/python3.10/site-packages (from scikit-learn>=0.20.0->librosa) (3.5.0)
# Collecting cffi>=1.0 (from soundfile>=0.12.1->librosa)
#   Downloading cffi-1.17.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting pycparser (from cffi>=1.0->soundfile>=0.12.1->librosa)
#   Using cached pycparser-2.22-py3-none-any.whl.metadata (943 bytes)
# Requirement already satisfied: charset-normalizer<4,>=2 in /nfs/ada/vjaneja/users/zkhanja1/.conda/envs/myenv/lib/python3.10/site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /nfs/ada/vjaneja/users/zkhanja1/.conda/envs/myenv/lib/python3.10/site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /nfs/ada/vjaneja/users/zkhanja1/.conda/envs/myenv/lib/python3.10/site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /nfs/ada/vjaneja/users/zkhanja1/.conda/envs/myenv/lib/python3.10/site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (2025.1.31)
# Using cached librosa-0.10.2.post1-py3-none-any.whl (260 kB)
# Using cached audioread-3.0.1-py3-none-any.whl (23 kB)
# Using cached lazy_loader-0.4-py3-none-any.whl (12 kB)
# Downloading msgpack-1.1.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (378 kB)
# Downloading numba-0.61.0-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (3.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 84.1 MB/s eta 0:00:00
# Using cached pooch-1.8.2-py3-none-any.whl (64 kB)
# Using cached soundfile-0.13.1-py2.py3-none-any.whl (25 kB)
# Downloading soxr-0.5.0.post1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (252 kB)
# Downloading cffi-1.17.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (446 kB)
# Downloading llvmlite-0.44.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (42.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.4/42.4 MB 95.0 MB/s eta 0:00:00:00:0100:01
# Using cached pycparser-2.22-py3-none-any.whl (117 kB)
# Installing collected packages: soxr, pycparser, msgpack, llvmlite, lazy-loader, audioread, pooch, numba, cffi, soundfile, librosa
# Successfully installed audioread-3.0.1 cffi-1.17.1 lazy-loader-0.4 librosa-0.10.2.post1 llvmlite-0.44.0 msgpack-1.1.0 numba-0.61.0 pooch-1.8.2 pycparser-2.22 soundfile-0.13.1 soxr-0.5.0.post1
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install resampy
# Out:
# Collecting resampy
#   Downloading resampy-0.4.3-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: numpy>=1.17 in /umbc/rs/iharp/users/zkhanja1/tensorflow_env/lib/python3.13/site-packages (from resampy) (2.3.3)
# Requirement already satisfied: numba>=0.53 in /umbc/rs/iharp/users/zkhanja1/tensorflow_env/lib/python3.13/site-packages (from resampy) (0.62.1)
# Requirement already satisfied: llvmlite<0.46,>=0.45.0dev0 in /umbc/rs/iharp/users/zkhanja1/tensorflow_env/lib/python3.13/site-packages (from numba>=0.53->resampy) (0.45.1)
# Downloading resampy-0.4.3-py3-none-any.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 14.3 MB/s  0:00:00 eta 0:00:01
# Installing collected packages: resampy
# Successfully installed resampy-0.4.3
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install tf_slim
# Out:
# Collecting tf_slim
#   Downloading tf_slim-1.1.0-py2.py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: absl-py>=0.2.2 in /umbc/rs/iharp/users/zkhanja1/tensorflow_env/lib/python3.13/site-packages (from tf_slim) (2.3.1)
# Downloading tf_slim-1.1.0-py2.py3-none-any.whl (352 kB)
# Installing collected packages: tf_slim
# Successfully installed tf_slim-1.1.0
# Note: you may need to restart the kernel to use updated packages.

# %%
from tensorflow.keras.models import Model
from tensorflow.keras import Input
from tensorflow.keras.layers import concatenate, Permute, Reshape
import os

# %%
import math
import glob
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential

# %%
#from tensorflow.keras.optimizers import Adam
from tensorflow.keras.optimizers.legacy import Adam
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.layers import LSTM,TimeDistributed
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.layers import BatchNormalization
from keras.layers import MaxPooling2D
from keras.layers import BatchNormalization
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.model_selection import StratifiedKFold
import numpy as np
import sklearn.metrics as metrics

# %%
import pandas as pd
import math
import numpy as np
#from numpy.lib.function_base import average
import os
import librosa
import librosa.display
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import normalize
import warnings
warnings.filterwarnings('ignore')
from sklearn.model_selection import train_test_split
import tensorflow
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras import models, layers
import tensorflow as tf
from matplotlib.pyplot import specgram
import glob

# %%
from sklearn.metrics import confusion_matrix
import IPython.display as ipd  # To play sound in the notebook
from sklearn.model_selection import train_test_split
import tensorflow.keras as keras
import sys
import warnings
# ignore warnings
if not sys.warnoptions:
    warnings.simplefilter("ignore")
warnings.filterwarnings("ignore", category=DeprecationWarning)
import json

from sklearn.preprocessing import normalize
import warnings
warnings.filterwarnings('ignore')

import pickle
import joblib
from tensorflow.keras import models, layers
import tensorflow as tf

# %%
pwd
# Out:
# '/umbc/rs/iharp/users/zkhanja1/asvspoof5_codes'

# %%
# !wget https://storage.googleapis.com/audioset/vggish_model.ckpt
# !wget https://storage.googleapis.com/audioset/vggish_pca_params.npz
# Out:
# --2025-11-10 07:28:26--  https://storage.googleapis.com/audioset/vggish_model.ckpt
# Resolving storage.googleapis.com (storage.googleapis.com)... 172.253.62.207, 142.251.167.207, 172.253.122.207, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|172.253.62.207|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 291108469 (278M) [application/octet-stream]
# Saving to: ‘vggish_model.ckpt’
#
# vggish_model.ckpt   100%[===================>] 277.62M  84.0MB/s    in 3.3s
#
# 2025-11-10 07:28:31 (84.0 MB/s) - ‘vggish_model.ckpt’ saved [291108469/291108469]
#
# --2025-11-10 07:28:31--  https://storage.googleapis.com/audioset/vggish_pca_params.npz
# Resolving storage.googleapis.com (storage.googleapis.com)... 142.251.163.207, 172.253.115.207, 142.251.167.207, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|142.251.163.207|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 73020 (71K) [application/octet-stream]
# Saving to: ‘vggish_pca_params.npz’
#
# vggish_pca_params.n 100%[===================>]  71.31K  --.-KB/s    in 0.009s
#
# 2025-11-10 07:28:31 (8.16 MB/s) - ‘vggish_pca_params.npz’ saved [73020/73020]

# %%
pwd
# Out:
# '/umbc/rs/iharp/users/zkhanja1/asvspoof5_codes'

# %%
# !git clone https://github.com/tensorflow/models.git
# Out:
# Cloning into 'models'...
# remote: Enumerating objects: 102855, done.
# remote: Counting objects: 100% (179/179), done.
# remote: Compressing objects: 100% (99/99), done.
# remote: Total 102855 (delta 136), reused 80 (delta 80), pack-reused 102676 (from 4)
# Receiving objects: 100% (102855/102855), 642.86 MiB | 64.23 MiB/s, done.
# Resolving deltas: 100% (74291/74291), done.
# Updating files: 100% (3960/3960), done.

# %%
pwd
# Out:
# '/umbc/rs/iharp/users/zkhanja1/asvspoof5_codes'

# %%
cd /umbc/rs/iharp/users/zkhanja1/asvspoof5_codes_and_ITW/models/research/audioset/vggish/
# Out:
# /umbc/rs/iharp/users/zkhanja1/asvspoof5_codes_and_ITW/models/research/audioset/vggish

# %%
import vggish_input
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 import vggish_input
#
# ModuleNotFoundError: No module named 'vggish_input'

# %%
import vggish_params
import vggish_postprocess
import vggish_slim
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 import vggish_params
#       2 import vggish_postprocess
#       3 import vggish_slim
#
# ModuleNotFoundError: No module named 'vggish_params'

# %%
print("Num GPUs Available:", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available: 1

# %%
print(tf.config.list_physical_devices('GPU'))
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# !nvidia-smi
# Out:
# Sat Mar 29 10:24:09 2025
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 530.30.02              Driver Version: 530.30.02    CUDA Version: 12.1     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                  Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf            Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Quadro RTX 6000                 On | 00000000:3D:00.0 Off |                  Off |
# | 33%   22C    P8               14W / 250W|  23553MiB / 24576MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |    0   N/A  N/A     45278      C   ...hanja1/.conda/envs/myenv/bin/python    23550MiB |
# +---------------------------------------------------------------------------------------+

# %%
# !pip3 list | grep tensorflow
# Out:
# tensorflow                        2.19.0
# tensorflow-io-gcs-filesystem      0.37.1

# %%
import tensorflow as tf

# Get all GPUs
gpus = tf.config.list_physical_devices('GPU')

if len(gpus) > 1:
    # Only use GPU 0, hide GPU 1
    tf.config.experimental.set_visible_devices(gpus[0], 'GPU')

print("Available GPUs after filtering:", tf.config.list_physical_devices('GPU'))
# Out:
# Available GPUs after filtering: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
print(tf.__version__)
# Out:
# 2.18.0

# %%
gpus = tf.config.list_physical_devices('GPU')
print("Available GPUs:", gpus)

if gpus:
    try:
        tf.config.set_visible_devices(gpus[0], 'GPU')
        tf.config.experimental.set_memory_growth(gpus[0], True)  # Avoid full memory allocation
        print("Using GPU:", gpus[0])
    except RuntimeError as e:
        print(e)
# Out:
# Available GPUs: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# Using GPU: PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')

# %%
tf.debugging.set_log_device_placement(True)

# %%
tf
# Out:
# <module 'tensorflow' from '/home/zkhanja1/.conda/envs/myenv/lib/python3.10/site-packages/tensorflow/__init__.py'>

# %%
import tensorflow as tf
import librosa
import os
import vggish_input
import vggish_params

# %%
import vggish_slim

# %%
cd /umbc/rs/iharp/users/zkhanja1/asvspoof5_codes_and_ITW
# Out:
# /umbc/rs/iharp/users/zkhanja1/asvspoof5_codes_and_ITW

# %% [markdown]
# #Pad shorter clips with zeros to match the maximum number of frames
# max_frames = max(features.shape[0] for features in vggish_features_list)
# vggish_features_list_padded = [np.pad(features, ((0, max_frames - features.shape[0]), (0, 0)), mode='constant') for features in vggish_features_list]
# vggish_features_array = np.stack(vggish_features_list_padded, axis=0)
# #Save extracted features and metadata
# np.save('/umbc/rs/iharp/users/zkhanja1/asvspoof5_codes/asvspoof5_vggish_features_array_train.npy', vggish_features_array)
# #df.to_csv('/nfs/rs/vjaneja/users/zkhanja1/audio_file_info_train.csv', index=False)
#
# print("Feature extraction complete. Files saved.")

# %%
#len(vggish_features_array)
# Save extracted features and metadata
#np.save('asvspoof5_vggish_features_array_train2.npy', vggish_features_array)
#df.to_csv('/nfs/rs/vjaneja/users/zkhanja1/audio_file_info_train.csv', index=False)

#print("Feature extraction complete. Files saved.")

# %%
import numpy as np

# Load the saved .npy file
vggish_features_array_train = np.load('asvspoof5_vggish_features_array_train2.npy')

print("Loaded features shape:", vggish_features_array_train.shape)
# Out:
# Loaded features shape: (36500, 30, 128)

# %%
#vggish_features_array_eval = np.load('asvspoofvggish_features_array_eval.npy')

#print("Loaded features shape:", vggish_features_array_eval.shape)

# %%
vggish_features_array_train = vggish_features_array

# %%
#df.to_csv("asvspoof5_train_fTa_audio_file_names.csv", index=False)

# %%
pwd
# Out:
# '/umbc/rs/iharp/users/zkhanja1/asvspoof5_codes_and_ITW'

# %%
df_train = pd.read_csv("/umbc/rs/iharp/users/zkhanja1/asvspoof5_codes_and_ITW/asvspoof5_for_vggish_Df_train_with_labels.csv")

# %%
df_train
# Out:
#            FileName  Label
# 0      T_0000023804  spoof
# 1      T_0000009556  spoof
# 2      T_0000009135  spoof
# 3      T_0000024330  spoof
# 4      T_0000008809  spoof
# ...             ...    ...
# 36495  T_0000015302  spoof
# 36496  T_0000016337  spoof
# 36497  T_0000009424  spoof
# 36498  T_0000013754  spoof
# 36499  T_0000035000  spoof
#
# [36500 rows x 2 columns]

# %%
df_test = pd.read_csv("/umbc/rs/iharp/users/zkhanja1/in_the_wild_more_files/meta.csv")

# %%
# ✅ Reset default graph before defining model
tf.compat.v1.reset_default_graph()

# %%
pwd
# Out:
# '/umbc/rs/iharp/users/zkhanja1/asvspoof5_codes_and_ITW'

# %%
audio_folder = '/umbc/rs/iharp/users/zkhanja1/release_in_the_wild'
tf.compat.v1.disable_eager_execution()
# Enable logging of device placement
tf.debugging.set_log_device_placement(True)

# Get a list of all .wav audio files
audio_files = [f for f in os.listdir(audio_folder) if f.endswith('.wav')]

# Initialize lists to store extracted features, paths, and file names
vggish_features_list = []
paths_list = []
file_names_list = []

# Load the VGGish model
sess = tf.compat.v1.Session()
with sess.as_default():
    vggish_slim.define_vggish_slim()
    vggish_saver = tf.compat.v1.train.Saver()
    vggish_saver.restore(sess, "vggish_model.ckpt")  # Ensure this file exists in your working directory

# Get VGGish input and output tensors
features_tensor = sess.graph.get_tensor_by_name(vggish_params.INPUT_TENSOR_NAME)
embedding_tensor = sess.graph.get_tensor_by_name(vggish_params.OUTPUT_TENSOR_NAME)

# Process each audio file
for audio_file in audio_files:
    audio_path = os.path.join(audio_folder, audio_file)

    # Convert .wav file into VGGish-compatible input
    example_wav_data = vggish_input.wavfile_to_examples(audio_path)

    # Run the model and extract embeddings
    vggish_features = sess.run(embedding_tensor, feed_dict={features_tensor: example_wav_data})

    # Store results
    vggish_features_list.append(vggish_features)
    paths_list.append(audio_path)
    file_names_list.append(audio_file)

max_frames = max(features.shape[0] for features in vggish_features_list)
vggish_features_list_padded = [np.pad(features, ((0, max_frames - features.shape[0]), (0, 0)), mode='constant') for features in vggish_features_list]
vggish_features_array = np.stack(vggish_features_list_padded, axis=0)


print("Feature extraction complete. Files saved.")

# Create a DataFrame with file metadata
df = pd.DataFrame({'Path': paths_list, 'FileName': file_names_list})
len(vggish_features_array)
# Save extracted features and metadata
np.save('ITW_vggish_features_array.npy', vggish_features_array)
df.to_csv('ITW_audio_file_info_VGGish.csv', index=False)

print("Feature extraction complete. Files saved.")
# Out:
# Device mapping:
# /job:localhost/replica:0/task:0/device:GPU:0 -> device: 0, name: NVIDIA L40S, pci bus id: 0000:4a:00.0, compute capability: 8.9
#
# INFO:tensorflow:Restoring parameters from vggish_model.ckpt
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1768257569.888030  315460 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 43489 MB memory:  -> device: 0, name: NVIDIA L40S, pci bus id: 0000:4a:00.0, compute capability: 8.9
# I0000 00:00:1768257569.985359  315460 mlir_graph_optimization_pass.cc:437] MLIR V1 optimization pass is not enabled
# 2026-01-12 17:39:29.990313: I tensorflow/core/common_runtime/placer.cc:162] vggish/Reshape: (Reshape): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.990380: I tensorflow/core/common_runtime/placer.cc:162] vggish/conv1/weights/Initializer/truncated_normal/TruncatedNormal: (TruncatedNormal): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.990396: I tensorflow/core/common_runtime/placer.cc:162] vggish/conv1/weights/Initializer/truncated_normal/mul: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.990406: I tensorflow/core/common_runtime/placer.cc:162] vggish/conv1/weights/Initializer/truncated_normal: (AddV2): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.990415: I tensorflow/core/common_runtime/placer.cc:162] vggish/conv1/weights/IsInitialized/VarIsInitializedOp: (VarIsInitializedOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.990426: I tensorflow/core/common_runtime/placer.cc:162] vggish/conv1/weights/Assign: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.990435: I tensorflow/core/common_runtime/placer.cc:162] vggish/conv1/weights/Read/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.990445: I tensorflow/core/common_runtime/placer.cc:162] vggish/conv1/biases/IsInitialized/VarIsInitializedOp: (VarIsInitializedOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.990457: I tensorflow/core/common_runtime/placer.cc:162] vggish/conv1/biases/Assign: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.990467: I tensorflow/core/common_runtime/placer.cc:162] vggish/conv1/biases/Read/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.990476: I tensorflow/core/common_runtime/placer.cc:162] vggish/conv1/Conv2D/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.990487: I tensorflow/core/common_runtime/placer.cc:162] vggish/conv1/Conv2D: (Conv2D): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.990495: I tensorflow/core/common_runtime/placer.cc:162] vggish/conv1/BiasAdd/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.990506: I tensorflow/core/common_runtime/placer.cc:162] vggish/conv1/BiasAdd: (BiasAdd): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.990515: I tensorflow/core/common_runtime/placer.cc:162] vggish/conv1/Relu: (Relu): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.990524: I tensorflow/core/common_runtime/placer.cc:162] vggish/pool1/MaxPool: (MaxPool): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.990533: I tensorflow/core/common_runtime/placer.cc:162] vggish/conv2/weights/Initializer/truncated_normal/TruncatedNormal: (TruncatedNormal): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.990542: I tensorflow/core/common_runtime/placer.cc:162] vggish/conv2/weights/Initializer/truncated_normal/mul: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.990552: I tensorflow/core/common_runtime/placer.cc:162] vggish/conv2/weights/Initializer/truncated_normal: (AddV2): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.990565: I tensorflow/core/common_runtime/placer.cc:162] vggish/conv2/weights/IsInitialized/VarIsInitializedOp: (VarIsInitializedOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.990573: I tensorflow/core/common_runtime/placer.cc:162] vggish/conv2/weights/Assign: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.990581: I tensorflow/core/common_runtime/placer.cc:162] vggish/conv2/weights/Read/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.990590: I tensorflow/core/common_runtime/placer.cc:162] vggish/conv2/biases/IsInitialized/VarIsInitializedOp: (VarIsInitializedOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.990600: I tensorflow/core/common_runtime/placer.cc:162] vggish/conv2/biases/Assign: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.990611: I tensorflow/core/common_runtime/placer.cc:162] vggish/conv2/biases/Read/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.990619: I tensorflow/core/common_runtime/placer.cc:162] vggish/conv2/Conv2D/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.990628: I tensorflow/core/common_runtime/placer.cc:162] vggish/conv2/Conv2D: (Conv2D): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.990636: I tensorflow/core/common_runtime/placer.cc:162] vggish/conv2/BiasAdd/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.990645: I tensorflow/core/common_runtime/placer.cc:162] vggish/conv2/BiasAdd: (BiasAdd): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.990654: I tensorflow/core/common_runtime/placer.cc:162] vggish/conv2/Relu: (Relu): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.990664: I tensorflow/core/common_runtime/placer.cc:162] vggish/pool2/MaxPool: (MaxPool): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.990674: I tensorflow/core/common_runtime/placer.cc:162] vggish/conv3/conv3_1/weights/Initializer/truncated_normal/TruncatedNormal: (TruncatedNormal): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.990683: I tensorflow/core/common_runtime/placer.cc:162] vggish/conv3/conv3_1/weights/Initializer/truncated_normal/mul: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.990691: I tensorflow/core/common_runtime/placer.cc:162] vggish/conv3/conv3_1/weights/Initializer/truncated_normal: (AddV2): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.990699: I tensorflow/core/common_runtime/placer.cc:162] vggish/conv3/conv3_1/weights/IsInitialized/VarIsInitializedOp: (VarIsInitializedOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.990707: I tensorflow/core/common_runtime/placer.cc:162] vggish/conv3/conv3_1/weights/Assign: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.990715: I tensorflow/core/common_runtime/placer.cc:162] vggish/conv3/conv3_1/weights/Read/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.990727: I tensorflow/core/common_runtime/placer.cc:162] vggish/conv3/conv3_1/biases/IsInitialized/VarIsInitializedOp: (VarIsInitializedOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.990739: I tensorflow/core/common_runtime/placer.cc:162] vggish/conv3/conv3_1/biases/Assign: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.990747: I tensorflow/core/common_runtime/placer.cc:162] vggish/conv3/conv3_1/biases/Read/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.990992: I tensorflow/core/common_runtime/placer.cc:162] vggish/conv3/conv3_1/Conv2D/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.991013: I tensorflow/core/common_runtime/placer.cc:162] vggish/conv3/conv3_1/Conv2D: (Conv2D): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.991026: I tensorflow/core/common_runtime/placer.cc:162] vggish/conv3/conv3_1/BiasAdd/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.991036: I tensorflow/core/common_runtime/placer.cc:162] vggish/conv3/conv3_1/BiasAdd: (BiasAdd): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.991047: I tensorflow/core/common_runtime/placer.cc:162] vggish/conv3/conv3_1/Relu: (Relu): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.991057: I tensorflow/core/common_runtime/placer.cc:162] vggish/conv3/conv3_2/weights/Initializer/truncated_normal/TruncatedNormal: (TruncatedNormal): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.991066: I tensorflow/core/common_runtime/placer.cc:162] vggish/conv3/conv3_2/weights/Initializer/truncated_normal/mul: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.991075: I tensorflow/core/common_runtime/placer.cc:162] vggish/conv3/conv3_2/weights/Initializer/truncated_normal: (AddV2): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.991083: I tensorflow/core/common_runtime/placer.cc:162] vggish/conv3/conv3_2/weights/IsInitialized/VarIsInitializedOp: (VarIsInitializedOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.991101: I tensorflow/core/common_runtime/placer.cc:162] vggish/conv3/conv3_2/weights/Assign: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.991115: I tensorflow/core/common_runtime/placer.cc:162] vggish/conv3/conv3_2/weights/Read/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.991127: I tensorflow/core/common_runtime/placer.cc:162] vggish/conv3/conv3_2/biases/IsInitialized/VarIsInitializedOp: (VarIsInitializedOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.991137: I tensorflow/core/common_runtime/placer.cc:162] vggish/conv3/conv3_2/biases/Assign: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.991145: I tensorflow/core/common_runtime/placer.cc:162] vggish/conv3/conv3_2/biases/Read/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.991156: I tensorflow/core/common_runtime/placer.cc:162] vggish/conv3/conv3_2/Conv2D/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.991164: I tensorflow/core/common_runtime/placer.cc:162] vggish/conv3/conv3_2/Conv2D: (Conv2D): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.991172: I tensorflow/core/common_runtime/placer.cc:162] vggish/conv3/conv3_2/BiasAdd/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.991181: I tensorflow/core/common_runtime/placer.cc:162] vggish/conv3/conv3_2/BiasAdd: (BiasAdd): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.991190: I tensorflow/core/common_runtime/placer.cc:162] vggish/conv3/conv3_2/Relu: (Relu): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.991199: I tensorflow/core/common_runtime/placer.cc:162] vggish/pool3/MaxPool: (MaxPool): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.991208: I tensorflow/core/common_runtime/placer.cc:162] vggish/conv4/conv4_1/weights/Initializer/truncated_normal/TruncatedNormal: (TruncatedNormal): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.991217: I tensorflow/core/common_runtime/placer.cc:162] vggish/conv4/conv4_1/weights/Initializer/truncated_normal/mul: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.991225: I tensorflow/core/common_runtime/placer.cc:162] vggish/conv4/conv4_1/weights/Initializer/truncated_normal: (AddV2): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.991233: I tensorflow/core/common_runtime/placer.cc:162] vggish/conv4/conv4_1/weights/IsInitialized/VarIsInitializedOp: (VarIsInitializedOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.991243: I tensorflow/core/common_runtime/placer.cc:162] vggish/conv4/conv4_1/weights/Assign: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.991251: I tensorflow/core/common_runtime/placer.cc:162] vggish/conv4/conv4_1/weights/Read/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.991260: I tensorflow/core/common_runtime/placer.cc:162] vggish/conv4/conv4_1/biases/IsInitialized/VarIsInitializedOp: (VarIsInitializedOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.991268: I tensorflow/core/common_runtime/placer.cc:162] vggish/conv4/conv4_1/biases/Assign: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.991277: I tensorflow/core/common_runtime/placer.cc:162] vggish/conv4/conv4_1/biases/Read/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.991285: I tensorflow/core/common_runtime/placer.cc:162] vggish/conv4/conv4_1/Conv2D/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.991294: I tensorflow/core/common_runtime/placer.cc:162] vggish/conv4/conv4_1/Conv2D: (Conv2D): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.991302: I tensorflow/core/common_runtime/placer.cc:162] vggish/conv4/conv4_1/BiasAdd/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.991311: I tensorflow/core/common_runtime/placer.cc:162] vggish/conv4/conv4_1/BiasAdd: (BiasAdd): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.991321: I tensorflow/core/common_runtime/placer.cc:162] vggish/conv4/conv4_1/Relu: (Relu): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.991330: I tensorflow/core/common_runtime/placer.cc:162] vggish/conv4/conv4_2/weights/Initializer/truncated_normal/TruncatedNormal: (TruncatedNormal): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.991339: I tensorflow/core/common_runtime/placer.cc:162] vggish/conv4/conv4_2/weights/Initializer/truncated_normal/mul: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.991348: I tensorflow/core/common_runtime/placer.cc:162] vggish/conv4/conv4_2/weights/Initializer/truncated_normal: (AddV2): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.991357: I tensorflow/core/common_runtime/placer.cc:162] vggish/conv4/conv4_2/weights/IsInitialized/VarIsInitializedOp: (VarIsInitializedOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.991367: I tensorflow/core/common_runtime/placer.cc:162] vggish/conv4/conv4_2/weights/Assign: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.991375: I tensorflow/core/common_runtime/placer.cc:162] vggish/conv4/conv4_2/weights/Read/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.991384: I tensorflow/core/common_runtime/placer.cc:162] vggish/conv4/conv4_2/biases/IsInitialized/VarIsInitializedOp: (VarIsInitializedOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.991392: I tensorflow/core/common_runtime/placer.cc:162] vggish/conv4/conv4_2/biases/Assign: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.991400: I tensorflow/core/common_runtime/placer.cc:162] vggish/conv4/conv4_2/biases/Read/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.991408: I tensorflow/core/common_runtime/placer.cc:162] vggish/conv4/conv4_2/Conv2D/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.991417: I tensorflow/core/common_runtime/placer.cc:162] vggish/conv4/conv4_2/Conv2D: (Conv2D): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.991425: I tensorflow/core/common_runtime/placer.cc:162] vggish/conv4/conv4_2/BiasAdd/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.991435: I tensorflow/core/common_runtime/placer.cc:162] vggish/conv4/conv4_2/BiasAdd: (BiasAdd): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.991443: I tensorflow/core/common_runtime/placer.cc:162] vggish/conv4/conv4_2/Relu: (Relu): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.991452: I tensorflow/core/common_runtime/placer.cc:162] vggish/pool4/MaxPool: (MaxPool): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.991461: I tensorflow/core/common_runtime/placer.cc:162] vggish/Flatten/flatten/Reshape: (Reshape): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.991469: I tensorflow/core/common_runtime/placer.cc:162] vggish/fc1/fc1_1/weights/Initializer/truncated_normal/TruncatedNormal: (TruncatedNormal): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.991478: I tensorflow/core/common_runtime/placer.cc:162] vggish/fc1/fc1_1/weights/Initializer/truncated_normal/mul: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.991486: I tensorflow/core/common_runtime/placer.cc:162] vggish/fc1/fc1_1/weights/Initializer/truncated_normal: (AddV2): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.991494: I tensorflow/core/common_runtime/placer.cc:162] vggish/fc1/fc1_1/weights/IsInitialized/VarIsInitializedOp: (VarIsInitializedOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.991502: I tensorflow/core/common_runtime/placer.cc:162] vggish/fc1/fc1_1/weights/Assign: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.991510: I tensorflow/core/common_runtime/placer.cc:162] vggish/fc1/fc1_1/weights/Read/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.991519: I tensorflow/core/common_runtime/placer.cc:162] vggish/fc1/fc1_1/biases/Initializer/zeros: (Fill): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.991537: I tensorflow/core/common_runtime/placer.cc:162] vggish/fc1/fc1_1/biases/IsInitialized/VarIsInitializedOp: (VarIsInitializedOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.991546: I tensorflow/core/common_runtime/placer.cc:162] vggish/fc1/fc1_1/biases/Assign: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.991555: I tensorflow/core/common_runtime/placer.cc:162] vggish/fc1/fc1_1/biases/Read/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.991563: I tensorflow/core/common_runtime/placer.cc:162] vggish/fc1/fc1_1/MatMul/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.991571: I tensorflow/core/common_runtime/placer.cc:162] vggish/fc1/fc1_1/MatMul: (MatMul): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.991581: I tensorflow/core/common_runtime/placer.cc:162] vggish/fc1/fc1_1/BiasAdd/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.991590: I tensorflow/core/common_runtime/placer.cc:162] vggish/fc1/fc1_1/BiasAdd: (BiasAdd): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.991599: I tensorflow/core/common_runtime/placer.cc:162] vggish/fc1/fc1_1/Relu: (Relu): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.991608: I tensorflow/core/common_runtime/placer.cc:162] vggish/fc1/fc1_2/weights/Initializer/truncated_normal/TruncatedNormal: (TruncatedNormal): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.991617: I tensorflow/core/common_runtime/placer.cc:162] vggish/fc1/fc1_2/weights/Initializer/truncated_normal/mul: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.991625: I tensorflow/core/common_runtime/placer.cc:162] vggish/fc1/fc1_2/weights/Initializer/truncated_normal: (AddV2): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.991634: I tensorflow/core/common_runtime/placer.cc:162] vggish/fc1/fc1_2/weights/IsInitialized/VarIsInitializedOp: (VarIsInitializedOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.991643: I tensorflow/core/common_runtime/placer.cc:162] vggish/fc1/fc1_2/weights/Assign: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.991652: I tensorflow/core/common_runtime/placer.cc:162] vggish/fc1/fc1_2/weights/Read/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.991661: I tensorflow/core/common_runtime/placer.cc:162] vggish/fc1/fc1_2/biases/Initializer/zeros: (Fill): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.991669: I tensorflow/core/common_runtime/placer.cc:162] vggish/fc1/fc1_2/biases/IsInitialized/VarIsInitializedOp: (VarIsInitializedOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.991677: I tensorflow/core/common_runtime/placer.cc:162] vggish/fc1/fc1_2/biases/Assign: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.991685: I tensorflow/core/common_runtime/placer.cc:162] vggish/fc1/fc1_2/biases/Read/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.991694: I tensorflow/core/common_runtime/placer.cc:162] vggish/fc1/fc1_2/MatMul/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.991703: I tensorflow/core/common_runtime/placer.cc:162] vggish/fc1/fc1_2/MatMul: (MatMul): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.991712: I tensorflow/core/common_runtime/placer.cc:162] vggish/fc1/fc1_2/BiasAdd/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.991721: I tensorflow/core/common_runtime/placer.cc:162] vggish/fc1/fc1_2/BiasAdd: (BiasAdd): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.991730: I tensorflow/core/common_runtime/placer.cc:162] vggish/fc1/fc1_2/Relu: (Relu): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.991741: I tensorflow/core/common_runtime/placer.cc:162] vggish/fc2/weights/Initializer/truncated_normal/TruncatedNormal: (TruncatedNormal): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.991832: I tensorflow/core/common_runtime/placer.cc:162] vggish/fc2/weights/Initializer/truncated_normal/mul: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.991841: I tensorflow/core/common_runtime/placer.cc:162] vggish/fc2/weights/Initializer/truncated_normal: (AddV2): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.991856: I tensorflow/core/common_runtime/placer.cc:162] vggish/fc2/weights/IsInitialized/VarIsInitializedOp: (VarIsInitializedOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.991864: I tensorflow/core/common_runtime/placer.cc:162] vggish/fc2/weights/Assign: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.991872: I tensorflow/core/common_runtime/placer.cc:162] vggish/fc2/weights/Read/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.991881: I tensorflow/core/common_runtime/placer.cc:162] vggish/fc2/biases/IsInitialized/VarIsInitializedOp: (VarIsInitializedOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.991889: I tensorflow/core/common_runtime/placer.cc:162] vggish/fc2/biases/Assign: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.991897: I tensorflow/core/common_runtime/placer.cc:162] vggish/fc2/biases/Read/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.991905: I tensorflow/core/common_runtime/placer.cc:162] vggish/fc2/MatMul/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.991914: I tensorflow/core/common_runtime/placer.cc:162] vggish/fc2/MatMul: (MatMul): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.991922: I tensorflow/core/common_runtime/placer.cc:162] vggish/fc2/BiasAdd/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.991931: I tensorflow/core/common_runtime/placer.cc:162] vggish/fc2/BiasAdd: (BiasAdd): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.991940: I tensorflow/core/common_runtime/placer.cc:162] vggish/embedding: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.991949: I tensorflow/core/common_runtime/placer.cc:162] save/filename: (PlaceholderWithDefault): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.991958: I tensorflow/core/common_runtime/placer.cc:162] save/Const: (PlaceholderWithDefault): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.991967: I tensorflow/core/common_runtime/placer.cc:162] save/SaveV2: (SaveV2): /job:localhost/replica:0/task:0/device:CPU:0
# 2026-01-12 17:39:29.991976: I tensorflow/core/common_runtime/placer.cc:162] save/control_dependency: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.991986: I tensorflow/core/common_runtime/placer.cc:162] save/RestoreV2: (RestoreV2): /job:localhost/replica:0/task:0/device:CPU:0
# 2026-01-12 17:39:29.991995: I tensorflow/core/common_runtime/placer.cc:162] save/Identity: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.992003: I tensorflow/core/common_runtime/placer.cc:162] save/AssignVariableOp: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.992012: I tensorflow/core/common_runtime/placer.cc:162] save/Identity_1: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.992020: I tensorflow/core/common_runtime/placer.cc:162] save/AssignVariableOp_1: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.992028: I tensorflow/core/common_runtime/placer.cc:162] save/Identity_2: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.992036: I tensorflow/core/common_runtime/placer.cc:162] save/AssignVariableOp_2: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.992045: I tensorflow/core/common_runtime/placer.cc:162] save/Identity_3: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.992053: I tensorflow/core/common_runtime/placer.cc:162] save/AssignVariableOp_3: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.992061: I tensorflow/core/common_runtime/placer.cc:162] save/Identity_4: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.992069: I tensorflow/core/common_runtime/placer.cc:162] save/AssignVariableOp_4: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.992078: I tensorflow/core/common_runtime/placer.cc:162] save/Identity_5: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.992086: I tensorflow/core/common_runtime/placer.cc:162] save/AssignVariableOp_5: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.992095: I tensorflow/core/common_runtime/placer.cc:162] save/Identity_6: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.992106: I tensorflow/core/common_runtime/placer.cc:162] save/AssignVariableOp_6: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.992117: I tensorflow/core/common_runtime/placer.cc:162] save/Identity_7: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.992125: I tensorflow/core/common_runtime/placer.cc:162] save/AssignVariableOp_7: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.992134: I tensorflow/core/common_runtime/placer.cc:162] save/Identity_8: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.992142: I tensorflow/core/common_runtime/placer.cc:162] save/AssignVariableOp_8: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.992151: I tensorflow/core/common_runtime/placer.cc:162] save/Identity_9: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.992159: I tensorflow/core/common_runtime/placer.cc:162] save/AssignVariableOp_9: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.992170: I tensorflow/core/common_runtime/placer.cc:162] save/Identity_10: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.992178: I tensorflow/core/common_runtime/placer.cc:162] save/AssignVariableOp_10: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.992187: I tensorflow/core/common_runtime/placer.cc:162] save/Identity_11: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.992195: I tensorflow/core/common_runtime/placer.cc:162] save/AssignVariableOp_11: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.992204: I tensorflow/core/common_runtime/placer.cc:162] save/Identity_12: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.992242: I tensorflow/core/common_runtime/placer.cc:162] save/AssignVariableOp_12: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.992252: I tensorflow/core/common_runtime/placer.cc:162] save/Identity_13: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.992260: I tensorflow/core/common_runtime/placer.cc:162] save/AssignVariableOp_13: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.992269: I tensorflow/core/common_runtime/placer.cc:162] save/Identity_14: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.992277: I tensorflow/core/common_runtime/placer.cc:162] save/AssignVariableOp_14: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.992286: I tensorflow/core/common_runtime/placer.cc:162] save/Identity_15: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.992295: I tensorflow/core/common_runtime/placer.cc:162] save/AssignVariableOp_15: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.992304: I tensorflow/core/common_runtime/placer.cc:162] save/Identity_16: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.992312: I tensorflow/core/common_runtime/placer.cc:162] save/AssignVariableOp_16: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.992321: I tensorflow/core/common_runtime/placer.cc:162] save/Identity_17: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.992329: I tensorflow/core/common_runtime/placer.cc:162] save/AssignVariableOp_17: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.992338: I tensorflow/core/common_runtime/placer.cc:162] save/restore_all: (NoOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.992347: I tensorflow/core/common_runtime/placer.cc:162] vggish/input_features: (Placeholder): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.992356: I tensorflow/core/common_runtime/placer.cc:162] vggish/Reshape/shape: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.992365: I tensorflow/core/common_runtime/placer.cc:162] vggish/conv1/weights/Initializer/truncated_normal/shape: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.992373: I tensorflow/core/common_runtime/placer.cc:162] vggish/conv1/weights/Initializer/truncated_normal/mean: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.992381: I tensorflow/core/common_runtime/placer.cc:162] vggish/conv1/weights/Initializer/truncated_normal/stddev: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.992390: I tensorflow/core/common_runtime/placer.cc:162] vggish/conv1/weights: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.992398: I tensorflow/core/common_runtime/placer.cc:162] vggish/conv1/biases/Initializer/zeros: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.992406: I tensorflow/core/common_runtime/placer.cc:162] vggish/conv1/biases: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.992415: I tensorflow/core/common_runtime/placer.cc:162] vggish/conv2/weights/Initializer/truncated_normal/shape: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.992423: I tensorflow/core/common_runtime/placer.cc:162] vggish/conv2/weights/Initializer/truncated_normal/mean: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.992431: I tensorflow/core/common_runtime/placer.cc:162] vggish/conv2/weights/Initializer/truncated_normal/stddev: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.992439: I tensorflow/core/common_runtime/placer.cc:162] vggish/conv2/weights: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.992447: I tensorflow/core/common_runtime/placer.cc:162] vggish/conv2/biases/Initializer/zeros: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.992456: I tensorflow/core/common_runtime/placer.cc:162] vggish/conv2/biases: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.992463: I tensorflow/core/common_runtime/placer.cc:162] vggish/conv3/conv3_1/weights/Initializer/truncated_normal/shape: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.992471: I tensorflow/core/common_runtime/placer.cc:162] vggish/conv3/conv3_1/weights/Initializer/truncated_normal/mean: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.992480: I tensorflow/core/common_runtime/placer.cc:162] vggish/conv3/conv3_1/weights/Initializer/truncated_normal/stddev: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.992490: I tensorflow/core/common_runtime/placer.cc:162] vggish/conv3/conv3_1/weights: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.992498: I tensorflow/core/common_runtime/placer.cc:162] vggish/conv3/conv3_1/biases/Initializer/zeros: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.992508: I tensorflow/core/common_runtime/placer.cc:162] vggish/conv3/conv3_1/biases: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.992516: I tensorflow/core/common_runtime/placer.cc:162] vggish/conv3/conv3_2/weights/Initializer/truncated_normal/shape: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.992525: I tensorflow/core/common_runtime/placer.cc:162] vggish/conv3/conv3_2/weights/Initializer/truncated_normal/mean: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.992533: I tensorflow/core/common_runtime/placer.cc:162] vggish/conv3/conv3_2/weights/Initializer/truncated_normal/stddev: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.992541: I tensorflow/core/common_runtime/placer.cc:162] vggish/conv3/conv3_2/weights: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.992549: I tensorflow/core/common_runtime/placer.cc:162] vggish/conv3/conv3_2/biases/Initializer/zeros: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.992559: I tensorflow/core/common_runtime/placer.cc:162] vggish/conv3/conv3_2/biases: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.992567: I tensorflow/core/common_runtime/placer.cc:162] vggish/conv4/conv4_1/weights/Initializer/truncated_normal/shape: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.992575: I tensorflow/core/common_runtime/placer.cc:162] vggish/conv4/conv4_1/weights/Initializer/truncated_normal/mean: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.992583: I tensorflow/core/common_runtime/placer.cc:162] vggish/conv4/conv4_1/weights/Initializer/truncated_normal/stddev: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.992591: I tensorflow/core/common_runtime/placer.cc:162] vggish/conv4/conv4_1/weights: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.992599: I tensorflow/core/common_runtime/placer.cc:162] vggish/conv4/conv4_1/biases/Initializer/zeros: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.992647: I tensorflow/core/common_runtime/placer.cc:162] vggish/conv4/conv4_1/biases: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.992655: I tensorflow/core/common_runtime/placer.cc:162] vggish/conv4/conv4_2/weights/Initializer/truncated_normal/shape: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.992664: I tensorflow/core/common_runtime/placer.cc:162] vggish/conv4/conv4_2/weights/Initializer/truncated_normal/mean: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.992672: I tensorflow/core/common_runtime/placer.cc:162] vggish/conv4/conv4_2/weights/Initializer/truncated_normal/stddev: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.992680: I tensorflow/core/common_runtime/placer.cc:162] vggish/conv4/conv4_2/weights: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.992688: I tensorflow/core/common_runtime/placer.cc:162] vggish/conv4/conv4_2/biases/Initializer/zeros: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.992697: I tensorflow/core/common_runtime/placer.cc:162] vggish/conv4/conv4_2/biases: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.992705: I tensorflow/core/common_runtime/placer.cc:162] vggish/Flatten/flatten/Const: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.992713: I tensorflow/core/common_runtime/placer.cc:162] vggish/fc1/fc1_1/weights/Initializer/truncated_normal/shape: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.992721: I tensorflow/core/common_runtime/placer.cc:162] vggish/fc1/fc1_1/weights/Initializer/truncated_normal/mean: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.992729: I tensorflow/core/common_runtime/placer.cc:162] vggish/fc1/fc1_1/weights/Initializer/truncated_normal/stddev: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.992737: I tensorflow/core/common_runtime/placer.cc:162] vggish/fc1/fc1_1/weights: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.992748: I tensorflow/core/common_runtime/placer.cc:162] vggish/fc1/fc1_1/biases/Initializer/zeros/shape_as_tensor: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.992756: I tensorflow/core/common_runtime/placer.cc:162] vggish/fc1/fc1_1/biases/Initializer/zeros/Const: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.992764: I tensorflow/core/common_runtime/placer.cc:162] vggish/fc1/fc1_1/biases: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.992772: I tensorflow/core/common_runtime/placer.cc:162] vggish/fc1/fc1_2/weights/Initializer/truncated_normal/shape: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.992780: I tensorflow/core/common_runtime/placer.cc:162] vggish/fc1/fc1_2/weights/Initializer/truncated_normal/mean: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.992788: I tensorflow/core/common_runtime/placer.cc:162] vggish/fc1/fc1_2/weights/Initializer/truncated_normal/stddev: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.992796: I tensorflow/core/common_runtime/placer.cc:162] vggish/fc1/fc1_2/weights: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.992804: I tensorflow/core/common_runtime/placer.cc:162] vggish/fc1/fc1_2/biases/Initializer/zeros/shape_as_tensor: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.992812: I tensorflow/core/common_runtime/placer.cc:162] vggish/fc1/fc1_2/biases/Initializer/zeros/Const: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.992820: I tensorflow/core/common_runtime/placer.cc:162] vggish/fc1/fc1_2/biases: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.992829: I tensorflow/core/common_runtime/placer.cc:162] vggish/fc2/weights/Initializer/truncated_normal/shape: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.992838: I tensorflow/core/common_runtime/placer.cc:162] vggish/fc2/weights/Initializer/truncated_normal/mean: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.992846: I tensorflow/core/common_runtime/placer.cc:162] vggish/fc2/weights/Initializer/truncated_normal/stddev: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.992854: I tensorflow/core/common_runtime/placer.cc:162] vggish/fc2/weights: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.992862: I tensorflow/core/common_runtime/placer.cc:162] vggish/fc2/biases/Initializer/zeros: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.992870: I tensorflow/core/common_runtime/placer.cc:162] vggish/fc2/biases: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# 2026-01-12 17:39:29.992879: I tensorflow/core/common_runtime/placer.cc:162] save/filename/input: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2026-01-12 17:39:29.992887: I tensorflow/core/common_runtime/placer.cc:162] save/SaveV2/tensor_names: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2026-01-12 17:39:29.992896: I tensorflow/core/common_runtime/placer.cc:162] save/SaveV2/shape_and_slices: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2026-01-12 17:39:29.992905: I tensorflow/core/common_runtime/placer.cc:162] save/RestoreV2/tensor_names: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# 2026-01-12 17:39:29.992913: I tensorflow/core/common_runtime/placer.cc:162] save/RestoreV2/shape_and_slices: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# vggish/Reshape: (Reshape): /job:localhost/replica:0/task:0/device:GPU:0
# vggish/conv1/weights/Initializer/truncated_normal/TruncatedNormal: (TruncatedNormal): /job:localhost/replica:0/task:0/device:GPU:0
# vggish/conv1/weights/Initializer/truncated_normal/mul: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# vggish/conv1/weights/Initializer/truncated_normal: (AddV2): /job:localhost/replica:0/task:0/device:GPU:0
# vggish/conv1/weights/IsInitialized/VarIsInitializedOp: (VarIsInitializedOp): /job:localhost/replica:0/task:0/device:GPU:0
# vggish/conv1/weights/Assign: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# vggish/conv1/weights/Read/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# vggish/conv1/biases/IsInitialized/VarIsInitializedOp: (VarIsInitializedOp): /job:localhost/replica:0/task:0/device:GPU:0
# vggish/conv1/biases/Assign: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# vggish/conv1/biases/Read/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# vggish/conv1/Conv2D/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# vggish/conv1/Conv2D: (Conv2D): /job:localhost/replica:0/task:0/device:GPU:0
# vggish/conv1/BiasAdd/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# vggish/conv1/BiasAdd: (BiasAdd): /job:localhost/replica:0/task:0/device:GPU:0
# vggish/conv1/Relu: (Relu): /job:localhost/replica:0/task:0/device:GPU:0
# vggish/pool1/MaxPool: (MaxPool): /job:localhost/replica:0/task:0/device:GPU:0
# vggish/conv2/weights/Initializer/truncated_normal/TruncatedNormal: (TruncatedNormal): /job:localhost/replica:0/task:0/device:GPU:0
# vggish/conv2/weights/Initializer/truncated_normal/mul: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# vggish/conv2/weights/Initializer/truncated_normal: (AddV2): /job:localhost/replica:0/task:0/device:GPU:0
# vggish/conv2/weights/IsInitialized/VarIsInitializedOp: (VarIsInitializedOp): /job:localhost/replica:0/task:0/device:GPU:0
# vggish/conv2/weights/Assign: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# vggish/conv2/weights/Read/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# vggish/conv2/biases/IsInitialized/VarIsInitializedOp: (VarIsInitializedOp): /job:localhost/replica:0/task:0/device:GPU:0
# vggish/conv2/biases/Assign: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# vggish/conv2/biases/Read/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# vggish/conv2/Conv2D/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# vggish/conv2/Conv2D: (Conv2D): /job:localhost/replica:0/task:0/device:GPU:0
# vggish/conv2/BiasAdd/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# vggish/conv2/BiasAdd: (BiasAdd): /job:localhost/replica:0/task:0/device:GPU:0
# vggish/conv2/Relu: (Relu): /job:localhost/replica:0/task:0/device:GPU:0
# vggish/pool2/MaxPool: (MaxPool): /job:localhost/replica:0/task:0/device:GPU:0
# vggish/conv3/conv3_1/weights/Initializer/truncated_normal/TruncatedNormal: (TruncatedNormal): /job:localhost/replica:0/task:0/device:GPU:0
# vggish/conv3/conv3_1/weights/Initializer/truncated_normal/mul: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# vggish/conv3/conv3_1/weights/Initializer/truncated_normal: (AddV2): /job:localhost/replica:0/task:0/device:GPU:0
# vggish/conv3/conv3_1/weights/IsInitialized/VarIsInitializedOp: (VarIsInitializedOp): /job:localhost/replica:0/task:0/device:GPU:0
# vggish/conv3/conv3_1/weights/Assign: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# vggish/conv3/conv3_1/weights/Read/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# vggish/conv3/conv3_1/biases/IsInitialized/VarIsInitializedOp: (VarIsInitializedOp): /job:localhost/replica:0/task:0/device:GPU:0
# vggish/conv3/conv3_1/biases/Assign: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# vggish/conv3/conv3_1/biases/Read/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# vggish/conv3/conv3_1/Conv2D/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# vggish/conv3/conv3_1/Conv2D: (Conv2D): /job:localhost/replica:0/task:0/device:GPU:0
# vggish/conv3/conv3_1/BiasAdd/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# vggish/conv3/conv3_1/BiasAdd: (BiasAdd): /job:localhost/replica:0/task:0/device:GPU:0
# vggish/conv3/conv3_1/Relu: (Relu): /job:localhost/replica:0/task:0/device:GPU:0
# vggish/conv3/conv3_2/weights/Initializer/truncated_normal/TruncatedNormal: (TruncatedNormal): /job:localhost/replica:0/task:0/device:GPU:0
# vggish/conv3/conv3_2/weights/Initializer/truncated_normal/mul: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# vggish/conv3/conv3_2/weights/Initializer/truncated_normal: (AddV2): /job:localhost/replica:0/task:0/device:GPU:0
# vggish/conv3/conv3_2/weights/IsInitialized/VarIsInitializedOp: (VarIsInitializedOp): /job:localhost/replica:0/task:0/device:GPU:0
# vggish/conv3/conv3_2/weights/Assign: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# vggish/conv3/conv3_2/weights/Read/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# vggish/conv3/conv3_2/biases/IsInitialized/VarIsInitializedOp: (VarIsInitializedOp): /job:localhost/replica:0/task:0/device:GPU:0
# vggish/conv3/conv3_2/biases/Assign: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# vggish/conv3/conv3_2/biases/Read/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# vggish/conv3/conv3_2/Conv2D/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# vggish/conv3/conv3_2/Conv2D: (Conv2D): /job:localhost/replica:0/task:0/device:GPU:0
# vggish/conv3/conv3_2/BiasAdd/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# vggish/conv3/conv3_2/BiasAdd: (BiasAdd): /job:localhost/replica:0/task:0/device:GPU:0
# vggish/conv3/conv3_2/Relu: (Relu): /job:localhost/replica:0/task:0/device:GPU:0
# vggish/pool3/MaxPool: (MaxPool): /job:localhost/replica:0/task:0/device:GPU:0
# vggish/conv4/conv4_1/weights/Initializer/truncated_normal/TruncatedNormal: (TruncatedNormal): /job:localhost/replica:0/task:0/device:GPU:0
# vggish/conv4/conv4_1/weights/Initializer/truncated_normal/mul: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# vggish/conv4/conv4_1/weights/Initializer/truncated_normal: (AddV2): /job:localhost/replica:0/task:0/device:GPU:0
# vggish/conv4/conv4_1/weights/IsInitialized/VarIsInitializedOp: (VarIsInitializedOp): /job:localhost/replica:0/task:0/device:GPU:0
# vggish/conv4/conv4_1/weights/Assign: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# vggish/conv4/conv4_1/weights/Read/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# vggish/conv4/conv4_1/biases/IsInitialized/VarIsInitializedOp: (VarIsInitializedOp): /job:localhost/replica:0/task:0/device:GPU:0
# vggish/conv4/conv4_1/biases/Assign: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# vggish/conv4/conv4_1/biases/Read/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# vggish/conv4/conv4_1/Conv2D/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# vggish/conv4/conv4_1/Conv2D: (Conv2D): /job:localhost/replica:0/task:0/device:GPU:0
# vggish/conv4/conv4_1/BiasAdd/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# vggish/conv4/conv4_1/BiasAdd: (BiasAdd): /job:localhost/replica:0/task:0/device:GPU:0
# vggish/conv4/conv4_1/Relu: (Relu): /job:localhost/replica:0/task:0/device:GPU:0
# vggish/conv4/conv4_2/weights/Initializer/truncated_normal/TruncatedNormal: (TruncatedNormal): /job:localhost/replica:0/task:0/device:GPU:0
# vggish/conv4/conv4_2/weights/Initializer/truncated_normal/mul: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# vggish/conv4/conv4_2/weights/Initializer/truncated_normal: (AddV2): /job:localhost/replica:0/task:0/device:GPU:0
# vggish/conv4/conv4_2/weights/IsInitialized/VarIsInitializedOp: (VarIsInitializedOp): /job:localhost/replica:0/task:0/device:GPU:0
# vggish/conv4/conv4_2/weights/Assign: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# vggish/conv4/conv4_2/weights/Read/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# vggish/conv4/conv4_2/biases/IsInitialized/VarIsInitializedOp: (VarIsInitializedOp): /job:localhost/replica:0/task:0/device:GPU:0
# vggish/conv4/conv4_2/biases/Assign: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# vggish/conv4/conv4_2/biases/Read/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# vggish/conv4/conv4_2/Conv2D/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# vggish/conv4/conv4_2/Conv2D: (Conv2D): /job:localhost/replica:0/task:0/device:GPU:0
# vggish/conv4/conv4_2/BiasAdd/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# vggish/conv4/conv4_2/BiasAdd: (BiasAdd): /job:localhost/replica:0/task:0/device:GPU:0
# vggish/conv4/conv4_2/Relu: (Relu): /job:localhost/replica:0/task:0/device:GPU:0
# vggish/pool4/MaxPool: (MaxPool): /job:localhost/replica:0/task:0/device:GPU:0
# vggish/Flatten/flatten/Reshape: (Reshape): /job:localhost/replica:0/task:0/device:GPU:0
# vggish/fc1/fc1_1/weights/Initializer/truncated_normal/TruncatedNormal: (TruncatedNormal): /job:localhost/replica:0/task:0/device:GPU:0
# vggish/fc1/fc1_1/weights/Initializer/truncated_normal/mul: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# vggish/fc1/fc1_1/weights/Initializer/truncated_normal: (AddV2): /job:localhost/replica:0/task:0/device:GPU:0
# vggish/fc1/fc1_1/weights/IsInitialized/VarIsInitializedOp: (VarIsInitializedOp): /job:localhost/replica:0/task:0/device:GPU:0
# vggish/fc1/fc1_1/weights/Assign: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# vggish/fc1/fc1_1/weights/Read/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# vggish/fc1/fc1_1/biases/Initializer/zeros: (Fill): /job:localhost/replica:0/task:0/device:GPU:0
# vggish/fc1/fc1_1/biases/IsInitialized/VarIsInitializedOp: (VarIsInitializedOp): /job:localhost/replica:0/task:0/device:GPU:0
# vggish/fc1/fc1_1/biases/Assign: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# vggish/fc1/fc1_1/biases/Read/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# vggish/fc1/fc1_1/MatMul/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# vggish/fc1/fc1_1/MatMul: (MatMul): /job:localhost/replica:0/task:0/device:GPU:0
# vggish/fc1/fc1_1/BiasAdd/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# vggish/fc1/fc1_1/BiasAdd: (BiasAdd): /job:localhost/replica:0/task:0/device:GPU:0
# vggish/fc1/fc1_1/Relu: (Relu): /job:localhost/replica:0/task:0/device:GPU:0
# vggish/fc1/fc1_2/weights/Initializer/truncated_normal/TruncatedNormal: (TruncatedNormal): /job:localhost/replica:0/task:0/device:GPU:0
# vggish/fc1/fc1_2/weights/Initializer/truncated_normal/mul: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# vggish/fc1/fc1_2/weights/Initializer/truncated_normal: (AddV2): /job:localhost/replica:0/task:0/device:GPU:0
# vggish/fc1/fc1_2/weights/IsInitialized/VarIsInitializedOp: (VarIsInitializedOp): /job:localhost/replica:0/task:0/device:GPU:0
# vggish/fc1/fc1_2/weights/Assign: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# vggish/fc1/fc1_2/weights/Read/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# vggish/fc1/fc1_2/biases/Initializer/zeros: (Fill): /job:localhost/replica:0/task:0/device:GPU:0
# vggish/fc1/fc1_2/biases/IsInitialized/VarIsInitializedOp: (VarIsInitializedOp): /job:localhost/replica:0/task:0/device:GPU:0
# vggish/fc1/fc1_2/biases/Assign: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# vggish/fc1/fc1_2/biases/Read/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# vggish/fc1/fc1_2/MatMul/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# vggish/fc1/fc1_2/MatMul: (MatMul): /job:localhost/replica:0/task:0/device:GPU:0
# vggish/fc1/fc1_2/BiasAdd/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# vggish/fc1/fc1_2/BiasAdd: (BiasAdd): /job:localhost/replica:0/task:0/device:GPU:0
# vggish/fc1/fc1_2/Relu: (Relu): /job:localhost/replica:0/task:0/device:GPU:0
# vggish/fc2/weights/Initializer/truncated_normal/TruncatedNormal: (TruncatedNormal): /job:localhost/replica:0/task:0/device:GPU:0
# vggish/fc2/weights/Initializer/truncated_normal/mul: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# vggish/fc2/weights/Initializer/truncated_normal: (AddV2): /job:localhost/replica:0/task:0/device:GPU:0
# vggish/fc2/weights/IsInitialized/VarIsInitializedOp: (VarIsInitializedOp): /job:localhost/replica:0/task:0/device:GPU:0
# vggish/fc2/weights/Assign: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# vggish/fc2/weights/Read/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# vggish/fc2/biases/IsInitialized/VarIsInitializedOp: (VarIsInitializedOp): /job:localhost/replica:0/task:0/device:GPU:0
# vggish/fc2/biases/Assign: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# vggish/fc2/biases/Read/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# vggish/fc2/MatMul/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# vggish/fc2/MatMul: (MatMul): /job:localhost/replica:0/task:0/device:GPU:0
# vggish/fc2/BiasAdd/ReadVariableOp: (ReadVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# vggish/fc2/BiasAdd: (BiasAdd): /job:localhost/replica:0/task:0/device:GPU:0
# vggish/embedding: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# save/filename: (PlaceholderWithDefault): /job:localhost/replica:0/task:0/device:GPU:0
# save/Const: (PlaceholderWithDefault): /job:localhost/replica:0/task:0/device:GPU:0
# save/SaveV2: (SaveV2): /job:localhost/replica:0/task:0/device:CPU:0
# save/control_dependency: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# save/RestoreV2: (RestoreV2): /job:localhost/replica:0/task:0/device:CPU:0
# save/Identity: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# save/AssignVariableOp: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# save/Identity_1: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# save/AssignVariableOp_1: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# save/Identity_2: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# save/AssignVariableOp_2: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# save/Identity_3: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# save/AssignVariableOp_3: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# save/Identity_4: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# save/AssignVariableOp_4: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# save/Identity_5: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# save/AssignVariableOp_5: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# save/Identity_6: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# save/AssignVariableOp_6: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# save/Identity_7: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# save/AssignVariableOp_7: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# save/Identity_8: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# save/AssignVariableOp_8: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# save/Identity_9: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# save/AssignVariableOp_9: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# save/Identity_10: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# save/AssignVariableOp_10: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# save/Identity_11: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# save/AssignVariableOp_11: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# save/Identity_12: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# save/AssignVariableOp_12: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# save/Identity_13: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# save/AssignVariableOp_13: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# save/Identity_14: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# save/AssignVariableOp_14: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# save/Identity_15: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# save/AssignVariableOp_15: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# save/Identity_16: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# save/AssignVariableOp_16: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# save/Identity_17: (Identity): /job:localhost/replica:0/task:0/device:GPU:0
# save/AssignVariableOp_17: (AssignVariableOp): /job:localhost/replica:0/task:0/device:GPU:0
# save/restore_all: (NoOp): /job:localhost/replica:0/task:0/device:GPU:0
# vggish/input_features: (Placeholder): /job:localhost/replica:0/task:0/device:GPU:0
# vggish/Reshape/shape: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# vggish/conv1/weights/Initializer/truncated_normal/shape: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# vggish/conv1/weights/Initializer/truncated_normal/mean: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# vggish/conv1/weights/Initializer/truncated_normal/stddev: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# vggish/conv1/weights: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# vggish/conv1/biases/Initializer/zeros: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# vggish/conv1/biases: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# vggish/conv2/weights/Initializer/truncated_normal/shape: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# vggish/conv2/weights/Initializer/truncated_normal/mean: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# vggish/conv2/weights/Initializer/truncated_normal/stddev: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# vggish/conv2/weights: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# vggish/conv2/biases/Initializer/zeros: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# vggish/conv2/biases: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# vggish/conv3/conv3_1/weights/Initializer/truncated_normal/shape: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# vggish/conv3/conv3_1/weights/Initializer/truncated_normal/mean: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# vggish/conv3/conv3_1/weights/Initializer/truncated_normal/stddev: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# vggish/conv3/conv3_1/weights: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# vggish/conv3/conv3_1/biases/Initializer/zeros: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# vggish/conv3/conv3_1/biases: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# vggish/conv3/conv3_2/weights/Initializer/truncated_normal/shape: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# vggish/conv3/conv3_2/weights/Initializer/truncated_normal/mean: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# vggish/conv3/conv3_2/weights/Initializer/truncated_normal/stddev: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# vggish/conv3/conv3_2/weights: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# vggish/conv3/conv3_2/biases/Initializer/zeros: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# vggish/conv3/conv3_2/biases: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# vggish/conv4/conv4_1/weights/Initializer/truncated_normal/shape: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# vggish/conv4/conv4_1/weights/Initializer/truncated_normal/mean: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# vggish/conv4/conv4_1/weights/Initializer/truncated_normal/stddev: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# vggish/conv4/conv4_1/weights: (VarHandleOp): /job:localhost/replica:0/task:0/device:GPU:0
# vggish/conv4/conv4_1/biases/Initializer/zeros: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# vggish/conv4/conv4_1/biases:
# 2026-01-12 17:39:31.282499: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:473] Loaded cuDNN version 91301
# Feature extraction complete. Files saved.
# Feature extraction complete. Files saved.

# %%
X_train.shape

# %%
len(vggish_features_array)
# Out:
# 31779

# %%
#how many audio clips were less than 11

# Count nonzero frames (assuming zero-padding)
nonzero_counts = np.count_nonzero(
    np.any(vggish_features_array != 0, axis=2),
    axis=1
)

num_under_11 = np.sum(nonzero_counts < 11)
print("Number of clips with < 11 frames:", num_under_11)
# Out:
# Number of clips with < 11 frames: 30087

# %%
30087/31777
# Out:
# 0.9468168801334298

# %% [markdown]
# 94 percent are less than 11 frame like the original ALiRAS method

# %%
nonzero_counts = np.count_nonzero(
    np.any(vggish_features_array != 0, axis=2),
    axis=1
)

num_under_11 = np.sum(nonzero_counts < 11)
print("Number of clips with in the training set < 11 frames:", num_under_11)
# Out:
# Number of clips with in the training set < 11 frames: 30087

# %%
len(vggish_features_array)
# Out:
# 31779

# %%
vggish_features_array_eval = vggish_features_array

# %%
vggish_features_array_eval.shape
# Out:
# (31779, 26, 128)

# %%
vggish_features_array.shape
# Out:
# (31779, 26, 128)

# %%
X_test = vggish_features_array_eval[:, :11, :]

# %%
X_train = vggish_features_array_train[:, :11, :]
X_test = vggish_features_array_eval[:, :11, :]

# %% [markdown]
# # Training Data for fake vs real - VGGish

# %%
df_eval = pd.read_csv('/umbc/rs/iharp/users/zkhanja1/in_the_wild_more_files/meta.csv')

# %%
df_train = pd.read_csv('asvspoof5_train_vggish_Ta_audio_file_names.csv')

# %%
df_train
# Out:
#                                                     Path           FileName
# 0      /umbc/rs/vjaneja/users/zkhanja1/asvspoof5/flac...  T_0000023804.flac
# 1      /umbc/rs/vjaneja/users/zkhanja1/asvspoof5/flac...  T_0000009556.flac
# 2      /umbc/rs/vjaneja/users/zkhanja1/asvspoof5/flac...  T_0000009135.flac
# 3      /umbc/rs/vjaneja/users/zkhanja1/asvspoof5/flac...  T_0000024330.flac
# 4      /umbc/rs/vjaneja/users/zkhanja1/asvspoof5/flac...  T_0000008809.flac
# ...                                                  ...                ...
# 36495  /umbc/rs/vjaneja/users/zkhanja1/asvspoof5/flac...  T_0000015302.flac
# 36496  /umbc/rs/vjaneja/users/zkhanja1/asvspoof5/flac...  T_0000016337.flac
# 36497  /umbc/rs/vjaneja/users/zkhanja1/asvspoof5/flac...  T_0000009424.flac
# 36498  /umbc/rs/vjaneja/users/zkhanja1/asvspoof5/flac...  T_0000013754.flac
# 36499  /umbc/rs/vjaneja/users/zkhanja1/asvspoof5/flac...  T_0000035000.flac
#
# [36500 rows x 2 columns]

# %%
 Df_eval_all_parts_with_labels = pd.read_csv('/umbc/rs/iharp/users/zkhanja1/in_the_wild_more_files/meta.csv')

# %%
df_all = Df_eval_all_parts_with_labels

# %%
df_all
# Out:
#             file                speaker      label
# 0          0.wav          Alec Guinness      spoof
# 1          1.wav          Alec Guinness      spoof
# 2          2.wav           Barack Obama      spoof
# 3          3.wav          Alec Guinness      spoof
# 4          4.wav   Christopher Hitchens  bona-fide
# ...          ...                    ...        ...
# 31774  31774.wav          Boris Johnson  bona-fide
# 31775  31775.wav           Donald Trump  bona-fide
# 31776  31776.wav           Donald Trump  bona-fide
# 31777  31777.wav             Alan Watts  bona-fide
# 31778  31778.wav  Arnold Schwarzenegger      spoof
#
# [31779 rows x 3 columns]

# %%
df_all.rename(columns={'file': 'FileName', 'label': 'Label'}, inplace=True)

# %%
df_all
# Out:
#         FileName                speaker      Label
# 0          0.wav          Alec Guinness      spoof
# 1          1.wav          Alec Guinness      spoof
# 2          2.wav           Barack Obama      spoof
# 3          3.wav          Alec Guinness      spoof
# 4          4.wav   Christopher Hitchens  bona-fide
# ...          ...                    ...        ...
# 31774  31774.wav          Boris Johnson  bona-fide
# 31775  31775.wav           Donald Trump  bona-fide
# 31776  31776.wav           Donald Trump  bona-fide
# 31777  31777.wav             Alan Watts  bona-fide
# 31778  31778.wav  Arnold Schwarzenegger      spoof
#
# [31779 rows x 3 columns]

# %%
df_test = df_all

# %%
df_test['FileName'] = df_test['FileName'].str.replace('.wav', '', regex=False)

# %%
df_test
# Out:
#       FileName                speaker      Label
# 0            0          Alec Guinness      spoof
# 1            1          Alec Guinness      spoof
# 2            2           Barack Obama      spoof
# 3            3          Alec Guinness      spoof
# 4            4   Christopher Hitchens  bona-fide
# ...        ...                    ...        ...
# 31774    31774          Boris Johnson  bona-fide
# 31775    31775           Donald Trump  bona-fide
# 31776    31776           Donald Trump  bona-fide
# 31777    31777             Alan Watts  bona-fide
# 31778    31778  Arnold Schwarzenegger      spoof
#
# [31779 rows x 3 columns]

# %%
df_subset_test = df[['FileName']]

# %%
df_subset_test
# Out:
#         FileName
# 0      16720.wav
# 1      23893.wav
# 2       4329.wav
# 3       6647.wav
# 4      26991.wav
# ...          ...
# 31774  16768.wav
# 31775  15093.wav
# 31776   1532.wav
# 31777   7310.wav
# 31778  31216.wav
#
# [31779 rows x 1 columns]

# %%
df_subset_test['FileName'] = df_subset_test['FileName'].str.replace('.wav', '', regex=False)

# %%
df_test_merged = df_subset_test.merge(df_test, on='FileName', how='left')

print(df_test_merged.head())
# Out:
#   FileName            speaker      Label
# 0    16720      Ronald Reagan      spoof
# 1    23893      Alec Guinness  bona-fide
# 2     4329       Barack Obama  bona-fide
# 3     6647      Richard Nixon      spoof
# 4    26991  Winston Churchill  bona-fide

# %%
df_test_merged
# Out:
#       FileName               speaker      Label
# 0        16720         Ronald Reagan      spoof
# 1        23893         Alec Guinness  bona-fide
# 2         4329          Barack Obama  bona-fide
# 3         6647         Richard Nixon      spoof
# 4        26991     Winston Churchill  bona-fide
# ...        ...                   ...        ...
# 31774    16768       Mark Zuckerberg      spoof
# 31775    15093    Queen Elizabeth II      spoof
# 31776     1532  Christopher Hitchens      spoof
# 31777     7310         Boris Johnson      spoof
# 31778    31216         Ronald Reagan  bona-fide
#
# [31779 rows x 3 columns]

# %%
df_all
# Out:
#       FileName                speaker      Label
# 0            0          Alec Guinness      spoof
# 1            1          Alec Guinness      spoof
# 2            2           Barack Obama      spoof
# 3            3          Alec Guinness      spoof
# 4            4   Christopher Hitchens  bona-fide
# ...        ...                    ...        ...
# 31774    31774          Boris Johnson  bona-fide
# 31775    31775           Donald Trump  bona-fide
# 31776    31776           Donald Trump  bona-fide
# 31777    31777             Alan Watts  bona-fide
# 31778    31778  Arnold Schwarzenegger      spoof
#
# [31779 rows x 3 columns]

# %%
df_test_merged.to_csv('ITW_for_vggish_labels.csv', index=False)

# %%
df_train = pd.read_csv('asvspoof5_for_vggish_Df_train_with_labels.csv')
df_test = pd.read_csv('ITW_for_vggish_labels.csv')

# %%
df_train
# Out:
#            FileName  Label
# 0      T_0000023804  spoof
# 1      T_0000009556  spoof
# 2      T_0000009135  spoof
# 3      T_0000024330  spoof
# 4      T_0000008809  spoof
# ...             ...    ...
# 36495  T_0000015302  spoof
# 36496  T_0000016337  spoof
# 36497  T_0000009424  spoof
# 36498  T_0000013754  spoof
# 36499  T_0000035000  spoof
#
# [36500 rows x 2 columns]

# %% [markdown]
# # Training Data for fake vs real - VGGish

# %%
df_train_merged = df_train

# %%
df_missing_labels = df_train_merged[pd.isna(df_train_merged['Label'])]

# Display the rows with missing labels
print(df_missing_labels)
# Out:
# Empty DataFrame
# Columns: [FileName, Label]
# Index: []

# %%
df_missing_labels
# Out:
# Empty DataFrame
# Columns: [FileName, Label]
# Index: []

# %%
from tensorflow.keras.models import load_model

# Load the model
model_path = "/umbc/rs/pi_vjaneja/users/zkhanja1/CNNmodel_audioQuality.h5"
model = load_model(model_path)

# Print the expected input shape
print("Model Input Shape:", model.input_shape)
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:absl:Error in loading the saved optimizer state. As a result, your model is starting with a freshly initialized optimizer.
# Model Input Shape: (None, 11, 128)

# %%
y_test = df_test_merged['Label']

# %%
y_test = y_test.map({'spoof': 1, 'bona-fide': 0})

# %%
y_test
# Out:
# 0        1
# 1        0
# 2        0
# 3        1
# 4        0
#         ..
# 31774    1
# 31775    1
# 31776    1
# 31777    1
# 31778    0
# Name: Label, Length: 31779, dtype: int64

# %%
y_train_final = df_train_merged['Label']

# %%
y_train_final = y_train_final.map({'spoof': 1, 'bonafide': 0})

# %%
y_train = y_train_final

# %%
unique_values = np.unique(y_train)

# Print the unique values
print("Unique values in y_train:", unique_values)
# Out:
# Unique values in y_train: [0 1]

# %%
# Count occurrences of each class
class_counts = np.bincount(y_train)

# Compute percentages
total_samples = len(y_train)
percentages = (class_counts / total_samples) * 100

# Print results
print(f"Class Distribution in Training Set:")
print(f"0 (bonafide): {percentages[0]:.2f}%")
print(f"1 (spoof): {percentages[1]:.2f}%")
# Out:
# Class Distribution in Training Set:
# 0 (bonafide): 10.41%
# 1 (spoof): 89.59%

# %%
pip install imbalanced-learn
# Out:
# Collecting imbalanced-learn
#   Downloading imbalanced_learn-0.13.0-py3-none-any.whl.metadata (8.8 kB)
# Requirement already satisfied: numpy<3,>=1.24.3 in /nfs/ada/vjaneja/users/zkhanja1/.conda/envs/myenv/lib/python3.10/site-packages (from imbalanced-learn) (2.0.2)
# Requirement already satisfied: scipy<2,>=1.10.1 in /nfs/ada/vjaneja/users/zkhanja1/.conda/envs/myenv/lib/python3.10/site-packages (from imbalanced-learn) (1.15.2)
# Requirement already satisfied: scikit-learn<2,>=1.3.2 in /nfs/ada/vjaneja/users/zkhanja1/.conda/envs/myenv/lib/python3.10/site-packages (from imbalanced-learn) (1.6.1)
# Collecting sklearn-compat<1,>=0.1 (from imbalanced-learn)
#   Downloading sklearn_compat-0.1.3-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: joblib<2,>=1.1.1 in /nfs/ada/vjaneja/users/zkhanja1/.conda/envs/myenv/lib/python3.10/site-packages (from imbalanced-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl<4,>=2.0.0 in /nfs/ada/vjaneja/users/zkhanja1/.conda/envs/myenv/lib/python3.10/site-packages (from imbalanced-learn) (3.5.0)
# Downloading imbalanced_learn-0.13.0-py3-none-any.whl (238 kB)
# Downloading sklearn_compat-0.1.3-py3-none-any.whl (18 kB)
# Installing collected packages: sklearn-compat, imbalanced-learn
# Successfully installed imbalanced-learn-0.13.0 sklearn-compat-0.1.3
# Note: you may need to restart the kernel to use updated packages.

# %%
from imblearn.over_sampling import SMOTE

# %%
len(X_train)
# Out:
# 36500

# %%
X_train.shape
# Out:
# (36500, 11, 128)

# %%
len(y_train)
# Out:
# 36500

# %%
samples, timesteps, features = X_train.shape  # (samples, 11, 128)

# Reshape X_train to 2D for SMOTE
X_train_reshaped = X_train.reshape(samples, timesteps * features)

# %%
smote = SMOTE(sampling_strategy='auto', random_state=42)
X_train_resampled, y_train_resampled = smote.fit_resample(X_train_reshaped, y_train)

# %%
y_train_matched = y_train

# %%
y_test_matched = y_test

# %%
y_train
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 36495    1
# 36496    1
# 36497    1
# 36498    1
# 36499    1
# Name: Label, Length: 36500, dtype: int64

# %%
y_train_matched = y_train_matched.map({'spoof': 1, 'bonafide': 0})

# %%
y_test_matched = y_test_matched.map({'spoof': 1, 'bonafide': 0})

# %%
# matched X_train with other SSL models
samples, timesteps, features = X_train_matched.shape  # (samples, 11, 128)
X_train_reshaped = X_train_matched.reshape(samples, timesteps * features)
smote = SMOTE(sampling_strategy='auto', random_state=42)
X_train_resampled, y_train_resampled = smote.fit_resample(X_train_reshaped, y_train_matched)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[115], line 2
#       1 # matched X_train with other SSL models
# ----> 2 samples, timesteps, features = X_train_matched.shape  # (samples, 11, 128)
#       3 X_train_reshaped = X_train_matched.reshape(samples, timesteps * features)
#       4 smote = SMOTE(sampling_strategy='auto', random_state=42)
#
# NameError: name 'X_train_matched' is not defined

# %%
# matched X_train with other SSL models second round is all matched

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam

# %%
from sklearn.model_selection import train_test_split

# %%
len(y_train)
# Out:
# 36500

# %%
X_train_resampled = np.array(X_train_resampled, dtype=np.float32)
y_train_resampled = np.array(y_train_resampled, dtype=np.float32)

# %%
from sklearn.neural_network import MLPClassifier

# %%
from sklearn.model_selection import GridSearchCV

# %%
from sklearn.pipeline import make_pipeline

# %%
X_train_final, X_val, y_train_final, y_val = train_test_split(
    X_train_resampled, y_train_resampled, test_size=0.1, random_state=42, stratify=y_train_resampled
)

# %%
mlp = MLPClassifier(hidden_layer_sizes=(32), max_iter=500, random_state=42, activation='relu', solver='adam', early_stopping=True)

# %%
#mlp.fit(X_train_final, y_train_final)
# Out:
# MLPClassifier(early_stopping=True, hidden_layer_sizes=32, max_iter=500,
#               random_state=42)

# %%
mlp.fit(X_train_resampled, y_train_resampled)
# Out:
# MLPClassifier(early_stopping=True, hidden_layer_sizes=32, max_iter=500,
#               random_state=42)

# %%
from sklearn.metrics import accuracy_score

# %%
#fine tuning hyper parameters using the validation set, I am doing this multiple runs
#y_val_pred = mlp.predict_proba(X_val)

# %%
#y_val_pred = y_val_pred[:, 1]

# %%
#y_val_pred

# %%
#roc_auc = roc_auc_score(y_val, y_val_pred)

# Print the ROC AUC score
#print(f"ROC AUC score for test data: {roc_auc:.4f}")

# %%
len(X_train_reshaped)
# Out:
# 36500

# %%
X_train_resampled.shape
# Out:
# (65398, 1408)

# %%
X_train_matched = X_train
X_test_matched = X_test

# %%
X_train2 = X_train_matched.reshape(X_train_matched.shape[0], -1)
print(X_train2.shape)
# Out:
# (36500, 1408)

# %%
X_test2 = X_test_matched.reshape(X_test_matched.shape[0], -1)
print(X_test2.shape)
# Out:
# (31779, 1408)

# %%
test_probs = mlp.predict_proba(X_test2)

# %%
test_probs
# Out:
# array([[1.1920929e-07, 9.9999988e-01],
#        [3.0195713e-04, 9.9969804e-01],
#        [1.4066696e-05, 9.9998593e-01],
#        ...,
#        [0.0000000e+00, 1.0000000e+00],
#        [9.0038776e-04, 9.9909961e-01],
#        [4.7683716e-07, 9.9999952e-01]], shape=(31779, 2), dtype=float32)

# %%
X_train2.shape
# Out:
# (36500, 1408)

# %%
#test_accuracy = accuracy_score(y_test, test_probs)
#print(f"Validation Accuracy: {test_accuracy:.4f}")

# %%
train_probs = mlp.predict_proba(X_train2)

# %%
#train_accuracy = accuracy_score(y_train, train_probs)
#print(f"Validation Accuracy: {train_accuracy:.4f}")

# %%
from sklearn.metrics import roc_auc_score

# %%
train_probs = train_probs[:, 1]
test_probs = test_probs[:,1]

# %%
y_train_resampled
# Out:
# array([1., 1., 1., ..., 0., 0., 0.], shape=(65398,), dtype=float32)

# %%
roc_auc = roc_auc_score(y_train, train_probs)

# Print the ROC AUC score
print(f"ROC AUC score for training data: {roc_auc:.4f}")
# Out:
# ROC AUC score for training data: 0.9999

# %%
roc_auc = roc_auc_score(y_test, test_probs)

# Print the ROC AUC score
print(f"ROC AUC score for test data: {roc_auc:.4f}")
# Out:
# ROC AUC score for test data: 0.6177

# %% [markdown]
# df_matched

# %% [markdown]
# df_matched

# %%
df_matched
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[155], line 1
# ----> 1 df_matched
#
# NameError: name 'df_matched' is not defined

# %%
#df_matched = df_matched.rename(columns={'audio_filenames': 'FileName'})

# %%
#df_matched_train = df_matched_train.rename(columns={'audio_filenames': 'FileName'})

# %%
#key = 'FileName'

# Reindex df_train_merged to match df_matched order
#df_train_matched = df_train_merged.set_index(key).loc[df_matched_train[key]].reset_index()

# %%
#df_matched_test = df_matched

# %%
#df_matched_test = pd.read_csv('asvspoof5_DF_labels_corresponding_to_hubert_7000_test.csv')

# %%
y_test
# Out:
# 0        1
# 1        0
# 2        0
# 3        1
# 4        0
#         ..
# 31774    1
# 31775    1
# 31776    1
# 31777    1
# 31778    0
# Name: Label, Length: 31779, dtype: int64

# %%
df_test_matched = df_test_merged

# %%
X_test_matched.shape
# Out:
# (31779, 11, 128)

# %% [markdown]
# Now I am going up and train MLP one time more with the matched 7000 samples -- this is done

# %%
X_train_matched.shape
# Out:
# (36500, 11, 128)

# %%
X_test_matched.shape
# Out:
# (31779, 11, 128)

# %%
X_train = X_train_matched
X_test = X_test_matched

# %%
X_train_resampled.shape
# Out:
# (65398, 1, 1408)

# %%
X_train_resampled2 = X_train_resampled.reshape(65398, 11, 128)

# %%
X_train_resampled2.shape
# Out:
# (65398, 11, 128)

# %%
X_train_resampled= X_train_resampled2

# %%
X_train_resampled.shape
# Out:
# (65398, 11, 128)

# %%
from tensorflow.keras.callbacks import EarlyStopping

# Define early stopping
early_stop = EarlyStopping(
    monitor='val_roc_auc',   # monitor validation AUC
    patience=5,              # stop if no improvement after 5 epochs
    mode='max',              # maximize AUC
    restore_best_weights=True  # restore the best model weights
)

# %%
X_train_resampled = np.expand_dims(X_train_resampled, axis=1)  # (samples, 1, time_steps, features)
#X_val = np.expand_dims(X_val, axis=1)
X_train = np.expand_dims(X_train, axis=1)
X_test = np.expand_dims(X_test, axis=1)

# %%
import tensorflow as tf
from tensorflow.keras import layers, models, regularizers

def build_resnet18(input_shape):
    inputs = layers.Input(shape=input_shape)
    x = layers.Conv2D(64, 7, strides=2, padding='same', use_bias=False)(inputs)
    x = layers.BatchNormalization()(x)
    x = layers.ReLU()(x)
    x = layers.MaxPooling2D(3, strides=2, padding='same')(x)

    def residual_block(x, filters, downsample=False):
        shortcut = x
        strides = 2 if downsample else 1
        x = layers.Conv2D(filters, 3, strides=strides, padding='same', use_bias=False,
                          kernel_regularizer=regularizers.l2(1e-4))(x)
        x = layers.BatchNormalization()(x)
        x = layers.ReLU()(x)
        x = layers.Conv2D(filters, 3, strides=1, padding='same', use_bias=False,
                          kernel_regularizer=regularizers.l2(1e-4))(x)
        x = layers.BatchNormalization()(x)

        if downsample or shortcut.shape[-1] != filters:
            shortcut = layers.Conv2D(filters, 1, strides=strides, padding='same', use_bias=False,
                                     kernel_regularizer=regularizers.l2(1e-4))(shortcut)
            shortcut = layers.BatchNormalization()(shortcut)

        x = layers.add([x, shortcut])
        x = layers.ReLU()(x)
        return x

    x = residual_block(x, 64)
    x = residual_block(x, 64)
    x = residual_block(x, 128, downsample=True)
    x = residual_block(x, 128)
    x = residual_block(x, 256, downsample=True)
    x = residual_block(x, 256)
    x = residual_block(x, 512, downsample=True)
    x = residual_block(x, 512)

    x = layers.GlobalAveragePooling2D()(x)
    outputs = layers.Dense(1, activation='sigmoid')(x)

    model = models.Model(inputs, outputs)
    return model
input_shape = X_train_resampled.shape[1:]  # (time_steps, features, 1)
resnet18_model = build_resnet18(input_shape)

# %%
from tensorflow.keras.optimizers import Adam

resnet18_model.compile(
    optimizer=Adam(learning_rate=1e-4),
    loss='binary_crossentropy',
    metrics=[tf.keras.metrics.AUC(name='roc_auc')]
)

# %%
history = resnet18_model.fit(
    X_train_resampled, y_train_resampled,
    validation_split=0.15,
    epochs=50,
    batch_size=32,
    callbacks=[early_stop]
)
# Out:
# Epoch 1/50
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[175], line 1
# ----> 1 history = resnet18_model.fit(
#       2     X_train_resampled, y_train_resampled,
#       3     validation_split=0.15,
#       4     epochs=50,
#       5     batch_size=32,
#       6     callbacks=[early_stop]
#       7 )
#
# File /umbc/rs/iharp/users/zkhanja1/tensorflow_env/lib/python3.13/site-packages/keras/src/utils/traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File /umbc/rs/iharp/users/zkhanja1/tensorflow_env/lib/python3.13/site-packages/tensorflow/python/data/ops/dataset_ops.py:503, in DatasetV2.__iter__(self)
#     501     return iterator_ops.OwnedIterator(self)
#     502 else:
# --> 503   raise RuntimeError("`tf.data.Dataset` only supports Python-style "
#     504                      "iteration in eager mode or within tf.function.")
#
# RuntimeError: `tf.data.Dataset` only supports Python-style iteration in eager mode or within tf.function.

# %%
probs_train = resnet18_model.predict(X_train).flatten()
probs_test = resnet18_model.predict(X_test).flatten()

print(f"First 5 probabilities (train): {probs_train[:5]}")
print(f"First 5 probabilities (test): {probs_test[:5]}")
# Out:
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# First 5 probabilities (train): [0.5702073  0.64915806 0.5071994  0.62879837 0.37721846]
# First 5 probabilities (test): [0.7904586  0.45776233 0.6164098  0.5499025  0.5359843 ]

# %%
roc_auc_train = roc_auc_score(y_train_matched, probs_train)
print(f"ROC AUC on training data: {roc_auc_train:.4f}")
# Out:
# ROC AUC on training data: 0.9134

# %%
roc_auc_test = roc_auc_score(y_test_matched, probs_test)
print(f"ROC AUC on test data: {roc_auc_test:.4f}")
# Out:
# ROC AUC on test data: 0.5809

# %% [markdown]
# MLP was slightly better than ResNET so I am going to save those results, I reran the predictions from MLP

# %%
test_probs_df = pd.DataFrame(test_probs, columns=['test_probs_for1_MLP_vggish'])
train_probs_df = pd.DataFrame(train_probs, columns=['train_probs_for1_MLP_vggish'])

# %%
test_probs_df
# Out:
#        test_probs_for1_MLP_vggish
# 0                        1.000000
# 1                        0.999698
# 2                        0.999986
# 3                        1.000000
# 4                        0.999097
# ...                           ...
# 31774                    0.999698
# 31775                    1.000000
# 31776                    1.000000
# 31777                    0.999100
# 31778                    1.000000
#
# [31779 rows x 1 columns]

# %%
df_train_merged
# Out:
#            FileName  Label
# 0      T_0000023804  spoof
# 1      T_0000009556  spoof
# 2      T_0000009135  spoof
# 3      T_0000024330  spoof
# 4      T_0000008809  spoof
# ...             ...    ...
# 36495  T_0000015302  spoof
# 36496  T_0000016337  spoof
# 36497  T_0000009424  spoof
# 36498  T_0000013754  spoof
# 36499  T_0000035000  spoof
#
# [36500 rows x 2 columns]

# %%
df_test_matched['test_probs_for1_MLP_vggish'] = test_probs_df['test_probs_for1_MLP_vggish']

# %%
df_train_merged['train_probs_for1_MLP_vggish'] = train_probs_df['train_probs_for1_MLP_vggish']

# %%
df_train_matched = df_train_merged

# %%
df_train_matched
# Out:
#            FileName  Label  train_probs_for1_MLP_vggish
# 0      T_0000023804  spoof                     1.000000
# 1      T_0000009556  spoof                     1.000000
# 2      T_0000009135  spoof                     1.000000
# 3      T_0000024330  spoof                     1.000000
# 4      T_0000008809  spoof                     1.000000
# ...             ...    ...                          ...
# 36495  T_0000015302  spoof                     1.000000
# 36496  T_0000016337  spoof                     1.000000
# 36497  T_0000009424  spoof                     0.999348
# 36498  T_0000013754  spoof                     1.000000
# 36499  T_0000035000  spoof                     1.000000
#
# [36500 rows x 3 columns]

# %%
df_test_matched.to_csv('ITW_DF_test_probs_onlyvggish_mlp.csv', index=False)
df_train_matched.to_csv('asvspoof5_DF_train_probs_onlyvggish_mlp_for_ITW.csv', index=False)

# %%
#np.save('asvspoof5_X_train_matched_vggish_7000_samples.npy', X_train_matched)
#print("Saved: X_train_matched.npy")

# %%
#np.save('asvspoof5_X_test_matched_vggish_7000_samples.npy', X_test_matched)
#print("Saved: X_test_matched.npy")

# %%
#X_test_matched.shape

# %%
import numpy as np
from sklearn.metrics import roc_curve

# %%
import numpy as np
from sklearn.metrics import roc_curve

def compute_eer(y_true, y_probs):
    """
    Computes the Equal Error Rate (EER) as the average of FPR and FNR.

    Parameters:
        y_true (array-like): True binary labels (0 or 1).
        y_probs (array-like): Predicted probabilities for the positive class.

    Returns:
        eer (float): Equal Error Rate (average of FPR and FNR).
        eer_threshold (float): Threshold where FPR and FNR are closest.
    """
    # Compute ROC curve
    fpr, tpr, thresholds = roc_curve(y_true, y_probs)

    # Compute False Negative Rate (FNR)
    fnr = 1 - tpr  # FNR = 1 - TPR

    # Find the threshold where FPR and FNR are closest
    eer_index = np.nanargmin(np.abs(fpr - fnr))  # Get index of min difference
    eer_threshold = thresholds[eer_index]

    # Compute EER as the average of FPR and FNR at that threshold
    eer = (fpr[eer_index] + fnr[eer_index]) / 2

    return eer, eer_threshold

# %%
eer, eer_threshold = compute_eer(y_train, train_probs)
print(f"EER (Average of FPR & FNR): {eer:.4f}, Threshold: {eer_threshold:.4f}")
# Out:
# EER (Average of FPR & FNR): 0.0008, Threshold: 0.5993

# %%
from sklearn.metrics import confusion_matrix
import numpy as np

def compute_eer_fixed_threshold(y_true, y_scores, threshold):
    """
    Compute the Equal Error Rate (EER) at a fixed threshold.

    Parameters:
    - y_true: array-like of shape (n_samples,) -> True binary labels (0 or 1)
    - y_scores: array-like of shape (n_samples,) -> Predicted scores/probabilities
    - threshold: float, the fixed threshold at which to compute EER

    Returns:
    - eer: float, the average of FPR and FNR at the fixed threshold
    """
    # Convert scores to binary predictions using the fixed threshold
    y_pred = (y_scores >= threshold).astype(int)

    # Compute confusion matrix
    tn, fp, fn, tp = confusion_matrix(y_true, y_pred).ravel()

    # Compute False Positive Rate (FPR) and False Negative Rate (FNR)
    fpr = fp / (fp + tn) if (fp + tn) > 0 else 0.0
    fnr = fn / (fn + tp) if (fn + tp) > 0 else 0.0

    # Compute EER as the average of FPR and FNR
    eer = (fpr + fnr) / 2

    return eer

# %%
eer = compute_eer_fixed_threshold(y_test, test_probs,  0.5993)

# %%
eer
# Out:
# np.float64(0.4915085672542952)

# %% [markdown]
# # Auto-labeling with vggish

# %%
import numpy as np

# Load the saved .npy file
vggish_features_array_train = np.load('asvspoof5_vggish_features_array_train2.npy')

# %%
vggish_features_array_test= np.load('ITW_vggish_features_array.npy')

# %%
df_test = pd.read_csv('ITW_audio_file_info_VGGish.csv')

# %%
df_train = pd.read_csv('asvspoof5_for_vggish_Df_train_with_labels.csv')
df_test = pd.read_csv('ITW_for_vggish_labels.csv')

# %%
X_train =vggish_features_array_train

# %%
X_test =vggish_features_array_test

# %%
#pwd**
# Out:
# '/umbc/rs/iharp/users/zkhanja1/asvspoof5_codes'

# %%
#X_test = np.load('asvspoof5_X_test_matched_vggish_7000_samples.npy')

# %%
#X_train = np.load('asvspoof5_X_train_matched_vggish_7000_samples.npy')

# %%
# I had done this training set auto-labeling before and now I am reading the results only
results_df = pd.read_csv('asvspoof5_aliras_vggish_train.csv')

# %%
df_test
# Out:
#        FileName               speaker      Label
# 0         16720         Ronald Reagan      spoof
# 1         23893         Alec Guinness  bona-fide
# 2          4329          Barack Obama  bona-fide
# 3          6647         Richard Nixon      spoof
# 4         26991     Winston Churchill  bona-fide
# ...         ...                   ...        ...
# 31774     16768       Mark Zuckerberg      spoof
# 31775     15093    Queen Elizabeth II      spoof
# 31776      1532  Christopher Hitchens      spoof
# 31777      7310         Boris Johnson      spoof
# 31778     31216         Ronald Reagan  bona-fide
#
# [31779 rows x 3 columns]

# %%
#cd /umbc/rs/vjaneja/users/zkhanja1/

# %%
from tensorflow.keras.models import load_model

# Load the model
model_path = "/umbc/rs/pi_vjaneja/users/zkhanja1/CNNmodel_audioQuality.h5"
model_audioQuality = load_model(model_path)

# Print the expected input shape
print("Model Input Shape:", model_audioQuality.input_shape)
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1768317912.152853  387715 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 43489 MB memory:  -> device: 0, name: NVIDIA L40S, pci bus id: 0000:4a:00.0, compute capability: 8.9
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:absl:Error in loading the saved optimizer state. As a result, your model is starting with a freshly initialized optimizer.
# Model Input Shape: (None, 11, 128)

# %%
model_path = "/umbc/rs/pi_vjaneja/users/zkhanja1/CNNmodel_breath.h5"
model_breath = load_model(model_path)

# Print the expected input shape
print("Model Input Shape:", model_breath.input_shape)
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:absl:Error in loading the saved optimizer state. As a result, your model is starting with a freshly initialized optimizer.
# Model Input Shape: (None, 1408, 1)

# %%
model_path = "/umbc/rs/pi_vjaneja/users/zkhanja1/CNNmodel_PitchAnomaly.h5"
model_pitch = load_model(model_path)

# Print the expected input shape
print("Model Input Shape:", model_pitch.input_shape)
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:absl:Error in loading the saved optimizer state. As a result, your model is starting with a freshly initialized optimizer.
# Model Input Shape: (None, 1408, 1)

# %%
X_test.shape
# Out:
# (31779, 26, 128)

# %%
X_train = vggish_features_array_train[:, :11, :]
X_test = vggish_features_array_test[:, :11, :]

# %%
test_audioQ = model_audioQuality.predict(X_test)
# Out:
# 2026-01-13 10:26:43.798054: I external/local_xla/xla/service/service.cc:163] XLA service 0x1553cc016970 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2026-01-13 10:26:43.798069: I external/local_xla/xla/service/service.cc:171]   StreamExecutor device (0): NVIDIA L40S, Compute Capability 8.9
# 2026-01-13 10:26:43.805671: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2026-01-13 10:26:43.836336: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:473] Loaded cuDNN version 91301
# 2026-01-13 10:26:43.843532: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2026-01-13 10:26:43.843611: W external/local_xla/xla/service/gpu/autotuning/gemm_fusion_autotuner.cc:1005] Compiling 36 configs for gemm_fusion_dot.98 on a single thread.
# 198/994 ━━━━━━━━━━━━━━━━━━━━ 0s 769us/step
# I0000 00:00:1768318006.391227  388506 device_compiler.h:196] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 946/994 ━━━━━━━━━━━━━━━━━━━━ 0s 746us/step
# 2026-01-13 10:26:47.215634: W external/local_xla/xla/service/gpu/autotuning/gemm_fusion_autotuner.cc:1005] Compiling 9 configs for gemm_fusion_dot.114 on a single thread.
# 994/994 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step

# %%
X_train_org = X_train

# %%
X_train_org = X_train
X_test_org = X_test

# %%
X_train = X_train.reshape(X_train.shape[0], -1, 1)

# %%
X_test = X_test.reshape(X_test.shape[0], -1, 1)

# %%
#train_breath = model_breath.predict(X_train)

# %%
test_breath = model_breath.predict(X_test)
# Out:
# 2026-01-13 10:27:07.766430: W external/local_xla/xla/service/gpu/autotuning/gemm_fusion_autotuner.cc:1005] Compiling 3 configs for gemm_fusion_dot.98 on a single thread.
# 938/994 ━━━━━━━━━━━━━━━━━━━━ 0s 751us/step
# 2026-01-13 10:27:09.103046: W external/local_xla/xla/service/gpu/autotuning/gemm_fusion_autotuner.cc:1005] Compiling 4 configs for gemm_fusion_dot.114 on a single thread.
# 994/994 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step

# %%
#train_pitch = model_pitch.predict(X_train)

# %%
test_pitch = model_pitch.predict(X_test)
# Out:
# 2026-01-13 10:27:14.318687: W external/local_xla/xla/service/gpu/autotuning/gemm_fusion_autotuner.cc:1005] Compiling 3 configs for gemm_fusion_dot.98 on a single thread.
# 942/994 ━━━━━━━━━━━━━━━━━━━━ 0s 751us/step
# 2026-01-13 10:27:15.651325: W external/local_xla/xla/service/gpu/autotuning/gemm_fusion_autotuner.cc:1005] Compiling 23 configs for gemm_fusion_dot.114 on a single thread.
# 2026-01-13 10:27:16.276414: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_114', 12 bytes spill stores, 12 bytes spill loads
# 994/994 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step

# %%
#train_pitch.shape

# %%
#train_audioQ = np.squeeze(train_audioQ)

# %%
#train_audioQ = np.squeeze(train_audioQ)
#train_pitch = np.squeeze(train_pitch)
#train_breath = np.squeeze(train_breath)

# %%
test_audioQ = np.squeeze(test_audioQ)
test_pitch = np.squeeze(test_pitch)
test_breath = np.squeeze(test_breath)

# %%
#results_df = pd.DataFrame({
 #   'audio_quality': train_audioQ,
 #   'pitch': train_pitch,
  #  'breath': train_breath
#})

# %%
results_df_test = pd.DataFrame({
    'audio_quality': test_audioQ,
    'pitch': test_pitch,
    'breath': test_breath
})

# %%
results_df
# Out:
#       audio_quality     pitch    breath
# 0          0.331997  0.188679  0.006483
# 1          0.250470  0.031026  0.756300
# 2          0.108325  0.996733  0.905821
# 3          0.486518  0.885993  0.986433
# 4          0.156293  0.999627  0.908110
# ...             ...       ...       ...
# 6995       0.566767  0.999063  0.424259
# 6996       0.423330  0.996964  0.935205
# 6997       0.185415  0.983965  0.999607
# 6998       0.243536  0.999225  0.776450
# 6999       0.151264  0.937717  0.024741
#
# [7000 rows x 3 columns]

# %%
df_matched_train = pd.read_csv('asvspoof5_DF_labels_corresponding_to_hubert_7000_train.csv')

# %%
df_matched_train
# Out:
#       Unnamed: 0 audio_filenames     Label
# 0              0    T_0000000000     spoof
# 1              1    T_0000000001     spoof
# 2              2    T_0000000002     spoof
# 3              3    T_0000000003     spoof
# 4              4    T_0000000004     spoof
# ...          ...             ...       ...
# 6995        6995    T_0000006995     spoof
# 6996        6996    T_0000006996     spoof
# 6997        6997    T_0000006997     spoof
# 6998        6998    T_0000006998  bonafide
# 6999        6999    T_0000006999     spoof
#
# [7000 rows x 3 columns]

# %%
# Save to CSV
#output_csv_path = "asvspoof5_aliras_vggish_train.csv"  # Replace with your desired path
#results_df.to_csv(output_csv_path, index=False)  #

# %%
output_csv_path = "ITW_aliras_vggish_test.csv"  # Replace with your desired path
results_df_test.to_csv(output_csv_path, index=False)  #

# %%
results_df_test
# Out:
#        audio_quality     pitch    breath
# 0           0.701664  0.122354  0.710586
# 1           0.499775  0.066862  0.441330
# 2           0.479205  0.153846  0.716117
# 3           0.701664  0.049918  0.943760
# 4           0.499731  0.062945  0.019548
# ...              ...       ...       ...
# 31774       0.499775  0.066862  0.441330
# 31775       0.479250  0.112460  0.962905
# 31776       0.701664  0.049918  0.943760
# 31777       0.499755  0.062895  0.019548
# 31778       0.478972  0.113138  0.962677
#
# [31779 rows x 3 columns]

# %%
df_train
# Out:
#            FileName  Label
# 0      T_0000023804  spoof
# 1      T_0000009556  spoof
# 2      T_0000009135  spoof
# 3      T_0000024330  spoof
# 4      T_0000008809  spoof
# ...             ...    ...
# 36495  T_0000015302  spoof
# 36496  T_0000016337  spoof
# 36497  T_0000009424  spoof
# 36498  T_0000013754  spoof
# 36499  T_0000035000  spoof
#
# [36500 rows x 2 columns]

# %%
y_train = df_matched_train['Label']

# %%
y_test = df_test['Label']

# %%
X_train = results_df

# %%
X_train
# Out:
#       audio_quality     pitch    breath
# 0          0.331997  0.188679  0.006483
# 1          0.250470  0.031026  0.756300
# 2          0.108325  0.996733  0.905821
# 3          0.486518  0.885993  0.986433
# 4          0.156293  0.999627  0.908110
# ...             ...       ...       ...
# 6995       0.566767  0.999063  0.424259
# 6996       0.423330  0.996964  0.935205
# 6997       0.185415  0.983965  0.999607
# 6998       0.243536  0.999225  0.776450
# 6999       0.151264  0.937717  0.024741
#
# [7000 rows x 3 columns]

# %%
y_train = y_train.map({'spoof': 1, 'bonafide': 0})

# %%
y_test = y_test.map({'spoof': 1, 'bona-fide': 0})

# %%
X_test = results_df_test

# %%
y_test
# Out:
# 0        1
# 1        0
# 2        0
# 3        1
# 4        0
#         ..
# 31774    1
# 31775    1
# 31776    1
# 31777    1
# 31778    0
# Name: Label, Length: 31779, dtype: int64

# %%
X_train.shape
# Out:
# (7000, 3)

# %%
#y_train1 = pd.read_csv('asvspoof5_for_vggish_Df_train_with_labels.csv')
# this file does not contain the matched y_train, the matched one is the one that read as df_matched_train

# %%
#y_train2 = pd.read_csv('asvspoof5_train_vggish_Ta_audio_file_names.csv')
# this file does not contain the matched y_train, the matched one is the one that read as df_matched_train

# %%
from imblearn.over_sampling import SMOTE
smote = SMOTE(sampling_strategy='auto', random_state=42)
X_train_resampled, y_train_resampled = smote.fit_resample(X_train, y_train)

# %%
X_train_final, X_val, y_train_final, y_val = train_test_split(
    X_train_resampled, y_train_resampled, test_size=0.1, random_state=42, stratify=y_train_resampled
)

# %%
X_train.shape
# Out:
# (7000, 3)

# %%
mlp = MLPClassifier(hidden_layer_sizes=(3), max_iter=500, random_state=42, activation='relu', solver='adam', early_stopping=True)
mlp.fit(X_train_final, y_train_final)
# Out:
# MLPClassifier(early_stopping=True, hidden_layer_sizes=3, max_iter=500,
#               random_state=42)

# %%
y_train_pred = mlp.predict_proba(X_train)
y_train_pred = y_train_pred[:, 1]

# %%
y_val_pred = mlp.predict_proba(X_val)
y_val_pred = y_val_pred[:, 1]

# %%
from sklearn.metrics import roc_auc_score

# %%
roc_auc = roc_auc_score(y_val, y_val_pred)

# Print the ROC AUC score
print(f"ROC AUC score for val data: {roc_auc:.4f}")
# Out:
# ROC AUC score for val data: 0.7353

# %%
roc_auc = roc_auc_score(y_train, y_train_pred)

# Print the ROC AUC score
print(f"ROC AUC score for training data: {roc_auc:.4f}")
# Out:
# ROC AUC score for training data: 0.7252

# %%
y_test_pred = mlp.predict_proba(X_test)
y_test_pred = y_test_pred[:, 1]

# %%
y_test_pred.shape
# Out:
# (31779,)

# %%
roc_auc = roc_auc_score(y_test, y_test_pred)

# Print the ROC AUC score
print(f"ROC AUC score for test data: {roc_auc:.4f}")
# Out:
# ROC AUC score for test data: 0.5594

# %%
# Out:
#       Unnamed: 0 audio_filenames     Label
# 0              0    T_0000000000     spoof
# 1              1    T_0000000001     spoof
# 2              2    T_0000000002     spoof
# 3              3    T_0000000003     spoof
# 4              4    T_0000000004     spoof
# ...          ...             ...       ...
# 6995        6995    T_0000006995     spoof
# 6996        6996    T_0000006996     spoof
# 6997        6997    T_0000006997     spoof
# 6998        6998    T_0000006998  bonafide
# 6999        6999    T_0000006999     spoof
#
# [7000 rows x 3 columns]

# %%
from sklearn.metrics import roc_auc_score

# %%
import numpy as np
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import roc_auc_score

# -----------------------------
# Define pipeline
# -----------------------------
pipe = Pipeline([
    ('scaler', StandardScaler()),
    ('logreg', LogisticRegression(max_iter=1000))
])

# -----------------------------
# Define parameter grid
# -----------------------------
param_grid = [
    {
        'logreg__solver': ['liblinear'],
        'logreg__penalty': ['l1', 'l2'],
        'logreg__C': [0.01, 0.1, 1, 10, 100]
    },
    {
        'logreg__solver': ['saga'],
        'logreg__penalty': ['l1', 'l2'],
        'logreg__C': [0.01, 0.1, 1, 10, 100]
    },
    {
        'logreg__solver': ['lbfgs', 'newton-cg'],
        'logreg__penalty': ['l2'],
        'logreg__C': [0.01, 0.1, 1, 10, 100]
    }
]

# -----------------------------
# GridSearch with validation set
# -----------------------------
grid = GridSearchCV(
    estimator=pipe,
    param_grid=param_grid,
    scoring='roc_auc',
    cv=[(np.arange(len(X_val)), np.arange(len(X_val)))]  # force validation set
)

# Fit on training set
grid.fit(X_train_final, y_train_final)

# -----------------------------
# Evaluate on validation set
# -----------------------------
y_val_pred_proba = grid.best_estimator_.predict_proba(X_val)[:, 1]
roc_auc_val = roc_auc_score(y_val, y_val_pred_proba)

print("Best Parameters:", grid.best_params_)
print("Validation ROC AUC:", roc_auc_val)
# Out:
# Best Parameters: {'logreg__C': 0.01, 'logreg__penalty': 'l1', 'logreg__solver': 'liblinear'}
# Validation ROC AUC: 0.7820370607028754

# %%
from sklearn.metrics import roc_auc_score

# %%
import numpy as np
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_auc_score

# %%
# -----------------------------
# Build pipeline with best params
# -----------------------------
best_pipe = Pipeline([
    ('scaler', StandardScaler()),
    ('logreg', LogisticRegression(
        C=0.01,
        penalty='l1',
        solver='liblinear',
        max_iter=1000
    ))
])

# -----------------------------
# Fit on training set
# -----------------------------
best_pipe.fit(X_train_final, y_train_final)

# -----------------------------
# Predict probabilities
# -----------------------------
y_train_pred_proba = best_pipe.predict_proba(X_train)[:, 1]
y_test_pred_proba = best_pipe.predict_proba(X_test)[:, 1]

# -----------------------------
# Evaluate ROC AUC
# -----------------------------
roc_auc_train = roc_auc_score(y_train, y_train_pred_proba)
roc_auc_test = roc_auc_score(y_test, y_test_pred_proba)

print("Best Parameters: {'C': 0.01, 'penalty': 'l1', 'solver': 'liblinear'}")
print("Training ROC AUC:", roc_auc_train)
print("Test ROC AUC:", roc_auc_test)
# Out:
# Best Parameters: {'C': 0.01, 'penalty': 'l1', 'solver': 'liblinear'}
# Training ROC AUC: 0.7654429476552986
# Test ROC AUC: 0.5626048698725006

# %%
y_test_pred =y_test_pred_proba

# %%
y_test = np.squeeze(y_test)   # Shape: (n_samples,)
y_test_pred = np.squeeze(y_test_pred)
results_df2 = pd.DataFrame({
    'true_label_fake1_real0_lr': y_test,   # True labels (ground truth)
    'y_test_pred': y_test_pred    # Model predictions
})

# Save to CSV (no index column)
results_df2.to_csv('ITW_y_test_pred_from_aliras_labels_LR.csv', index=False)
print("CSV saved successfully!")
# Out:
# CSV saved successfully!

# %%
results_df2['FileName'] = df_test['FileName']

# %%
results_df2
# Out:
#        true_label_fake1_real0_lr  y_test_pred  FileName
# 0                              1     0.905350     16720
# 1                              0     0.911876     23893
# 2                              0     0.896563      4329
# 3                              1     0.929222      6647
# 4                              0     0.899787     26991
# ...                          ...          ...       ...
# 31774                          1     0.911876     16768
# 31775                          1     0.915452     15093
# 31776                          1     0.929222      1532
# 31777                          1     0.899801      7310
# 31778                          0     0.915278     31216
#
# [31779 rows x 3 columns]

# %%
results_df2.to_csv('ITW_y_test_pred_from_aliras_labels_LR.csv', index=False)
print("Updated CSV saved successfully!")
# Out:
# Updated CSV saved successfully!

# %% [markdown]
# Did not run the code below as i do have the results for the train
#
# y_train = np.squeeze(y_train)   # Shape: (n_samples,)
# y_train_pred = np.squeeze(y_train_pred)
# results_df3 = pd.DataFrame({
#     'true_label_fake1_real0': y_train,   # True labels (ground truth)
#     'y_train_pred': y_train_pred    # Model predictions
# })
#
#
# results_df3.to_csv('asvspoof5_y_train_pred_from_aliras_labels_7000samples.csv', index=False)
# print("CSV saved successfully!")

# %%
eer, eer_threshold = compute_eer(y_train, y_train_pred)
print(f"EER (Average of FPR & FNR): {eer:.4f}, Threshold: {eer_threshold:.4f}")
# Out:
# EER (Average of FPR & FNR): 0.3554, Threshold: 0.4407

# %%
eer_test = compute_eer_fixed_threshold(y_test, y_test_pred, 0.4407)

# %%
eer_test
# Out:
# np.float64(0.5)

# %%
train_aliras = pd.read_csv('asvspoof5_y_train_pred_from_aliras_labels_7000samples.csv')

# %%
test_aliras = pd.read_csv('ITW_y_test_pred_from_aliras_labels_LR.csv')

# %%
#train_aliras

# %%
test_aliras
# Out:
#        true_label_fake1_real0_lr  y_test_pred  FileName
# 0                              1     0.905350     16720
# 1                              0     0.911876     23893
# 2                              0     0.896563      4329
# 3                              1     0.929222      6647
# 4                              0     0.899787     26991
# ...                          ...          ...       ...
# 31774                          1     0.911876     16768
# 31775                          1     0.915452     15093
# 31776                          1     0.929222      1532
# 31777                          1     0.899801      7310
# 31778                          0     0.915278     31216
#
# [31779 rows x 3 columns]

# %%
y_train_pred
# Out:
# array([0.68949701, 0.71640263, 0.39594781, ..., 0.40631021, 0.41181392,
#        0.43884842], shape=(7000,))

# %%
df

# %%
y_train_aliras= train_aliras['y_train_pred']

# %%
y_test_aliras= test_aliras['y_test_pred']

# %%
y_train= train_aliras['true_label_fake1_real0']

# %%
test_aliras
# Out:
#        true_label_fake1_real0_lr  y_test_pred  FileName
# 0                              1     0.905350     16720
# 1                              0     0.911876     23893
# 2                              0     0.896563      4329
# 3                              1     0.929222      6647
# 4                              0     0.899787     26991
# ...                          ...          ...       ...
# 31774                          1     0.911876     16768
# 31775                          1     0.915452     15093
# 31776                          1     0.929222      1532
# 31777                          1     0.899801      7310
# 31778                          0     0.915278     31216
#
# [31779 rows x 3 columns]

# %%
y_test= test_aliras['true_label_fake1_real0_lr']

# %% [markdown]
# # ensemble modeling (aliras + vggish) NOT RUN

# %%
#train = pd.read_csv('/nfs/rs/vjaneja/users/zkhanja1/y_train_pred_from_aliras_labels.csv')

# %%
#test = pd.read_csv('/nfs/rs/vjaneja/users/zkhanja1/y_test_pred_from_aliras_labels.csv')

# %%
train = train_aliras

# %%
test = test_aliras

# %%
train_vggish = pd.read_csv('asvspoof5_y_train_pred_from_VGGish_matched_7000samples.csv')

# %%
#train_vggish = pd.read_csv('asvspoof5_DF_train_probs_onlyvggish_mlp_for_ITW.csv')
#this one is the whole VGGish for the whole training data

# %%
test_vggish = pd.read_csv('ITW_DF_test_probs_onlyvggish_mlp.csv')

# %%
#train_vggish
# Out:
#            FileName  Label  train_probs_for1_MLP_vggish
# 0      T_0000023804  spoof                     1.000000
# 1      T_0000009556  spoof                     1.000000
# 2      T_0000009135  spoof                     1.000000
# 3      T_0000024330  spoof                     1.000000
# 4      T_0000008809  spoof                     1.000000
# ...             ...    ...                          ...
# 36495  T_0000015302  spoof                     1.000000
# 36496  T_0000016337  spoof                     1.000000
# 36497  T_0000009424  spoof                     0.999348
# 36498  T_0000013754  spoof                     1.000000
# 36499  T_0000035000  spoof                     1.000000
#
# [36500 rows x 3 columns]

# %%
train_vggish
# Out:
#            FileName  Label  train_probs_for1_MLP_vggish
# 0      T_0000023804  spoof                     1.000000
# 1      T_0000009556  spoof                     1.000000
# 2      T_0000009135  spoof                     1.000000
# 3      T_0000024330  spoof                     1.000000
# 4      T_0000008809  spoof                     1.000000
# ...             ...    ...                          ...
# 36495  T_0000015302  spoof                     1.000000
# 36496  T_0000016337  spoof                     1.000000
# 36497  T_0000009424  spoof                     0.999348
# 36498  T_0000013754  spoof                     1.000000
# 36499  T_0000035000  spoof                     1.000000
#
# [36500 rows x 3 columns]

# %%
df_matched_train
# Out:
#       Unnamed: 0 audio_filenames     Label
# 0              0    T_0000000000     spoof
# 1              1    T_0000000001     spoof
# 2              2    T_0000000002     spoof
# 3              3    T_0000000003     spoof
# 4              4    T_0000000004     spoof
# ...          ...             ...       ...
# 6995        6995    T_0000006995     spoof
# 6996        6996    T_0000006996     spoof
# 6997        6997    T_0000006997     spoof
# 6998        6998    T_0000006998  bonafide
# 6999        6999    T_0000006999     spoof
#
# [7000 rows x 3 columns]

# %%
train_vggish.rename(columns={'FileName': 'audio_filenames'}, inplace=True)

# %%
train_vggish
# Out:
#       audio_filenames  Label  train_probs_for1_MLP_vggish
# 0        T_0000023804  spoof                     1.000000
# 1        T_0000009556  spoof                     1.000000
# 2        T_0000009135  spoof                     1.000000
# 3        T_0000024330  spoof                     1.000000
# 4        T_0000008809  spoof                     1.000000
# ...               ...    ...                          ...
# 36495    T_0000015302  spoof                     1.000000
# 36496    T_0000016337  spoof                     1.000000
# 36497    T_0000009424  spoof                     0.999348
# 36498    T_0000013754  spoof                     1.000000
# 36499    T_0000035000  spoof                     1.000000
#
# [36500 rows x 3 columns]

# %%
df_train_merged = df_matched_train.merge(train_vggish, on='audio_filenames', how='left')

# %%
df_train_merged.to_csv('asvspoof5_y_train_pred_from_VGGish_matched_7000samples.csv', index=False)

# %%
#y_pred_vggish = train_vggish['train_probs_for1_MLP_vggish']

# %%
train_vggish
# Out:
#       Unnamed: 0 audio_filenames   Label_x   Label_y  \
# 0              0    T_0000000000     spoof     spoof
# 1              1    T_0000000001     spoof     spoof
# 2              2    T_0000000002     spoof     spoof
# 3              3    T_0000000003     spoof     spoof
# 4              4    T_0000000004     spoof     spoof
# ...          ...             ...       ...       ...
# 6995        6995    T_0000006995     spoof     spoof
# 6996        6996    T_0000006996     spoof     spoof
# 6997        6997    T_0000006997     spoof     spoof
# 6998        6998    T_0000006998  bonafide  bonafide
# 6999        6999    T_0000006999     spoof     spoof
#
#       train_probs_for1_MLP_vggish
# 0                    1.000000e+00
# 1                    1.000000e+00
# 2                    1.000000e+00
# 3                    9.999999e-01
# 4                    1.000000e+00
# ...                           ...
# 6995                 1.000000e+00
# 6996                 1.000000e+00
# 6997                 9.999282e-01
# 6998                 7.758906e-19
# 6999                 9.999102e-01
#
# [7000 rows x 5 columns]

# %%
(train_vggish['train_probs_for1_MLP_vggish'] < 0.5).sum()
# Out:
# np.int64(3820)

# %%
test_vggish
# Out:
#        FileName               speaker      Label  test_probs_for1_MLP_vggish
# 0         16720         Ronald Reagan      spoof                    1.000000
# 1         23893         Alec Guinness  bona-fide                    0.999698
# 2          4329          Barack Obama  bona-fide                    0.999986
# 3          6647         Richard Nixon      spoof                    1.000000
# 4         26991     Winston Churchill  bona-fide                    0.999097
# ...         ...                   ...        ...                         ...
# 31774     16768       Mark Zuckerberg      spoof                    0.999698
# 31775     15093    Queen Elizabeth II      spoof                    1.000000
# 31776      1532  Christopher Hitchens      spoof                    1.000000
# 31777      7310         Boris Johnson      spoof                    0.999100
# 31778     31216         Ronald Reagan  bona-fide                    1.000000
#
# [31779 rows x 4 columns]

# %%
y_pred_vggish_test = test_vggish['test_probs_for1_MLP_vggish']

# %%
y_pred_vggish_test
# Out:
# 0        1.000000
# 1        0.999698
# 2        0.999986
# 3        1.000000
# 4        0.999097
#            ...
# 31774    0.999698
# 31775    1.000000
# 31776    1.000000
# 31777    0.999100
# 31778    1.000000
# Name: test_probs_for1_MLP_vggish, Length: 31779, dtype: float64

# %%
test
# Out:
#        true_label_fake1_real0_lr  y_test_pred  FileName
# 0                              1     0.905350     16720
# 1                              0     0.911876     23893
# 2                              0     0.896563      4329
# 3                              1     0.929222      6647
# 4                              0     0.899787     26991
# ...                          ...          ...       ...
# 31774                          1     0.911876     16768
# 31775                          1     0.915452     15093
# 31776                          1     0.929222      1532
# 31777                          1     0.899801      7310
# 31778                          0     0.915278     31216
#
# [31779 rows x 3 columns]

# %%
#y_train = train['true_label_fake1_real0']

# %%
y_pred_aliras = train['y_train_pred']

# %%
y_test = test['true_label_fake1_real0_lr']

# %%
y_pred_aliras_test = test['y_test_pred']

# %%
y_pred_aliras
# Out:
# 0       0.689496
# 1       0.716402
# 2       0.395948
# 3       0.472303
# 4       0.399888
#           ...
# 6995    0.453467
# 6996    0.428176
# 6997    0.406310
# 6998    0.411814
# 6999    0.438849
# Name: y_train_pred, Length: 7000, dtype: float64

# %%
y_pred_vggish = df_train_merged['train_probs_for1_MLP_vggish']

# %%
# Step 1: Determine the weights
weight1 = 1  # Weight for y_pred_vggish
weight2 = 0.0  # Weight for y_test_pred

# Step 2: Combine the predictions
ensemble_prediction = (weight1 * y_pred_vggish) + (weight2 * y_pred_aliras)

roc_auc = roc_auc_score(y_train, ensemble_prediction)

print("ROC AUC Score:", roc_auc)
# Out:
# ROC AUC Score: 0.999990772482685

# %%
ensemble_prediction_test = (weight1 * y_pred_vggish_test) + (weight2 * y_pred_aliras_test)

roc_auc = roc_auc_score(y_test, ensemble_prediction_test)

print("ROC AUC Score:", roc_auc)
# Out:
# ROC AUC Score: 0.6176503185429266

# %%
# Step 1: Determine the weights
weight1 = 0.8  # Weight for y_pred_lfcc
weight2 = 0.2  # Weight for y_test_pred

# Step 2: Combine the predictions
ensemble_prediction = (weight1 * y_pred_vggish) + (weight2 * y_pred_aliras)

roc_auc = roc_auc_score(y_train, ensemble_prediction)

print("ROC AUC Score:", roc_auc)
# Out:
# ROC AUC Score: 0.9999860514273144

# %%
ensemble_prediction_test = (weight1 * y_pred_vggish_test) + (weight2 * y_pred_aliras_test)

roc_auc = roc_auc_score(y_test, ensemble_prediction_test)

print("ROC AUC Score:", roc_auc)
# Out:
# ROC AUC Score: 0.5838116167414796

# %%
compute_eer(y_train, ensemble_prediction)
# Out:
# (np.float64(0.0010708211953926582), np.float64(0.455410128))

# %%
compute_eer_fixed_threshold(y_test, ensemble_prediction_test, 0.455410128)
# Out:
# np.float64(0.5)

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
models = ['Mel', 'MFCC', 'LogSpec', 'LFCC', 'CQT', 'LEAF', 'SincNet',
          'EnCodec', 'AudioDec', 'AudioMAE', 'XLS-R', 'Hubert', 'WavLM',
          'Whisper', 'VGGish+MLP', 'VGGish+MLP|ALiRAS']
eer = [20.13, 27.27, 20.62, 25.67, 20.75, 21.54, 20.78,
       24.93, 26.13, 30.47, 11.78, 14.76, 15.53, 23.28, 25.95, 25.97]

sorted_indices = np.argsort(eer)
models = [models[i] for i in sorted_indices]
eer = [eer[i] for i in sorted_indices]

colors = ['red' if ('VGGish' in model) else 'skyblue' for model in models]

plt.figure(figsize=(12, 8))
bars = plt.barh(models, eer, color=colors)

# Add value labels
for bar in bars:
    width = bar.get_width()
    plt.text(width + 0.3, bar.get_y() + bar.get_height()/2,
             f'{width:.2f}',
             ha='left', va='center')

plt.xlabel('Equal Error Rate (EER) (%)', fontsize=12)
plt.title('ASVspoof 2021 DF Evaluation: Model Performance Comparison', fontsize=14, pad=20)
plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.xlim(0, max(eer) + 5)
plt.tight_layout()

# Show plot
plt.show()

# %%
pip install seaborn
# Out:
# Collecting seaborn
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /nfs/ada/vjaneja/users/zkhanja1/.conda/envs/myenv/lib/python3.10/site-packages (from seaborn) (2.0.2)
# Requirement already satisfied: pandas>=1.2 in /nfs/ada/vjaneja/users/zkhanja1/.conda/envs/myenv/lib/python3.10/site-packages (from seaborn) (2.2.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /nfs/ada/vjaneja/users/zkhanja1/.conda/envs/myenv/lib/python3.10/site-packages (from seaborn) (3.10.1)
# Requirement already satisfied: contourpy>=1.0.1 in /nfs/ada/vjaneja/users/zkhanja1/.conda/envs/myenv/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /nfs/ada/vjaneja/users/zkhanja1/.conda/envs/myenv/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /nfs/ada/vjaneja/users/zkhanja1/.conda/envs/myenv/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /nfs/ada/vjaneja/users/zkhanja1/.conda/envs/myenv/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /nfs/ada/vjaneja/users/zkhanja1/.conda/envs/myenv/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.1)
# Requirement already satisfied: pillow>=8 in /nfs/ada/vjaneja/users/zkhanja1/.conda/envs/myenv/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /nfs/ada/vjaneja/users/zkhanja1/.conda/envs/myenv/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /nfs/ada/vjaneja/users/zkhanja1/.conda/envs/myenv/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in /nfs/ada/vjaneja/users/zkhanja1/.conda/envs/myenv/lib/python3.10/site-packages (from pandas>=1.2->seaborn) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /nfs/ada/vjaneja/users/zkhanja1/.conda/envs/myenv/lib/python3.10/site-packages (from pandas>=1.2->seaborn) (2025.1)
# Requirement already satisfied: six>=1.5 in /nfs/ada/vjaneja/users/zkhanja1/.conda/envs/myenv/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # ALiRAS + SSL models

# %%
y_train_pred
# Out:
# array([0.68949701, 0.71640263, 0.39594781, ..., 0.40631021, 0.41181392,
#        0.43884842], shape=(7000,))

# %%
y_train_aliras = y_train_pred

# %%
y_test_aliras = y_test_pred

# %%
y_test_aliras
# Out:
# 0        0.905350
# 1        0.911876
# 2        0.896563
# 3        0.929222
# 4        0.899787
#            ...
# 31774    0.911876
# 31775    0.915452
# 31776    0.929222
# 31777    0.899801
# 31778    0.915278
# Name: y_test_pred, Length: 31779, dtype: float64

# %%
y_test_aliras.shape
# Out:
# (31779,)

# %%
y_train_xlsr = pd.read_csv('ITW_train_predictions_xlsr_resnet18_asvspoof5_as_train.csv')

# %%
y_test_xlsr = pd.read_csv('ITW_test_predictions_xlsr_resnet18.csv')

# %%
y_train_xlsr
# Out:
#      audio_filenames  prob_spoof
# 0       T_0000000000    0.692673
# 1       T_0000000001    0.757853
# 2       T_0000000002    0.689329
# 3       T_0000000003    0.723492
# 4       T_0000000004    0.676550
# ...              ...         ...
# 6996    T_0000006996    0.722816
# 6997    T_0000006997    0.529187
# 6998    T_0000006998    0.586431
# 6999    T_0000006999    0.839899
# 7000    T_0000007000    0.609588
#
# [7001 rows x 2 columns]

# %%
y_train_hubert = pd.read_csv('ITW_train_predictions_hubert_resnet18_asvspoof5_as_train.csv')

# %%
y_test_hubert = pd.read_csv('ITW_test_predictions_hubert_resnet18.csv')

# %%
y_test_hubert
# Out:
#        audio_filenames  prob_spoof
# 0                    0    0.002993
# 1                    1    0.000027
# 2                   10    0.000025
# 3                  100    0.001600
# 4                 1000    0.000124
# ...                ...         ...
# 31772             9993    0.032006
# 31773             9994    0.003858
# 31774             9995    0.000050
# 31775             9996    0.000005
# 31776             9997    0.000019
#
# [31777 rows x 2 columns]

# %%
y_test
# Out:
# 0        1
# 1        0
# 2        0
# 3        1
# 4        0
#         ..
# 31774    1
# 31775    1
# 31776    1
# 31777    1
# 31778    0
# Name: true_label_fake1_real0_lr, Length: 31779, dtype: int64

# %%
y_train_hubert
# Out:
#      audio_filenames    prob_spoof
# 0       T_0000000000  8.505160e-02
# 1       T_0000000001  7.034008e-03
# 2       T_0000000002  8.284410e-05
# 3       T_0000000003  1.979008e-04
# 4       T_0000000004  1.500772e-03
# ...              ...           ...
# 6995    T_0000006995  4.790197e-04
# 6996    T_0000006996  1.069985e-03
# 6997    T_0000006997  4.019097e-03
# 6998    T_0000006998  2.852866e-08
# 6999    T_0000006999  1.048004e-04
#
# [7000 rows x 2 columns]

# %%
y_test_xlsr
# Out:
#        audio_filenames  prob_spoof
# 0                    0    0.786643
# 1                    1    0.737604
# 2                   10    0.726019
# 3                  100    0.779081
# 4                 1000    0.829804
# ...                ...         ...
# 31772             9993    0.794828
# 31773             9994    0.771972
# 31774             9995    0.801221
# 31775             9996    0.798714
# 31776             9997    0.715364
#
# [31777 rows x 2 columns]

# %%
df_train = y_train_xlsr

# %%
y_train_hubert
# Out:
#      audio_filenames    prob_spoof
# 0       T_0000000000  8.505160e-02
# 1       T_0000000001  7.034008e-03
# 2       T_0000000002  8.284410e-05
# 3       T_0000000003  1.979008e-04
# 4       T_0000000004  1.500772e-03
# ...              ...           ...
# 6995    T_0000006995  4.790197e-04
# 6996    T_0000006996  1.069985e-03
# 6997    T_0000006997  4.019097e-03
# 6998    T_0000006998  2.852866e-08
# 6999    T_0000006999  1.048004e-04
#
# [7000 rows x 2 columns]

# %%
y_train_hubert = y_train_hubert.rename(columns={'prob_spoof': 'prob_spoof_hubert'})

# %%
y_test_hubert = y_test_hubert.rename(columns={'prob_spoof': 'prob_spoof_hubert'})

# %%
df_test = y_test_xlsr

# %%
#df_test.drop(columns=["prob_spoof_hubert"], inplace=True)

# %%
df_test
# Out:
#        audio_filenames  prob_spoof
# 0                    0    0.786643
# 1                    1    0.737604
# 2                   10    0.726019
# 3                  100    0.779081
# 4                 1000    0.829804
# ...                ...         ...
# 31772             9993    0.794828
# 31773             9994    0.771972
# 31774             9995    0.801221
# 31775             9996    0.798714
# 31776             9997    0.715364
#
# [31777 rows x 2 columns]

# %%
y_train_hubert
# Out:
#      audio_filenames  prob_spoof_hubert
# 0       T_0000000000       8.505160e-02
# 1       T_0000000001       7.034008e-03
# 2       T_0000000002       8.284410e-05
# 3       T_0000000003       1.979008e-04
# 4       T_0000000004       1.500772e-03
# ...              ...                ...
# 6995    T_0000006995       4.790197e-04
# 6996    T_0000006996       1.069985e-03
# 6997    T_0000006997       4.019097e-03
# 6998    T_0000006998       2.852866e-08
# 6999    T_0000006999       1.048004e-04
#
# [7000 rows x 2 columns]

# %%
df_train['prob_spoof_hubert'] = y_train_hubert['prob_spoof_hubert']

# %%
df_test['prob_spoof_hubert'] = y_test_hubert['prob_spoof_hubert']

# %%
df_test
# Out:
#        audio_filenames  prob_spoof  prob_spoof_hubert
# 0                    0    0.786643           0.002993
# 1                    1    0.737604           0.000027
# 2                   10    0.726019           0.000025
# 3                  100    0.779081           0.001600
# 4                 1000    0.829804           0.000124
# ...                ...         ...                ...
# 31772             9993    0.794828           0.032006
# 31773             9994    0.771972           0.003858
# 31774             9995    0.801221           0.000050
# 31775             9996    0.798714           0.000005
# 31776             9997    0.715364           0.000019
#
# [31777 rows x 3 columns]

# %%
y_train_xlsr.shape
# Out:
# (7001, 3)

# %%
df_train['prob_spoof_aliras'] = y_train_aliras

# %%
a_y = pd.read_csv('ITW_y_test_pred_from_aliras_labels_LR.csv')

# %%
a_y.rename(columns={'FileName': 'audio_filenames', 'y_test_pred': 'y_test_pred_aliras'}, inplace=True)

# %%
a_y
# Out:
#        true_label_fake1_real0_lr  y_test_pred_aliras  audio_filenames
# 0                              1            0.905350            16720
# 1                              0            0.911876            23893
# 2                              0            0.896563             4329
# 3                              1            0.929222             6647
# 4                              0            0.899787            26991
# ...                          ...                 ...              ...
# 31774                          1            0.911876            16768
# 31775                          1            0.915452            15093
# 31776                          1            0.929222             1532
# 31777                          1            0.899801             7310
# 31778                          0            0.915278            31216
#
# [31779 rows x 3 columns]

# %%
df_test2 = df_test.merge(a_y, on='audio_filenames', how='left')

# %%
df_test2
# Out:
#        audio_filenames  prob_spoof  prob_spoof_hubert  \
# 0                    0    0.786643           0.002993
# 1                    1    0.737604           0.000027
# 2                   10    0.726019           0.000025
# 3                  100    0.779081           0.001600
# 4                 1000    0.829804           0.000124
# ...                ...         ...                ...
# 31772             9993    0.794828           0.032006
# 31773             9994    0.771972           0.003858
# 31774             9995    0.801221           0.000050
# 31775             9996    0.798714           0.000005
# 31776             9997    0.715364           0.000019
#
#        true_label_fake1_real0_lr  y_test_pred_aliras
# 0                              1            0.899801
# 1                              1            0.910893
# 2                              1            0.929222
# 3                              0            0.911881
# 4                              0            0.911876
# ...                          ...                 ...
# 31772                          1            0.911876
# 31773                          0            0.915452
# 31774                          1            0.899801
# 31775                          0            0.911876
# 31776                          1            0.905352
#
# [31777 rows x 5 columns]

# %%
df_train
# Out:
#      audio_filenames  prob_spoof  prob_spoof_hubert  prob_spoof_aliras
# 0       T_0000000000    0.692673       8.505160e-02           0.689496
# 1       T_0000000001    0.757853       7.034008e-03           0.716402
# 2       T_0000000002    0.689329       8.284410e-05           0.395948
# 3       T_0000000003    0.723492       1.979008e-04           0.472303
# 4       T_0000000004    0.676550       1.500772e-03           0.399888
# ...              ...         ...                ...                ...
# 6996    T_0000006996    0.722816       1.069985e-03           0.428176
# 6997    T_0000006997    0.529187       4.019097e-03           0.406310
# 6998    T_0000006998    0.586431       2.852866e-08           0.411814
# 6999    T_0000006999    0.839899       1.048004e-04           0.438849
# 7000    T_0000007000    0.609588                NaN                NaN
#
# [7001 rows x 4 columns]

# %%
df_test = df_test2

# %%
df_test
# Out:
#        audio_filenames  prob_spoof  prob_spoof_hubert  \
# 0                    0    0.786643           0.002993
# 1                    1    0.737604           0.000027
# 2                   10    0.726019           0.000025
# 3                  100    0.779081           0.001600
# 4                 1000    0.829804           0.000124
# ...                ...         ...                ...
# 31772             9993    0.794828           0.032006
# 31773             9994    0.771972           0.003858
# 31774             9995    0.801221           0.000050
# 31775             9996    0.798714           0.000005
# 31776             9997    0.715364           0.000019
#
#        true_label_fake1_real0_lr  y_test_pred_aliras
# 0                              1            0.899801
# 1                              1            0.910893
# 2                              1            0.929222
# 3                              0            0.911881
# 4                              0            0.911876
# ...                          ...                 ...
# 31772                          1            0.911876
# 31773                          0            0.915452
# 31774                          1            0.899801
# 31775                          0            0.911876
# 31776                          1            0.905352
#
# [31777 rows x 5 columns]

# %%
a_t = pd.read_csv('asvspoof5_DF_labels_corresponding_to_hubert_7000_train.csv')

# %%
a_t
# Out:
#       Unnamed: 0 audio_filenames     Label
# 0              0    T_0000000000     spoof
# 1              1    T_0000000001     spoof
# 2              2    T_0000000002     spoof
# 3              3    T_0000000003     spoof
# 4              4    T_0000000004     spoof
# ...          ...             ...       ...
# 6995        6995    T_0000006995     spoof
# 6996        6996    T_0000006996     spoof
# 6997        6997    T_0000006997     spoof
# 6998        6998    T_0000006998  bonafide
# 6999        6999    T_0000006999     spoof
#
# [7000 rows x 3 columns]

# %%
df_train2 = df_train.merge(a_t, on='audio_filenames', how='left')

# %%
df_train = df_train2

# %%
y_train = df_train['Label'].map({'spoof': 1, 'bonafide': 0})

# %%
y_train = y_train.dropna()

# %%
y_train
# Out:
# 0       1.0
# 1       1.0
# 2       1.0
# 3       1.0
# 4       1.0
#        ...
# 6995    1.0
# 6996    1.0
# 6997    1.0
# 6998    0.0
# 6999    1.0
# Name: Label, Length: 7000, dtype: float64

# %%
y_test
# Out:
# 0        1
# 1        0
# 2        0
# 3        1
# 4        0
#         ..
# 31774    1
# 31775    1
# 31776    1
# 31777    1
# 31778    0
# Name: true_label_fake1_real0_lr, Length: 31779, dtype: int64

# %%
y_test = df_test['true_label_fake1_real0_lr']

# %%
df_test
# Out:
#        audio_filenames  prob_spoof  prob_spoof_hubert  \
# 0                    0    0.786643           0.002993
# 1                    1    0.737604           0.000027
# 2                   10    0.726019           0.000025
# 3                  100    0.779081           0.001600
# 4                 1000    0.829804           0.000124
# ...                ...         ...                ...
# 31772             9993    0.794828           0.032006
# 31773             9994    0.771972           0.003858
# 31774             9995    0.801221           0.000050
# 31775             9996    0.798714           0.000005
# 31776             9997    0.715364           0.000019
#
#        true_label_fake1_real0_lr  y_test_pred_aliras
# 0                              1            0.899801
# 1                              1            0.910893
# 2                              1            0.929222
# 3                              0            0.911881
# 4                              0            0.911876
# ...                          ...                 ...
# 31772                          1            0.911876
# 31773                          0            0.915452
# 31774                          1            0.899801
# 31775                          0            0.911876
# 31776                          1            0.905352
#
# [31777 rows x 5 columns]

# %%
df_test = df_test.rename(columns={'prob_spoof': 'prob_spoof_xlsr'})

# %%
df_train
# Out:
#      audio_filenames  prob_spoof  prob_spoof_hubert  prob_spoof_aliras  \
# 0       T_0000000000    0.692673       8.505160e-02           0.689496
# 1       T_0000000001    0.757853       7.034008e-03           0.716402
# 2       T_0000000002    0.689329       8.284410e-05           0.395948
# 3       T_0000000003    0.723492       1.979008e-04           0.472303
# 4       T_0000000004    0.676550       1.500772e-03           0.399888
# ...              ...         ...                ...                ...
# 6996    T_0000006996    0.722816       1.069985e-03           0.428176
# 6997    T_0000006997    0.529187       4.019097e-03           0.406310
# 6998    T_0000006998    0.586431       2.852866e-08           0.411814
# 6999    T_0000006999    0.839899       1.048004e-04           0.438849
# 7000    T_0000007000    0.609588                NaN                NaN
#
#       Unnamed: 0     Label
# 0            0.0     spoof
# 1            1.0     spoof
# 2            2.0     spoof
# 3            3.0     spoof
# 4            4.0     spoof
# ...          ...       ...
# 6996      6996.0     spoof
# 6997      6997.0     spoof
# 6998      6998.0  bonafide
# 6999      6999.0     spoof
# 7000         NaN       NaN
#
# [7001 rows x 6 columns]

# %%
df_train = df_train.rename(columns={'prob_spoof': 'prob_spoof_xlsr'})

# %%
df_test
# Out:
#        audio_filenames  prob_spoof_xlsr  prob_spoof_hubert  \
# 0                    0         0.786643           0.002993
# 1                    1         0.737604           0.000027
# 2                   10         0.726019           0.000025
# 3                  100         0.779081           0.001600
# 4                 1000         0.829804           0.000124
# ...                ...              ...                ...
# 31772             9993         0.794828           0.032006
# 31773             9994         0.771972           0.003858
# 31774             9995         0.801221           0.000050
# 31775             9996         0.798714           0.000005
# 31776             9997         0.715364           0.000019
#
#        true_label_fake1_real0_lr  y_test_pred_aliras
# 0                              1            0.899801
# 1                              1            0.910893
# 2                              1            0.929222
# 3                              0            0.911881
# 4                              0            0.911876
# ...                          ...                 ...
# 31772                          1            0.911876
# 31773                          0            0.915452
# 31774                          1            0.899801
# 31775                          0            0.911876
# 31776                          1            0.905352
#
# [31777 rows x 5 columns]

# %%
df_test.to_csv('ITW_ready_SSL_and_Aliras_for_ensemble.csv', index=False)

# %%
df_train.to_csv('asvspoof5_ready_SSL_and_Aliras_for_ensemble.csv', index=False)

# %%
df_test = pd.read_csv('ITW_ready_SSL_and_Aliras_for_ensemble.csv')

# %%
df_train = pd.read_csv('asvspoof5_ready_SSL_and_Aliras_for_ensemble.csv')

# %%
y_test = df_test['true_label_fake1_real0_lr']

# %%
df_train
# Out:
#      audio_filenames  prob_spoof_xlsr  prob_spoof_hubert  prob_spoof_aliras  \
# 0       T_0000000000         0.692673       8.505160e-02           0.689496
# 1       T_0000000001         0.757853       7.034008e-03           0.716402
# 2       T_0000000002         0.689329       8.284410e-05           0.395948
# 3       T_0000000003         0.723492       1.979008e-04           0.472303
# 4       T_0000000004         0.676550       1.500772e-03           0.399888
# ...              ...              ...                ...                ...
# 6995    T_0000006995         0.809991       4.790197e-04           0.453467
# 6996    T_0000006996         0.722816       1.069985e-03           0.428176
# 6997    T_0000006997         0.529187       4.019097e-03           0.406310
# 6998    T_0000006998         0.586431       2.852866e-08           0.411814
# 6999    T_0000006999         0.839899       1.048004e-04           0.438849
#
#       Unnamed: 0     Label
# 0            0.0     spoof
# 1            1.0     spoof
# 2            2.0     spoof
# 3            3.0     spoof
# 4            4.0     spoof
# ...          ...       ...
# 6995      6995.0     spoof
# 6996      6996.0     spoof
# 6997      6997.0     spoof
# 6998      6998.0  bonafide
# 6999      6999.0     spoof
#
# [7000 rows x 6 columns]

# %%
roc_auc = roc_auc_score(df_test['true_label_fake1_real0_lr'], df_test['prob_spoof_hubert'])

print("ROC AUC Score:", roc_auc)
# Out:
# ROC AUC Score: 0.6436896735197638

# %%
#df_train.to_csv('asvspoof5_outputs_for_ensemble_7000samples_train.csv', index=False)

# %%
#df_train = pd.read_csv('asvspoof5_outputs_for_ensemble_7000samples_train.csv')

# %%
df_train = df_train.iloc[:-1]

# %%
roc_auc = roc_auc_score(y_train, df_train['prob_spoof_hubert'])

print("ROC AUC Score:", roc_auc)
# Out:
# ROC AUC Score: 0.9999712444809253

# %%
roc_auc = roc_auc_score(df_test['true_label_fake1_real0_lr'], df_test['prob_spoof_xlsr'])

print("ROC AUC Score:", roc_auc)
# Out:
# ROC AUC Score: 0.4700999079800499

# %%
roc_auc = roc_auc_score(y_train, df_train['prob_spoof_xlsr'])

print("ROC AUC Score:", roc_auc)
# Out:
# ROC AUC Score: 0.9491719376176911

# %%
y_train_aliras
# Out:
# 0       0.689496
# 1       0.716402
# 2       0.395948
# 3       0.472303
# 4       0.399888
#           ...
# 6995    0.453467
# 6996    0.428176
# 6997    0.406310
# 6998    0.411814
# 6999    0.438849
# Name: y_train_pred, Length: 7000, dtype: float64

# %%
df_test
# Out:
#        audio_filenames  prob_spoof_xlsr  prob_spoof_hubert  \
# 0                    0         0.786643           0.002993
# 1                    1         0.737604           0.000027
# 2                   10         0.726019           0.000025
# 3                  100         0.779081           0.001600
# 4                 1000         0.829804           0.000124
# ...                ...              ...                ...
# 31772             9993         0.794828           0.032006
# 31773             9994         0.771972           0.003858
# 31774             9995         0.801221           0.000050
# 31775             9996         0.798714           0.000005
# 31776             9997         0.715364           0.000019
#
#        true_label_fake1_real0_lr  y_test_pred_aliras
# 0                              1            0.899801
# 1                              1            0.910893
# 2                              1            0.929222
# 3                              0            0.911881
# 4                              0            0.911876
# ...                          ...                 ...
# 31772                          1            0.911876
# 31773                          0            0.915452
# 31774                          1            0.899801
# 31775                          0            0.911876
# 31776                          1            0.905352
#
# [31777 rows x 5 columns]

# %%
train_probs_aliras = df_train['prob_spoof_aliras']
test_probs_aliras = df_test['y_test_pred_aliras']

# %%
train_probs_hubert = df_train['prob_spoof_hubert']
test_probs_hubert = df_test['prob_spoof_hubert']

# %%
train_probs_xlsr = df_train['prob_spoof_xlsr']
test_probs_xlsr = df_test['prob_spoof_xlsr']

# %%
y_train = df_train['Label']

# %%
y_train = y_train.map({'spoof': 1, 'bonafide': 0})

# %%
# Step 1: Determine the weights
weight1 = 0.5
weight2 = 0.5

# Step 2: Combine the predictions
ensemble_prediction_hubert = (weight1 * train_probs_hubert) + (weight2 * train_probs_aliras)

roc_auc = roc_auc_score(y_train, ensemble_prediction_hubert)

print("ROC AUC Score:", roc_auc)
# Out:
# ROC AUC Score: 0.7606375570684392

# %%
#test_probs is from vggish only
ensemble_prediction_test_hubert = (weight1 * test_probs_hubert) + (weight2 * test_probs_aliras)

roc_auc = roc_auc_score(y_test, ensemble_prediction_test_hubert)

print("ROC AUC Score:", roc_auc)
# Out:
# ROC AUC Score: 0.6889407521349387

# %%
pwd&&
# Out:
# '/umbc/rs/iharp/users/zkhanja1/asvspoof5_codes'

# %%
compute_eer(y_train, ensemble_prediction_hubert)
# Out:
# (np.float64(0.3182130805422776), np.float64(0.17843346529173862))

# %%
compute_eer_fixed_threshold(y_test, ensemble_prediction_test_hubert, 0.178)
# Out:
# np.float64(0.5)

# %%
#df_train_final['prob_spoof_from_aliras_hubert'] =  ensemble_prediction_hubert

# %%
#df_test_final['prob_spoof_from_aliras_hubert'] =  ensemble_prediction_test_hubert

# %%
weight1 = 0.6
weight2 = 0.4

# Step 2: Combine the predictions
ensemble_prediction_xlsr = (weight1 * train_probs_xlsr) + (weight2 * train_probs_aliras)

roc_auc = roc_auc_score(y_train, ensemble_prediction_xlsr)

print("ROC AUC Score for train:", roc_auc)
ensemble_prediction_test_xlsr = (weight1 * test_probs_xlsr) + (weight2 * test_probs_aliras)

roc_auc = roc_auc_score(y_test, ensemble_prediction_test_xlsr)

print("ROC AUC Score for test:", roc_auc)
compute_eer(y_train, ensemble_prediction_xlsr)
# Out:
# ROC AUC Score for train: 0.9422286600250002
# ROC AUC Score for test: 0.48229796791644286
# (np.float64(0.12369540609123442), np.float64(0.564151))

# %%
weight1 = 0.5
weight2 = 0.5

# Step 2: Combine the predictions
ensemble_prediction_xlsr = (weight1 * train_probs_xlsr) + (weight2 * train_probs_aliras)

roc_auc = roc_auc_score(y_train, ensemble_prediction_xlsr)

print("ROC AUC Score for train:", roc_auc)
ensemble_prediction_test_xlsr = (weight1 * test_probs_xlsr) + (weight2 * test_probs_aliras)

roc_auc = roc_auc_score(y_test, ensemble_prediction_test_xlsr)

print("ROC AUC Score for test:", roc_auc)
compute_eer(y_train, ensemble_prediction_xlsr)
# Out:
# ROC AUC Score for train: 0.9309803164180066
# ROC AUC Score for test: 0.49128143091001125
# (np.float64(0.13131937403097654), np.float64(0.5429414349999999))

# %%
compute_eer_fixed_threshold(y_test, ensemble_prediction_test_xlsr, 0.23462375800000002)
# Out:
# np.float64(0.5)

# %%
compute_eer(y_train, train_probs_xlsr)
# Out:
# (np.float64(0.18649402625550565), np.float64(0.0841032))

# %%
compute_eer_fixed_threshold(y_test, test_probs_xlsr, 0.23462375800000002)
# Out:
# np.float64(0.5000423190859078)

# %%
ensemble_prediction_test_hubert
# Out:
# 0        0.361716
# 1        0.364373
# 2        0.371704
# 3        0.365712
# 4        0.364825
#            ...
# 31772    0.383954
# 31773    0.368496
# 31774    0.359950
# 31775    0.364753
# 31776    0.362152
# Length: 31777, dtype: float64

# %%
weight1 = 0.5
weight2 = 0.5

# Step 2: Combine the predictions
ensemble_prediction_ssl = (weight1 * train_probs_xlsr) + (weight2 * train_probs_hubert)

roc_auc = roc_auc_score(y_train, ensemble_prediction_ssl)

print("ROC AUC Score for train:", roc_auc)
ensemble_prediction_test_ssl = (weight1 * test_probs_xlsr) + (weight2 * test_probs_hubert)

roc_auc = roc_auc_score(y_test, ensemble_prediction_test_ssl)

print("ROC AUC Score for test:", roc_auc)
compute_eer(y_train, ensemble_prediction_ssl)
# Out:
# ROC AUC Score for train: 0.955329159491199
# ROC AUC Score for test: 0.5262581893324781
# (np.float64(0.1142811924956679), np.float64(0.3191506051240895))

# %%
compute_eer_fixed_threshold(y_test, ensemble_prediction_test_ssl, 0.3191506051240895)
# Out:
# np.float64(0.5058564001183289)

# %%
df_train
# Out:
#      audio_filenames  prob_spoof_xlsr  prob_spoof_hubert  prob_spoof_aliras  \
# 0       T_0000000000         0.692673       8.505160e-02           0.689496
# 1       T_0000000001         0.757853       7.034008e-03           0.716402
# 2       T_0000000002         0.689329       8.284410e-05           0.395948
# 3       T_0000000003         0.723492       1.979008e-04           0.472303
# 4       T_0000000004         0.676550       1.500772e-03           0.399888
# ...              ...              ...                ...                ...
# 6995    T_0000006995         0.809991       4.790197e-04           0.453467
# 6996    T_0000006996         0.722816       1.069985e-03           0.428176
# 6997    T_0000006997         0.529187       4.019097e-03           0.406310
# 6998    T_0000006998         0.586431       2.852866e-08           0.411814
# 6999    T_0000006999         0.839899       1.048004e-04           0.438849
#
#       Unnamed: 0     Label
# 0            0.0     spoof
# 1            1.0     spoof
# 2            2.0     spoof
# 3            3.0     spoof
# 4            4.0     spoof
# ...          ...       ...
# 6995      6995.0     spoof
# 6996      6996.0     spoof
# 6997      6997.0     spoof
# 6998      6998.0  bonafide
# 6999      6999.0     spoof
#
# [7000 rows x 6 columns]

# %%
cost_efficient_hubert_aliras_train = df_train.apply(
    lambda row: 1 if row['prob_spoof_aliras'] > 0.55 else row['prob_spoof_hubert'],
    axis=1
)


roc_auc = roc_auc_score(y_train, cost_efficient_hubert_aliras_train)

print("ROC AUC Score for train:", roc_auc)
compute_eer(y_train, cost_efficient_hubert_aliras_train)
cost_efficient_hubert_aliras_test = df_test.apply(
    lambda row: 1 if row['y_test_pred_aliras'] > 0.55 else row['prob_spoof_hubert'],
    axis=1
)


roc_auc = roc_auc_score(y_test, cost_efficient_hubert_aliras_test)
print("ROC AUC Score for test:", roc_auc)

compute_eer_fixed_threshold(y_test, cost_efficient_hubert_aliras_test, 0.9999)
# Out:
# ROC AUC Score for train: 0.951031282356665
# ROC AUC Score for test: 0.5
# np.float64(0.5)

# %%
cost_efficient_hubert_aliras_train = df_train.apply(
    lambda row: 1 if row['prob_spoof_aliras'] > 0.7 else row['prob_spoof_hubert'],
    axis=1
)


roc_auc = roc_auc_score(y_train, cost_efficient_hubert_aliras_train)

print("ROC AUC Score for train:", roc_auc)
compute_eer(y_train, cost_efficient_hubert_aliras_train)
# Out:
# ROC AUC Score for train: 0.9824457212753287
# (np.float64(0.014623469010026882), np.float64(5.2951846e-06))

# %%
df_test
# Out:
#        audio_filenames  prob_spoof_xlsr  prob_spoof_hubert  \
# 0                    0         0.786643           0.002993
# 1                    1         0.737604           0.000027
# 2                   10         0.726019           0.000025
# 3                  100         0.779081           0.001600
# 4                 1000         0.829804           0.000124
# ...                ...              ...                ...
# 31772             9993         0.794828           0.032006
# 31773             9994         0.771972           0.003858
# 31774             9995         0.801221           0.000050
# 31775             9996         0.798714           0.000005
# 31776             9997         0.715364           0.000019
#
#        true_label_fake1_real0_lr  y_test_pred_aliras
# 0                              1            0.899801
# 1                              1            0.910893
# 2                              1            0.929222
# 3                              0            0.911881
# 4                              0            0.911876
# ...                          ...                 ...
# 31772                          1            0.911876
# 31773                          0            0.915452
# 31774                          1            0.899801
# 31775                          0            0.911876
# 31776                          1            0.905352
#
# [31777 rows x 5 columns]

# %%
df
# Out:
#        audio_filenames  prob_spoof_xlsr  prob_spoof_hubert  \
# 0                    0         0.786643           0.002993
# 1                    1         0.737604           0.000027
# 2                   10         0.726019           0.000025
# 3                  100         0.779081           0.001600
# 4                 1000         0.829804           0.000124
# ...                ...              ...                ...
# 31772             9993         0.794828           0.032006
# 31773             9994         0.771972           0.003858
# 31774             9995         0.801221           0.000050
# 31775             9996         0.798714           0.000005
# 31776             9997         0.715364           0.000019
#
#        true_label_fake1_real0  y_test_pred_aliras  \
# 0                           1            0.899801
# 1                           1            0.910893
# 2                           1            0.929222
# 3                           0            0.911881
# 4                           0            0.911876
# ...                       ...                 ...
# 31772                       1            0.911876
# 31773                       0            0.915452
# 31774                       1            0.899801
# 31775                       0            0.911876
# 31776                       1            0.905352
#
#        prob_spoof_from_aliras_xlsr_0.5weight  \
# 0                                   0.843222
# 1                                   0.824249
# 2                                   0.827620
# 3                                   0.845481
# 4                                   0.870840
# ...                                      ...
# 31772                               0.853352
# 31773                               0.843712
# 31774                               0.850511
# 31775                               0.855295
# 31776                               0.810358
#
#        prob_spoof_from_aliras_hubert0.5weight  \
# 0                                    0.451397
# 1                                    0.455460
# 2                                    0.464623
# 3                                    0.456741
# 4                                    0.456000
# ...                                       ...
# 31772                                0.471941
# 31773                                0.459655
# 31774                                0.449925
# 31775                                0.455940
# 31776                                0.452685
#
#        cost_efficient_xlsr_aliras_thrshold0.9  \
# 0                                    0.786643
# 1                                    1.000000
# 2                                    1.000000
# 3                                    1.000000
# 4                                    1.000000
# ...                                       ...
# 31772                                1.000000
# 31773                                1.000000
# 31774                                0.801221
# 31775                                1.000000
# 31776                                1.000000
#
#        prob_spoof_from_aliras_hubert_cost_efficient_threshold0.9  \
# 0                                               0.002993
# 1                                               1.000000
# 2                                               1.000000
# 3                                               1.000000
# 4                                               1.000000
# ...                                                  ...
# 31772                                           1.000000
# 31773                                           1.000000
# 31774                                           0.000050
# 31775                                           1.000000
# 31776                                           1.000000
#
#                         speaker      Label  test_probs_for1_MLP_vggish
# 0                 Alec Guinness      spoof                    0.999100
# 1                 Alec Guinness      spoof                    1.000000
# 2                Bernie Sanders      spoof                    1.000000
# 3      Alexandria Ocasio-Cortez  bona-fide                    0.999699
# 4                  Barack Obama  bona-fide                    0.999698
# ...                         ...        ...                         ...
# 31772             Alec Guinness      spoof                    0.999698
# 31773                  Ayn Rand  bona-fide                    1.000000
# 31774            Bernie Sanders      spoof                    0.999100
# 31775             Frank Sinatra  bona-fide                    0.999698
# 31776                       JFK      spoof                    1.000000
#
# [31777 rows x 12 columns]

# %%
cost_efficient_hubert_aliras_test = df_test.apply(
    lambda row: 1 if row['y_test_pred_aliras'] > 0.7 else row['prob_spoof_hubert'],
    axis=1
)


roc_auc = roc_auc_score(y_test, cost_efficient_hubert_aliras_test)
print("ROC AUC Score for test:", roc_auc)

compute_eer_fixed_threshold(y_test, cost_efficient_hubert_aliras_test, 0.9999)
# Out:
# ROC AUC Score for test: 0.5
# np.float64(0.5)

# %%
cost_efficient_hubert_aliras_train = df_train.apply(
    lambda row: 1 if row['prob_spoof_aliras'] > 0.75 else row['prob_spoof_hubert'],
    axis=1
)


roc_auc = roc_auc_score(y_train, cost_efficient_hubert_aliras_train)

print("ROC AUC Score for train:", roc_auc)
compute_eer(y_train, cost_efficient_hubert_aliras_train)
cost_efficient_hubert_aliras_test = df_test.apply(
    lambda row: 1 if row['y_test_pred_aliras'] > 0.75 else row['prob_spoof_hubert'],
    axis=1
)


roc_auc = roc_auc_score(y_test, cost_efficient_hubert_aliras_test)
print("ROC AUC Score for test:", roc_auc)
# Out:
# ROC AUC Score for train: 0.9973280972537407
# ROC AUC Score for test: 0.5

# %%
cost_efficient_hubert_aliras_train = df_train.apply(
    lambda row: 1 if row['prob_spoof_aliras'] > 0.85 else row['prob_spoof_hubert'],
    axis=1
)


roc_auc = roc_auc_score(y_train, cost_efficient_hubert_aliras_train)

print("ROC AUC Score for train:", roc_auc)
compute_eer(y_train, cost_efficient_hubert_aliras_train)
cost_efficient_hubert_aliras_test = df_test.apply(
    lambda row: 1 if row['y_test_pred_aliras'] > 0.85 else row['prob_spoof_hubert'],
    axis=1
)


roc_auc = roc_auc_score(y_test, cost_efficient_hubert_aliras_test)
print("ROC AUC Score for test:", roc_auc)
# Out:
# ROC AUC Score for train: 0.9999712444809253
# ROC AUC Score for test: 0.5085599689770276

# %%
cost_efficient_hubert_aliras_train = df_train.apply(
    lambda row: 1 if row['prob_spoof_aliras'] > 0.9 else row['prob_spoof_hubert'],
    axis=1
)


roc_auc = roc_auc_score(y_train, cost_efficient_hubert_aliras_train)

print("ROC AUC Score for train:", roc_auc)
compute_eer(y_train, cost_efficient_hubert_aliras_train)
# Out:
# ROC AUC Score for train: 0.9999712444809253
# (np.float64(0.0023814505442625554), np.float64(1.3595401e-06))

# %%
cost_efficient_hubert_aliras_test = df_test.apply(
    lambda row: 1 if row['y_test_pred_aliras'] > 0.9 else row['prob_spoof_hubert'],
    axis=1
)


roc_auc = roc_auc_score(y_test, cost_efficient_hubert_aliras_test)
print("ROC AUC Score for test:", roc_auc)


compute_eer_fixed_threshold(y_test, cost_efficient_hubert_aliras_test, 1.3595401e-06)
# Out:
# ROC AUC Score for test: 0.5854207781072653
# np.float64(0.4741212238928954)

# %%
cost_efficient_xlsr_aliras_train = df_train.apply(
    lambda row: 1 if row['prob_spoof_aliras'] > 0.7 else row['prob_spoof_xlsr'],
    axis=1
)


roc_auc = roc_auc_score(y_train, cost_efficient_xlsr_aliras_train)

print("ROC AUC Score for train:", roc_auc)
compute_eer(y_train, cost_efficient_xlsr_aliras_train)
# Out:
# ROC AUC Score for train: 0.9410254346858082
# (np.float64(0.1181331444911185), np.float64(0.64152324))

# %%
cost_efficient_xlsr_aliras_test = df_test.apply(
    lambda row: 1 if row['y_test_pred_aliras'] > 0.7 else row['prob_spoof'],
    axis=1
)


roc_auc = roc_auc_score(y_test, cost_efficient_xlsr_aliras_test)
print("ROC AUC Score for test:", roc_auc)

compute_eer_fixed_threshold(y_test, cost_efficient_xlsr_aliras_test, 0.64152324)
# Out:
# ROC AUC Score for test: 0.5
# np.float64(0.5)

# %%
cost_efficient_xlsr_aliras_train = df_train.apply(
    lambda row: 1 if row['prob_spoof_aliras'] > 0.90 else row['prob_spoof_xlsr'],
    axis=1
)


roc_auc = roc_auc_score(y_train, cost_efficient_xlsr_aliras_train)

print("ROC AUC Score for train:", roc_auc)
compute_eer(y_train, cost_efficient_xlsr_aliras_train)
# Out:
# ROC AUC Score for train: 0.9491719376176911
# (np.float64(0.1251659075424224), np.float64(0.635293))

# %%
cost_efficient_xlsr_aliras_test = df_test.apply(
    lambda row: 1 if row['y_test_pred_aliras'] > 0.90 else row['prob_spoof_xlsr'],
    axis=1
)


roc_auc = roc_auc_score(y_test, cost_efficient_xlsr_aliras_test)
print("ROC AUC Score for test:", roc_auc)

compute_eer_fixed_threshold(y_test, cost_efficient_xlsr_aliras_test, 0.6355126)
# Out:
# ROC AUC Score for test: 0.5615575094160072
# np.float64(0.4996346019773583)

# %%
cost_efficient_xlsr_aliras_train = df_train.apply(
    lambda row: 1 if row['prob_spoof_aliras'] > 0.95 else row['prob_spoof_xlsr'],
    axis=1
)


roc_auc = roc_auc_score(y_train, cost_efficient_xlsr_aliras_train)

print("ROC AUC Score for train:", roc_auc)
compute_eer(y_train, cost_efficient_xlsr_aliras_train)
# Out:
# ROC AUC Score for train: 0.9491719376176911
# (np.float64(0.1251659075424224), np.float64(0.635293))

# %%
cost_efficient_xlsr_aliras_test = df_test.apply(
    lambda row: 1 if row['y_test_pred_aliras'] > 0.95 else row['prob_spoof_xlsr'],
    axis=1
)


roc_auc = roc_auc_score(y_test, cost_efficient_xlsr_aliras_test)
print("ROC AUC Score for test:", roc_auc)

compute_eer_fixed_threshold(y_test, cost_efficient_xlsr_aliras_test, 0.635293)
# Out:
# ROC AUC Score for test: 0.4700999079800499
# np.float64(0.5055904504635829)

# %%
df_test_final = df_test

# %%
df_test_final['prob_spoof_from_aliras_xlsr']= ensemble_prediction_test_xlsr
df_test_final['prob_spoof_from_aliras_hubert']= ensemble_prediction_test_hubert
df_test_final['cost_efficient_xlsr_aliras']=cost_efficient_xlsr_aliras_test
df_test_final['prob_spoof_from_aliras_hubert_cost_efficient']=cost_efficient_hubert_aliras_test

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

# %%
df_test
# Out:
#        audio_filenames  prob_spoof_xlsr  prob_spoof_hubert  \
# 0                    0         0.786643           0.002993
# 1                    1         0.737604           0.000027
# 2                   10         0.726019           0.000025
# 3                  100         0.779081           0.001600
# 4                 1000         0.829804           0.000124
# ...                ...              ...                ...
# 31772             9993         0.794828           0.032006
# 31773             9994         0.771972           0.003858
# 31774             9995         0.801221           0.000050
# 31775             9996         0.798714           0.000005
# 31776             9997         0.715364           0.000019
#
#        true_label_fake1_real0_lr  y_test_pred_aliras  \
# 0                              1            0.899801
# 1                              1            0.910893
# 2                              1            0.929222
# 3                              0            0.911881
# 4                              0            0.911876
# ...                          ...                 ...
# 31772                          1            0.911876
# 31773                          0            0.915452
# 31774                          1            0.899801
# 31775                          0            0.911876
# 31776                          1            0.905352
#
#        prob_spoof_from_aliras_xlsr  prob_spoof_from_aliras_hubert  \
# 0                         0.843222                       0.451397
# 1                         0.824249                       0.455460
# 2                         0.827620                       0.464623
# 3                         0.845481                       0.456741
# 4                         0.870840                       0.456000
# ...                            ...                            ...
# 31772                     0.853352                       0.471941
# 31773                     0.843712                       0.459655
# 31774                     0.850511                       0.449925
# 31775                     0.855295                       0.455940
# 31776                     0.810358                       0.452685
#
#        cost_efficient_xlsr_aliras  \
# 0                        0.786643
# 1                        1.000000
# 2                        1.000000
# 3                        1.000000
# 4                        1.000000
# ...                           ...
# 31772                    1.000000
# 31773                    1.000000
# 31774                    0.801221
# 31775                    1.000000
# 31776                    1.000000
#
#        prob_spoof_from_aliras_hubert_cost_efficient
# 0                                          0.002993
# 1                                          1.000000
# 2                                          1.000000
# 3                                          1.000000
# 4                                          1.000000
# ...                                             ...
# 31772                                      1.000000
# 31773                                      1.000000
# 31774                                      0.000050
# 31775                                      1.000000
# 31776                                      1.000000
#
# [31777 rows x 9 columns]

# %%
test_vggish = test_vggish.rename(columns={'FileName': 'audio_filenames'})

# %%
df_test_merged = df_test.merge(test_vggish, on='audio_filenames', how='left')

# %%
df_test_merged2 = df_test_merged.rename(columns={'true_label_fake1_real0_lr': 'true_label_fake1_real0', 'prob_spoof_from_aliras_xlsr':'prob_spoof_from_aliras_xlsr_0.5weight', 'prob_spoof_from_aliras_hubert':'prob_spoof_from_aliras_hubert0.5weight','cost_efficient_xlsr_aliras':'cost_efficient_xlsr_aliras_thrshold0.9','prob_spoof_from_aliras_hubert_cost_efficient':'prob_spoof_from_aliras_hubert_cost_efficient_threshold0.9'})

# %%
df_test_merged2
# Out:
#        audio_filenames  prob_spoof_xlsr  prob_spoof_hubert  \
# 0                    0         0.786643           0.002993
# 1                    1         0.737604           0.000027
# 2                   10         0.726019           0.000025
# 3                  100         0.779081           0.001600
# 4                 1000         0.829804           0.000124
# ...                ...              ...                ...
# 31772             9993         0.794828           0.032006
# 31773             9994         0.771972           0.003858
# 31774             9995         0.801221           0.000050
# 31775             9996         0.798714           0.000005
# 31776             9997         0.715364           0.000019
#
#        true_label_fake1_real0  y_test_pred_aliras  \
# 0                           1            0.899801
# 1                           1            0.910893
# 2                           1            0.929222
# 3                           0            0.911881
# 4                           0            0.911876
# ...                       ...                 ...
# 31772                       1            0.911876
# 31773                       0            0.915452
# 31774                       1            0.899801
# 31775                       0            0.911876
# 31776                       1            0.905352
#
#        prob_spoof_from_aliras_xlsr_0.5weight  \
# 0                                   0.843222
# 1                                   0.824249
# 2                                   0.827620
# 3                                   0.845481
# 4                                   0.870840
# ...                                      ...
# 31772                               0.853352
# 31773                               0.843712
# 31774                               0.850511
# 31775                               0.855295
# 31776                               0.810358
#
#        prob_spoof_from_aliras_hubert0.5weight  \
# 0                                    0.451397
# 1                                    0.455460
# 2                                    0.464623
# 3                                    0.456741
# 4                                    0.456000
# ...                                       ...
# 31772                                0.471941
# 31773                                0.459655
# 31774                                0.449925
# 31775                                0.455940
# 31776                                0.452685
#
#        cost_efficient_xlsr_aliras_thrshold0.9  \
# 0                                    0.786643
# 1                                    1.000000
# 2                                    1.000000
# 3                                    1.000000
# 4                                    1.000000
# ...                                       ...
# 31772                                1.000000
# 31773                                1.000000
# 31774                                0.801221
# 31775                                1.000000
# 31776                                1.000000
#
#        prob_spoof_from_aliras_hubert_cost_efficient_threshold0.9  \
# 0                                               0.002993
# 1                                               1.000000
# 2                                               1.000000
# 3                                               1.000000
# 4                                               1.000000
# ...                                                  ...
# 31772                                           1.000000
# 31773                                           1.000000
# 31774                                           0.000050
# 31775                                           1.000000
# 31776                                           1.000000
#
#                         speaker      Label  test_probs_for1_MLP_vggish
# 0                 Alec Guinness      spoof                    0.999100
# 1                 Alec Guinness      spoof                    1.000000
# 2                Bernie Sanders      spoof                    1.000000
# 3      Alexandria Ocasio-Cortez  bona-fide                    0.999699
# 4                  Barack Obama  bona-fide                    0.999698
# ...                         ...        ...                         ...
# 31772             Alec Guinness      spoof                    0.999698
# 31773                  Ayn Rand  bona-fide                    1.000000
# 31774            Bernie Sanders      spoof                    0.999100
# 31775             Frank Sinatra  bona-fide                    0.999698
# 31776                       JFK      spoof                    1.000000
#
# [31777 rows x 12 columns]

# %%
df_test_merged2.to_csv('ITW__ensemble_vggish_SSL_ALiras_all', index=False)

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

# True labels
y_true = y_test

# Dictionary of models and their predicted probabilities
model_preds = {
    'XLSR-ResNet18': df_test_final['prob_spoof_xlsr'],
    'ALiRAS-LR+XLSR-ResNet18': df_test_final['prob_spoof_from_aliras_xlsr'],
    'ALiRAS-LR': df_test_final['y_test_pred_aliras'],
    'HuBERT-ResNet18': df_test_final['prob_spoof_hubert'],
    'ALiRAS-LR+HuBERT-ResNet18': df_test_final['prob_spoof_from_aliras_hubert'],
    'ALiRAS-LR+XLSR-ResNet18 (cost efficient)': df_test_final['cost_efficient_xlsr_aliras'],
    'ALiRAS-LR+HuBERT-ResNet18 (cost efficient)': df_test_final['prob_spoof_from_aliras_hubert_cost_efficient'],

}

plt.figure(figsize=(10, 8))

# Plot ROC for each model
for model_name, y_pred in model_preds.items():
    fpr, tpr, _ = roc_curve(y_true, y_pred)
    roc_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, lw=2, label=f'{model_name} (AUC = {roc_auc:.2f})')

# Plot chance line
plt.plot([0, 1], [0, 1], color='gray', linestyle='--', label='Chance')

# Graph formatting
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic Curves for the Test set')
plt.legend(loc='lower right')
plt.grid(alpha=0.3)
plt.show()

# %%
#same as above just removed the classifier name for AliRAS
# True labels

# Dictionary of models and their predicted probabilities
model_preds = {
    'XLSR-ResNet18': df_test_final['prob_spoof_xlsr'],
    'ALiRAS+XLSR-ResNet18': df_test_final['prob_spoof_from_aliras_xlsr'],
    'ALiRAS': df_test_final['y_test_pred_aliras'],
    'HuBERT-ResNet18': df_test_final['prob_spoof_hubert'],
    'ALiRAS+HuBERT-ResNet18': df_test_final['prob_spoof_from_aliras_hubert'],
    'ALiRAS+XLSR-ResNet18 (cost efficient)': df_test_final['cost_efficient_xlsr_aliras'],
    'ALiRAS+HuBERT-ResNet18 (cost efficient)': df_test_final['prob_spoof_from_aliras_hubert_cost_efficient'],

}

plt.figure(figsize=(10, 8))

# Plot ROC for each model
for model_name, y_pred in model_preds.items():
    fpr, tpr, _ = roc_curve(y_true, y_pred)
    roc_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, lw=2, label=f'{model_name} (AUC = {roc_auc:.2f})')

# Plot chance line
plt.plot([0, 1], [0, 1], color='gray', linestyle='--', label='Chance')

# Graph formatting
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic Curves for the Test set')
plt.legend(loc='lower right')
plt.grid(alpha=0.3)
plt.show()

# %%
# how much cost efficient is really efficient?
count = (df_test['y_test_pred_aliras'] <= 0.9).sum()
print(f'Number of rows with prob_spoof_from_aliras_lr which will be hubert or xlsr for them < 0.9: {count}')
# Out:
# Number of rows with prob_spoof_from_aliras_lr which will be hubert or xlsr for them < 0.9: 11744

# %%
(31777-11744)/31777
# Out:
# 0.6304245208798817

# %% [markdown]
# # Ablation Study
# What if we do only VGGish and not ALiRAS, can it help SSL models with time or accuracy?

# %%
import pandas as pd

# %%
df = pd.read_csv('ITW__ensemble_vggish_SSL_ALiras_all.csv')

# %%
df
# Out:
#        audio_filenames  prob_spoof_xlsr  prob_spoof_hubert  \
# 0                    0         0.786643           0.002993
# 1                    1         0.737604           0.000027
# 2                   10         0.726019           0.000025
# 3                  100         0.779081           0.001600
# 4                 1000         0.829804           0.000124
# ...                ...              ...                ...
# 31772             9993         0.794828           0.032006
# 31773             9994         0.771972           0.003858
# 31774             9995         0.801221           0.000050
# 31775             9996         0.798714           0.000005
# 31776             9997         0.715364           0.000019
#
#        true_label_fake1_real0  y_test_pred_aliras  \
# 0                           1            0.899801
# 1                           1            0.910893
# 2                           1            0.929222
# 3                           0            0.911881
# 4                           0            0.911876
# ...                       ...                 ...
# 31772                       1            0.911876
# 31773                       0            0.915452
# 31774                       1            0.899801
# 31775                       0            0.911876
# 31776                       1            0.905352
#
#        prob_spoof_from_aliras_xlsr_0.5weight  \
# 0                                   0.843222
# 1                                   0.824249
# 2                                   0.827620
# 3                                   0.845481
# 4                                   0.870840
# ...                                      ...
# 31772                               0.853352
# 31773                               0.843712
# 31774                               0.850511
# 31775                               0.855295
# 31776                               0.810358
#
#        prob_spoof_from_aliras_hubert0.5weight  \
# 0                                    0.451397
# 1                                    0.455460
# 2                                    0.464623
# 3                                    0.456741
# 4                                    0.456000
# ...                                       ...
# 31772                                0.471941
# 31773                                0.459655
# 31774                                0.449925
# 31775                                0.455940
# 31776                                0.452685
#
#        cost_efficient_xlsr_aliras_thrshold0.9  \
# 0                                    0.786643
# 1                                    1.000000
# 2                                    1.000000
# 3                                    1.000000
# 4                                    1.000000
# ...                                       ...
# 31772                                1.000000
# 31773                                1.000000
# 31774                                0.801221
# 31775                                1.000000
# 31776                                1.000000
#
#        prob_spoof_from_aliras_hubert_cost_efficient_threshold0.9  \
# 0                                               0.002993
# 1                                               1.000000
# 2                                               1.000000
# 3                                               1.000000
# 4                                               1.000000
# ...                                                  ...
# 31772                                           1.000000
# 31773                                           1.000000
# 31774                                           0.000050
# 31775                                           1.000000
# 31776                                           1.000000
#
#                         speaker      Label  test_probs_for1_MLP_vggish
# 0                 Alec Guinness      spoof                    0.999100
# 1                 Alec Guinness      spoof                    1.000000
# 2                Bernie Sanders      spoof                    1.000000
# 3      Alexandria Ocasio-Cortez  bona-fide                    0.999699
# 4                  Barack Obama  bona-fide                    0.999698
# ...                         ...        ...                         ...
# 31772             Alec Guinness      spoof                    0.999698
# 31773                  Ayn Rand  bona-fide                    1.000000
# 31774            Bernie Sanders      spoof                    0.999100
# 31775             Frank Sinatra  bona-fide                    0.999698
# 31776                       JFK      spoof                    1.000000
#
# [31777 rows x 12 columns]

# %%
df_test_final = df

# %%
y_test = df_test_final['true_label_fake1_real0']

# %%
cost_efficient_xlsr_vggish_test = df_test_final.apply(
    lambda row: 1 if row['test_probs_for1_MLP_vggish'] > 0.90 else row['prob_spoof_xlsr'],
    axis=1
)


roc_auc = roc_auc_score(y_test, cost_efficient_xlsr_vggish_test)
print("ROC AUC Score for test:", roc_auc)

#compute_eer_fixed_threshold(y_test, cost_efficient_xlsr_aliras_test, 0.635293)
# Out:
# ROC AUC Score for test: 0.5084119030559248

# %%
cost_efficient_hubert_vggish_test = df_test_final.apply(
    lambda row: 1 if row['test_probs_for1_MLP_vggish'] > 0.90 else row['prob_spoof_hubert'],
    axis=1
)


roc_auc = roc_auc_score(y_test, cost_efficient_hubert_vggish_test)
print("ROC AUC Score for test:", roc_auc)

#compute_eer_fixed_threshold(y_test, cost_efficient_xlsr_aliras_test, 0.635293)

# I changed the thrshold multiple times like 0.7 , 0.2 , the best is still this one for vggish too
# Out:
# ROC AUC Score for test: 0.5085599689770276

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

# True labels
y_true = df_test_final['true_label_fake1_real0']

# Dictionary of models and their predicted probabilities
model_preds = {
    'XLSR-ResNet18': df_test_final['prob_spoof_xlsr'],
    'HuBERT-ResNet18': df_test_final['prob_spoof_hubert'],
    'ALiRAS-LR+XLSR-ResNet18 (cost efficient)': df_test_final['cost_efficient_xlsr_aliras_thrshold0.9'],
    'ALiRAS-LR+HuBERT-ResNet18 (cost efficient)': df_test_final['prob_spoof_from_aliras_hubert_cost_efficient_threshold0.9'],
    'VGGish-MLP':df_test_final['test_probs_for1_MLP_vggish'] ,
    'VGGish-MLP+XLSR-ResNet18 (cost efficient)':  cost_efficient_xlsr_vggish_test,
    'VGGish-MLP+HuBERT-ResNet18 (cost efficient)': cost_efficient_hubert_vggish_test,
    
    

}

plt.figure(figsize=(10, 8))

# Plot ROC for each model
for model_name, y_pred in model_preds.items():
    fpr, tpr, _ = roc_curve(y_true, y_pred)
    roc_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, lw=2, label=f'{model_name} (AUC = {roc_auc:.2f})')

# Plot chance line
plt.plot([0, 1], [0, 1], color='gray', linestyle='--', label='Chance')

# Graph formatting
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic Curves for the Test set')
plt.legend(loc='lower right')
plt.grid(alpha=0.3)
plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

# True labels
y_true = df_test_final['true_label_fake1_real0']

# Dictionary of models and their predicted probabilities
model_preds = {
    'XLSR-ResNet18': df_test_final['prob_spoof_xlsr'],
    'HuBERT-ResNet18': df_test_final['prob_spoof_hubert'],
    'ALiRAS-LR+XLSR-ResNet18 (cost efficient)': df_test_final['cost_efficient_xlsr_aliras_thrshold0.9'],
    'ALiRAS-LR+HuBERT-ResNet18 (cost efficient)': df_test_final['prob_spoof_from_aliras_hubert_cost_efficient_threshold0.9'],
    'VGGish-MLP+XLSR-ResNet18 (cost efficient)':  cost_efficient_xlsr_vggish_test,
    'VGGish-MLP+HuBERT-ResNet18 (cost efficient)': cost_efficient_hubert_vggish_test,
    
    

}

plt.figure(figsize=(10, 8))

# Plot ROC for each model
for model_name, y_pred in model_preds.items():
    fpr, tpr, _ = roc_curve(y_true, y_pred)
    roc_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, lw=2, label=f'{model_name} (AUC = {roc_auc:.2f})')

# Plot chance line
plt.plot([0, 1], [0, 1], color='gray', linestyle='--', label='Chance')

# Graph formatting
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic Curves for the Test set')
plt.legend(loc='lower right')
plt.grid(alpha=0.3)
plt.show()

# %%
df_test_final
# Out:
#        audio_filenames  prob_spoof_xlsr  prob_spoof_hubert  \
# 0                    0         0.786643           0.002993
# 1                    1         0.737604           0.000027
# 2                   10         0.726019           0.000025
# 3                  100         0.779081           0.001600
# 4                 1000         0.829804           0.000124
# ...                ...              ...                ...
# 31772             9993         0.794828           0.032006
# 31773             9994         0.771972           0.003858
# 31774             9995         0.801221           0.000050
# 31775             9996         0.798714           0.000005
# 31776             9997         0.715364           0.000019
#
#        true_label_fake1_real0  y_test_pred_aliras  \
# 0                           1            0.899801
# 1                           1            0.910893
# 2                           1            0.929222
# 3                           0            0.911881
# 4                           0            0.911876
# ...                       ...                 ...
# 31772                       1            0.911876
# 31773                       0            0.915452
# 31774                       1            0.899801
# 31775                       0            0.911876
# 31776                       1            0.905352
#
#        prob_spoof_from_aliras_xlsr_0.5weight  \
# 0                                   0.843222
# 1                                   0.824249
# 2                                   0.827620
# 3                                   0.845481
# 4                                   0.870840
# ...                                      ...
# 31772                               0.853352
# 31773                               0.843712
# 31774                               0.850511
# 31775                               0.855295
# 31776                               0.810358
#
#        prob_spoof_from_aliras_hubert0.5weight  \
# 0                                    0.451397
# 1                                    0.455460
# 2                                    0.464623
# 3                                    0.456741
# 4                                    0.456000
# ...                                       ...
# 31772                                0.471941
# 31773                                0.459655
# 31774                                0.449925
# 31775                                0.455940
# 31776                                0.452685
#
#        cost_efficient_xlsr_aliras_thrshold0.9  \
# 0                                    0.786643
# 1                                    1.000000
# 2                                    1.000000
# 3                                    1.000000
# 4                                    1.000000
# ...                                       ...
# 31772                                1.000000
# 31773                                1.000000
# 31774                                0.801221
# 31775                                1.000000
# 31776                                1.000000
#
#        prob_spoof_from_aliras_hubert_cost_efficient_threshold0.9  \
# 0                                               0.002993
# 1                                               1.000000
# 2                                               1.000000
# 3                                               1.000000
# 4                                               1.000000
# ...                                                  ...
# 31772                                           1.000000
# 31773                                           1.000000
# 31774                                           0.000050
# 31775                                           1.000000
# 31776                                           1.000000
#
#                         speaker      Label  test_probs_for1_MLP_vggish
# 0                 Alec Guinness      spoof                    0.999100
# 1                 Alec Guinness      spoof                    1.000000
# 2                Bernie Sanders      spoof                    1.000000
# 3      Alexandria Ocasio-Cortez  bona-fide                    0.999699
# 4                  Barack Obama  bona-fide                    0.999698
# ...                         ...        ...                         ...
# 31772             Alec Guinness      spoof                    0.999698
# 31773                  Ayn Rand  bona-fide                    1.000000
# 31774            Bernie Sanders      spoof                    0.999100
# 31775             Frank Sinatra  bona-fide                    0.999698
# 31776                       JFK      spoof                    1.000000
#
# [31777 rows x 12 columns]

# %%
weight1 = 0.5
weight2 = 0.5
test_vggish = df_test_final['test_probs_for1_MLP_vggish']
prob_spoof_xlsr = df_test_final['prob_spoof_xlsr']
prob_spoof_hubert = df_test_final['prob_spoof_hubert']

# %%
weight1 = 0.5
weight2 = 0.5
test_vggish = df_test_final['test_probs_for1_MLP_vggish']
prob_spoof_xlsr = df_test_final['prob_spoof_xlsr']
prob_spoof_hubert = df_test_final['prob_spoof_hubert']

# Step 2: Combine the predictions
ensemble_prediction_ssl = (weight1 * test_vggish) + (weight2 * prob_spoof_hubert)

roc_auc = roc_auc_score(y_test, ensemble_prediction_ssl)

print("ROC AUC Score for train:", roc_auc)
# Out:
# ROC AUC Score for train: 0.6632015641398725

# %%
ensemble_prediction_ssl = (weight1 * test_vggish) + (weight2 * prob_spoof_xlsr)

roc_auc = roc_auc_score(y_test, ensemble_prediction_ssl)

print("ROC AUC Score for train:", roc_auc)
# Out:
# ROC AUC Score for train: 0.48759965347617945

# %%
import os

path = "resnet18_model_xlsr_trained_on_asvspoof5_7000samples.h5"
size_mb = os.path.getsize(path) / (1024**2)
print(f"Model size: {size_mb:.2f} MB")
# Out:
# Model size: 164.86 MB

# %%
path = "resnet18_model_hubert_trained_asvspoof5_7000.h5"
size_mb = os.path.getsize(path) / (1024**2)
print(f"Model size: {size_mb:.2f} MB")
# Out:
# Model size: 155.67 MB

# %%
## New : VGGish added to the comparision

# %%
df
# Out:
#        audio_filenames  prob_spoof_xlsr  prob_spoof_hubert  \
# 0                    0         0.786643           0.002993
# 1                    1         0.737604           0.000027
# 2                   10         0.726019           0.000025
# 3                  100         0.779081           0.001600
# 4                 1000         0.829804           0.000124
# ...                ...              ...                ...
# 31772             9993         0.794828           0.032006
# 31773             9994         0.771972           0.003858
# 31774             9995         0.801221           0.000050
# 31775             9996         0.798714           0.000005
# 31776             9997         0.715364           0.000019
#
#        true_label_fake1_real0  y_test_pred_aliras  \
# 0                           1            0.899801
# 1                           1            0.910893
# 2                           1            0.929222
# 3                           0            0.911881
# 4                           0            0.911876
# ...                       ...                 ...
# 31772                       1            0.911876
# 31773                       0            0.915452
# 31774                       1            0.899801
# 31775                       0            0.911876
# 31776                       1            0.905352
#
#        prob_spoof_from_aliras_xlsr_0.5weight  \
# 0                                   0.843222
# 1                                   0.824249
# 2                                   0.827620
# 3                                   0.845481
# 4                                   0.870840
# ...                                      ...
# 31772                               0.853352
# 31773                               0.843712
# 31774                               0.850511
# 31775                               0.855295
# 31776                               0.810358
#
#        prob_spoof_from_aliras_hubert0.5weight  \
# 0                                    0.451397
# 1                                    0.455460
# 2                                    0.464623
# 3                                    0.456741
# 4                                    0.456000
# ...                                       ...
# 31772                                0.471941
# 31773                                0.459655
# 31774                                0.449925
# 31775                                0.455940
# 31776                                0.452685
#
#        cost_efficient_xlsr_aliras_thrshold0.9  \
# 0                                    0.786643
# 1                                    1.000000
# 2                                    1.000000
# 3                                    1.000000
# 4                                    1.000000
# ...                                       ...
# 31772                                1.000000
# 31773                                1.000000
# 31774                                0.801221
# 31775                                1.000000
# 31776                                1.000000
#
#        prob_spoof_from_aliras_hubert_cost_efficient_threshold0.9  \
# 0                                               0.002993
# 1                                               1.000000
# 2                                               1.000000
# 3                                               1.000000
# 4                                               1.000000
# ...                                                  ...
# 31772                                           1.000000
# 31773                                           1.000000
# 31774                                           0.000050
# 31775                                           1.000000
# 31776                                           1.000000
#
#                         speaker      Label  test_probs_for1_MLP_vggish
# 0                 Alec Guinness      spoof                    0.999100
# 1                 Alec Guinness      spoof                    1.000000
# 2                Bernie Sanders      spoof                    1.000000
# 3      Alexandria Ocasio-Cortez  bona-fide                    0.999699
# 4                  Barack Obama  bona-fide                    0.999698
# ...                         ...        ...                         ...
# 31772             Alec Guinness      spoof                    0.999698
# 31773                  Ayn Rand  bona-fide                    1.000000
# 31774            Bernie Sanders      spoof                    0.999100
# 31775             Frank Sinatra  bona-fide                    0.999698
# 31776                       JFK      spoof                    1.000000
#
# [31777 rows x 12 columns]

# %%
df_test_final = df
weight1 = 0.5
weight2 = 0.5
test_vggish = df_test_final['test_probs_for1_MLP_vggish']
prob_spoof_aliras = df_test_final['y_test_pred_aliras']
y_test = df_test_final['true_label_fake1_real0']

# Step 2: Combine the predictions
ensemble_prediction_aliras = (weight1 * test_vggish) + (weight2 * prob_spoof_aliras)

roc_auc = roc_auc_score(y_test, ensemble_prediction_aliras)

print("ROC AUC Score for test:", roc_auc)
# Out:
# ROC AUC Score for test: 0.5628146228574876

# %%
df_test_final['prob_spoof_from_aliras_vggish_0.5weight'] = ensemble_prediction_aliras

# %%
df_test_final
# Out:
#        audio_filenames  prob_spoof_xlsr  prob_spoof_hubert  \
# 0                    0         0.786643           0.002993
# 1                    1         0.737604           0.000027
# 2                   10         0.726019           0.000025
# 3                  100         0.779081           0.001600
# 4                 1000         0.829804           0.000124
# ...                ...              ...                ...
# 31772             9993         0.794828           0.032006
# 31773             9994         0.771972           0.003858
# 31774             9995         0.801221           0.000050
# 31775             9996         0.798714           0.000005
# 31776             9997         0.715364           0.000019
#
#        true_label_fake1_real0  y_test_pred_aliras  \
# 0                           1            0.899801
# 1                           1            0.910893
# 2                           1            0.929222
# 3                           0            0.911881
# 4                           0            0.911876
# ...                       ...                 ...
# 31772                       1            0.911876
# 31773                       0            0.915452
# 31774                       1            0.899801
# 31775                       0            0.911876
# 31776                       1            0.905352
#
#        prob_spoof_from_aliras_xlsr_0.5weight  \
# 0                                   0.843222
# 1                                   0.824249
# 2                                   0.827620
# 3                                   0.845481
# 4                                   0.870840
# ...                                      ...
# 31772                               0.853352
# 31773                               0.843712
# 31774                               0.850511
# 31775                               0.855295
# 31776                               0.810358
#
#        prob_spoof_from_aliras_hubert0.5weight  \
# 0                                    0.451397
# 1                                    0.455460
# 2                                    0.464623
# 3                                    0.456741
# 4                                    0.456000
# ...                                       ...
# 31772                                0.471941
# 31773                                0.459655
# 31774                                0.449925
# 31775                                0.455940
# 31776                                0.452685
#
#        cost_efficient_xlsr_aliras_thrshold0.9  \
# 0                                    0.786643
# 1                                    1.000000
# 2                                    1.000000
# 3                                    1.000000
# 4                                    1.000000
# ...                                       ...
# 31772                                1.000000
# 31773                                1.000000
# 31774                                0.801221
# 31775                                1.000000
# 31776                                1.000000
#
#        prob_spoof_from_aliras_hubert_cost_efficient_threshold0.9  \
# 0                                               0.002993
# 1                                               1.000000
# 2                                               1.000000
# 3                                               1.000000
# 4                                               1.000000
# ...                                                  ...
# 31772                                           1.000000
# 31773                                           1.000000
# 31774                                           0.000050
# 31775                                           1.000000
# 31776                                           1.000000
#
#                         speaker      Label  test_probs_for1_MLP_vggish  \
# 0                 Alec Guinness      spoof                    0.999100
# 1                 Alec Guinness      spoof                    1.000000
# 2                Bernie Sanders      spoof                    1.000000
# 3      Alexandria Ocasio-Cortez  bona-fide                    0.999699
# 4                  Barack Obama  bona-fide                    0.999698
# ...                         ...        ...                         ...
# 31772             Alec Guinness      spoof                    0.999698
# 31773                  Ayn Rand  bona-fide                    1.000000
# 31774            Bernie Sanders      spoof                    0.999100
# 31775             Frank Sinatra  bona-fide                    0.999698
# 31776                       JFK      spoof                    1.000000
#
#        prob_spoof_from_aliras_vggish_0.5weight
# 0                                     0.949450
# 1                                     0.955447
# 2                                     0.964611
# 3                                     0.955790
# 4                                     0.955787
# ...                                        ...
# 31772                                 0.955787
# 31773                                 0.957726
# 31774                                 0.949450
# 31775                                 0.955787
# 31776                                 0.952676
#
# [31777 rows x 13 columns]

# %%
df_test_final.to_csv('ITW__ensemble_vggish_SSL_ALiras_all.csv')

# %%
df = pd.read_csv('ITW__ensemble_vggish_SSL_ALiras_all.csv')

# %%
df
# Out:
#        Unnamed: 0  audio_filenames  prob_spoof_xlsr  prob_spoof_hubert  \
# 0               0                0         0.786643           0.002993
# 1               1                1         0.737604           0.000027
# 2               2               10         0.726019           0.000025
# 3               3              100         0.779081           0.001600
# 4               4             1000         0.829804           0.000124
# ...           ...              ...              ...                ...
# 31772       31772             9993         0.794828           0.032006
# 31773       31773             9994         0.771972           0.003858
# 31774       31774             9995         0.801221           0.000050
# 31775       31775             9996         0.798714           0.000005
# 31776       31776             9997         0.715364           0.000019
#
#        true_label_fake1_real0  y_test_pred_aliras  \
# 0                           1            0.899801
# 1                           1            0.910893
# 2                           1            0.929222
# 3                           0            0.911881
# 4                           0            0.911876
# ...                       ...                 ...
# 31772                       1            0.911876
# 31773                       0            0.915452
# 31774                       1            0.899801
# 31775                       0            0.911876
# 31776                       1            0.905352
#
#        prob_spoof_from_aliras_xlsr_0.5weight  \
# 0                                   0.843222
# 1                                   0.824249
# 2                                   0.827620
# 3                                   0.845481
# 4                                   0.870840
# ...                                      ...
# 31772                               0.853352
# 31773                               0.843712
# 31774                               0.850511
# 31775                               0.855295
# 31776                               0.810358
#
#        prob_spoof_from_aliras_hubert0.5weight  \
# 0                                    0.451397
# 1                                    0.455460
# 2                                    0.464623
# 3                                    0.456741
# 4                                    0.456000
# ...                                       ...
# 31772                                0.471941
# 31773                                0.459655
# 31774                                0.449925
# 31775                                0.455940
# 31776                                0.452685
#
#        cost_efficient_xlsr_aliras_thrshold0.9  \
# 0                                    0.786643
# 1                                    1.000000
# 2                                    1.000000
# 3                                    1.000000
# 4                                    1.000000
# ...                                       ...
# 31772                                1.000000
# 31773                                1.000000
# 31774                                0.801221
# 31775                                1.000000
# 31776                                1.000000
#
#        prob_spoof_from_aliras_hubert_cost_efficient_threshold0.9  \
# 0                                               0.002993
# 1                                               1.000000
# 2                                               1.000000
# 3                                               1.000000
# 4                                               1.000000
# ...                                                  ...
# 31772                                           1.000000
# 31773                                           1.000000
# 31774                                           0.000050
# 31775                                           1.000000
# 31776                                           1.000000
#
#                         speaker      Label  test_probs_for1_MLP_vggish  \
# 0                 Alec Guinness      spoof                    0.999100
# 1                 Alec Guinness      spoof                    1.000000
# 2                Bernie Sanders      spoof                    1.000000
# 3      Alexandria Ocasio-Cortez  bona-fide                    0.999699
# 4                  Barack Obama  bona-fide                    0.999698
# ...                         ...        ...                         ...
# 31772             Alec Guinness      spoof                    0.999698
# 31773                  Ayn Rand  bona-fide                    1.000000
# 31774            Bernie Sanders      spoof                    0.999100
# 31775             Frank Sinatra  bona-fide                    0.999698
# 31776                       JFK      spoof                    1.000000
#
#        prob_spoof_from_aliras_vggish_0.5weight
# 0                                     0.949450
# 1                                     0.955447
# 2                                     0.964611
# 3                                     0.955790
# 4                                     0.955787
# ...                                        ...
# 31772                                 0.955787
# 31773                                 0.957726
# 31774                                 0.949450
# 31775                                 0.955787
# 31776                                 0.952676
#
# [31777 rows x 14 columns]

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

# True labels
y_true = y_test

# Dictionary of models and their predicted probabilities
model_preds = {
    'XLSR-ResNet18': df_test_final['prob_spoof_xlsr'],
    'ALiRAS-LR+XLSR-ResNet18': df_test_final['prob_spoof_from_aliras_xlsr_0.5weight'],
    'HuBERT-ResNet18': df_test_final['prob_spoof_hubert'],
    'ALiRAS-LR+HuBERT-ResNet18': df_test_final['prob_spoof_from_aliras_hubert0.5weight'],
    'ALiRAS-LR+XLSR-ResNet18 (cost efficient)': df_test_final['cost_efficient_xlsr_aliras_thrshold0.9'],
    'ALiRAS-LR+HuBERT-ResNet18 (cost efficient)': df_test_final['prob_spoof_from_aliras_hubert_cost_efficient_threshold0.9'],
    'VGGish-MLP': df_test_final['test_probs_for1_MLP_vggish'],
    'ALiRAS-LR+VGGish-MLP': df_test_final['prob_spoof_from_aliras_vggish_0.5weight']
    

}

plt.figure(figsize=(10, 8))

# Plot ROC for each model
for model_name, y_pred in model_preds.items():
    fpr, tpr, _ = roc_curve(y_true, y_pred)
    roc_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, lw=2, label=f'{model_name} (AUC = {roc_auc:.2f})')

# Plot chance line
plt.plot([0, 1], [0, 1], color='gray', linestyle='--', label='Chance')

# Graph formatting
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic Curves for the Test set')
plt.legend(loc='lower right')
plt.grid(alpha=0.3)
plt.show()
